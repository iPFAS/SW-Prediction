# %%
import sys
import os
current_dir = os.getcwd()  
project_root = os.path.dirname(current_dir)  
sys.path.insert(0, project_root) 
from pathlib import Path
import warnings
import pandas as pd
from pycaret.regression import *
from src.config.config import Config
from src.data.data_loader import DataLoader
from src.models.model_evaluator import ModelEvaluator

def train_models(train: pd.DataFrame,val: pd.DataFrame,target_column: str):
    """训练模型流程
    Args:
        data_path: 可选的数据文件路径
    """
    model_evaluator.setup_experiment(
        train_size=Config.MODEL_CONFIG['train_size'],
        train_data=train,
        val_data = val,
        target_column = target_column,
        categorical_features = Config.FEATURE_CONFIG['categorical_columns']
    )

    # 训练模型并返回最佳模型字典
    return model_evaluator.train_top_models(n_models=Config.MODEL_CONFIG['n_top_models'])

def tune(models: dict):
    """模型调优和集成"""
    # 对top模型进行调优
    tuned_models = model_evaluator.tune_models(models)

    return tuned_models

def ensemble(models: dict):
    """模型集成"""
    # 对top模型进行集成
    blended_model = model_evaluator.ensemble_models(models)

    return blended_model    
    # 模型
    
def save_models(models: dict):

    model_evaluator.saved_models(models)

# %%
# 示例用法
df = pd.read_csv(Path(Config.PATH_CONFIG['features_dir'])  / 'training_data.csv')
data_loader = DataLoader()
model_evaluator = ModelEvaluator()

# 划分数据集
train_data, val_data, country_test_data = data_loader.split_data_by_countries(
    df,
    train_size=Config.DATA_CONFIG['country_train_size'],
    val_size=Config.DATA_CONFIG['country_val_size'],
    random_state=Config.DATA_CONFIG['random_state']
)

train_data, time_test_data = data_loader.split_data_by_time(train_data,
    test_size=Config.DATA_CONFIG['time_test_size'])

# 数据分析
print('\n训练集统计信息:')
data_loader.analyze_datasets(train_data)
print('\n验证集统计信息:')
data_loader.analyze_datasets(val_data)
print('\n外部国家测试集统计信息:')
data_loader.analyze_datasets(country_test_data)
print('\n外部时间测试集统计信息:')
data_loader.analyze_datasets(time_test_data)
#合并验证集和外部国家测试集作为测试集
test_data = pd.concat([val_data, country_test_data])
print('\n合并，作为测试集统计信息:')
data_loader.analyze_datasets(test_data)
# Out:
# 训练集统计信息:
# 总数据条数: 283
# 国家总数: 32
# 包含的国家: Austria, Belgium, Bulgaria, China, Croatia, Cyprus, Denmark, Estonia, France, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, Serbia, Slovak Republic, Spain, Sweden, Turkiye, United Kingdom, United States
#
# 特征数量: 55
# 特征列表: IW, IW_log, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, income_group_ordinal, industry_gdp_interaction, industry_growth, industry_population_interaction, industry_region_relative, industry_trend, industry_value_added_pct_log, industry_value_added_pct_ma7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 1990.0:1 | 1991.0:1 | 1992.0:1 | 1993.0:1 | 1994.0:1 | 1995.0:1 | 1996.0:1 | 1997.0:2 | 1998.0:2 | 1999.0:2 | 2000.0:2 | 2001.0:2 | 2002.0:2 | 2003.0:2 | 2004.0:30 | 2005.0:2 | 2006.0:28 | 2007.0:2 | 2008.0:30 | 2009.0:2 | 2010.0:32 | 2011.0:2 | 2012.0:32 | 2013.0:2 | 2014.0:33 | 2015.0:1 | 2016.0:32 | 2018.0:30 | 2020.0:4
#
# 验证集统计信息:
# 总数据条数: 48
# 国家总数: 3
# 包含的国家: Finland, Japan, Slovenia
#
# 特征数量: 55
# 特征列表: IW, IW_log, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, income_group_ordinal, industry_gdp_interaction, industry_growth, industry_population_interaction, industry_region_relative, industry_trend, industry_value_added_pct_log, industry_value_added_pct_ma7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 1994.0:1 | 1995.0:1 | 1996.0:1 | 1997.0:1 | 1998.0:1 | 1999.0:1 | 2000.0:1 | 2001.0:1 | 2002.0:1 | 2003.0:1 | 2004.0:3 | 2005.0:1 | 2006.0:3 | 2007.0:1 | 2008.0:3 | 2009.0:1 | 2010.0:3 | 2011.0:1 | 2012.0:3 | 2013.0:1 | 2014.0:3 | 2015.0:1 | 2016.0:3 | 2017.0:1 | 2018.0:3 | 2019.0:1 | 2020.0:3 | 2021.0:1 | 2022.0:2
#
# 外部国家测试集统计信息:
# 总数据条数: 26
# 国家总数: 3
# 包含的国家: Bosnia and Herzegovina, Czechia, Germany
#
# 特征数量: 55
# 特征列表: IW, IW_log, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, income_group_ordinal, industry_gdp_interaction, industry_growth, industry_population_interaction, industry_region_relative, industry_trend, industry_value_added_pct_log, industry_value_added_pct_ma7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2004.0:2 | 2006.0:2 | 2008.0:2 | 2010.0:2 | 2012.0:3 | 2014.0:3 | 2016.0:3 | 2018.0:3 | 2020.0:3 | 2022.0:3
#
# 外部时间测试集统计信息:
# 总数据条数: 67
# 国家总数: 33
# 包含的国家: Albania, Austria, Belgium, Bulgaria, China, Croatia, Cyprus, Denmark, Estonia, France, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, Serbia, Slovak Republic, Spain, Sweden, Turkiye, United Kingdom, United States
#
# 特征数量: 55
# 特征列表: IW, IW_log, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, income_group_ordinal, industry_gdp_interaction, industry_growth, industry_population_interaction, industry_region_relative, industry_trend, industry_value_added_pct_log, industry_value_added_pct_ma7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2015.0:1 | 2016.0:1 | 2017.0:2 | 2018.0:3 | 2019.0:1 | 2020.0:27 | 2021.0:1 | 2022.0:31
#
# 合并，作为测试集统计信息:
# 总数据条数: 74
# 国家总数: 6
# 包含的国家: Bosnia and Herzegovina, Czechia, Finland, Germany, Japan, Slovenia
#
# 特征数量: 55
# 特征列表: IW, IW_log, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, income_group_ordinal, industry_gdp_interaction, industry_growth, industry_population_interaction, industry_region_relative, industry_trend, industry_value_added_pct_log, industry_value_added_pct_ma7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 1994.0:1 | 1995.0:1 | 1996.0:1 | 1997.0:1 | 1998.0:1 | 1999.0:1 | 2000.0:1 | 2001.0:1 | 2002.0:1 | 2003.0:1 | 2004.0:5 | 2005.0:1 | 2006.0:5 | 2007.0:1 | 2008.0:5 | 2009.0:1 | 2010.0:5 | 2011.0:1 | 2012.0:6 | 2013.0:1 | 2014.0:6 | 2015.0:1 | 2016.0:6 | 2017.0:1 | 2018.0:6 | 2019.0:1 | 2020.0:6 | 2021.0:1 | 2022.0:5

# %%
train_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'train.csv'), index=False)
test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'test.csv'), index=False)
time_test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'time_test_data.csv'), index=False)

# 排除不需要的列
feature_cols = [col for col in train_data.columns 
                if col not in [Config.DATA_CONFIG['target_column'], 'Country Name', 'Year','Region', 'Income Group']]

train = train_data[feature_cols]
test = test_data[feature_cols]
time_test_data = time_test_data[feature_cols] 

target_column = Config.DATA_CONFIG['target_column']
method = Config.FEATURE_CONFIG['target_transform_method']
transformed_column = f'{target_column}_{method}'

# %%
# 训练模型
models = train_models(train,test,transformed_column)
# Out:
# <style type="text/css">
# #T_66968_row8_col1, #T_66968_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_66968">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66968_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_66968_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66968_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66968_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_66968_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66968_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_66968_row1_col1" class="data row1 col1" >IW_log</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66968_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_66968_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66968_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_66968_row3_col1" class="data row3 col1" >(357, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66968_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_66968_row4_col1" class="data row4 col1" >(357, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66968_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_66968_row5_col1" class="data row5 col1" >(283, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66968_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_66968_row6_col1" class="data row6 col1" >(74, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66968_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_66968_row7_col1" class="data row7 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66968_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_66968_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_66968_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_66968_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_66968_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_66968_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_66968_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_66968_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_66968_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_66968_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_66968_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_66968_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_66968_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_66968_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_66968_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_66968_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_66968_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_66968_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_66968_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_66968_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_66968_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_66968_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_66968_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_66968_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_66968_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_66968_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_66968_row20_col1" class="data row20 col1" >53de</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cf0f7 th {
#   text-align: left;
# }
# #T_cf0f7_row0_col0, #T_cf0f7_row0_col1, #T_cf0f7_row0_col4, #T_cf0f7_row0_col6, #T_cf0f7_row1_col0, #T_cf0f7_row1_col1, #T_cf0f7_row1_col2, #T_cf0f7_row1_col3, #T_cf0f7_row1_col4, #T_cf0f7_row1_col5, #T_cf0f7_row1_col6, #T_cf0f7_row2_col0, #T_cf0f7_row2_col1, #T_cf0f7_row2_col2, #T_cf0f7_row2_col3, #T_cf0f7_row2_col5, #T_cf0f7_row2_col6, #T_cf0f7_row3_col0, #T_cf0f7_row3_col1, #T_cf0f7_row3_col2, #T_cf0f7_row3_col3, #T_cf0f7_row3_col4, #T_cf0f7_row3_col5, #T_cf0f7_row3_col6, #T_cf0f7_row4_col0, #T_cf0f7_row4_col2, #T_cf0f7_row4_col3, #T_cf0f7_row4_col4, #T_cf0f7_row4_col5, #T_cf0f7_row5_col0, #T_cf0f7_row5_col1, #T_cf0f7_row5_col2, #T_cf0f7_row5_col3, #T_cf0f7_row5_col4, #T_cf0f7_row5_col5, #T_cf0f7_row5_col6, #T_cf0f7_row6_col0, #T_cf0f7_row6_col1, #T_cf0f7_row6_col2, #T_cf0f7_row6_col3, #T_cf0f7_row6_col4, #T_cf0f7_row6_col5, #T_cf0f7_row6_col6, #T_cf0f7_row7_col0, #T_cf0f7_row7_col1, #T_cf0f7_row7_col2, #T_cf0f7_row7_col3, #T_cf0f7_row7_col4, #T_cf0f7_row7_col5, #T_cf0f7_row7_col6, #T_cf0f7_row8_col0, #T_cf0f7_row8_col1, #T_cf0f7_row8_col2, #T_cf0f7_row8_col3, #T_cf0f7_row8_col4, #T_cf0f7_row8_col5, #T_cf0f7_row8_col6, #T_cf0f7_row9_col0, #T_cf0f7_row9_col1, #T_cf0f7_row9_col2, #T_cf0f7_row9_col3, #T_cf0f7_row9_col4, #T_cf0f7_row9_col5, #T_cf0f7_row9_col6, #T_cf0f7_row10_col0, #T_cf0f7_row10_col1, #T_cf0f7_row10_col2, #T_cf0f7_row10_col3, #T_cf0f7_row10_col4, #T_cf0f7_row10_col5, #T_cf0f7_row10_col6, #T_cf0f7_row11_col0, #T_cf0f7_row11_col1, #T_cf0f7_row11_col2, #T_cf0f7_row11_col3, #T_cf0f7_row11_col4, #T_cf0f7_row11_col5, #T_cf0f7_row11_col6, #T_cf0f7_row12_col0, #T_cf0f7_row12_col1, #T_cf0f7_row12_col2, #T_cf0f7_row12_col3, #T_cf0f7_row12_col4, #T_cf0f7_row12_col5, #T_cf0f7_row12_col6, #T_cf0f7_row13_col0, #T_cf0f7_row13_col1, #T_cf0f7_row13_col2, #T_cf0f7_row13_col3, #T_cf0f7_row13_col4, #T_cf0f7_row13_col5, #T_cf0f7_row13_col6, #T_cf0f7_row14_col0, #T_cf0f7_row14_col1, #T_cf0f7_row14_col2, #T_cf0f7_row14_col3, #T_cf0f7_row14_col4, #T_cf0f7_row14_col5, #T_cf0f7_row14_col6, #T_cf0f7_row15_col0, #T_cf0f7_row15_col1, #T_cf0f7_row15_col2, #T_cf0f7_row15_col3, #T_cf0f7_row15_col4, #T_cf0f7_row15_col5, #T_cf0f7_row15_col6, #T_cf0f7_row16_col0, #T_cf0f7_row16_col1, #T_cf0f7_row16_col2, #T_cf0f7_row16_col3, #T_cf0f7_row16_col4, #T_cf0f7_row16_col5, #T_cf0f7_row16_col6, #T_cf0f7_row17_col0, #T_cf0f7_row17_col1, #T_cf0f7_row17_col2, #T_cf0f7_row17_col3, #T_cf0f7_row17_col4, #T_cf0f7_row17_col5, #T_cf0f7_row17_col6, #T_cf0f7_row18_col0, #T_cf0f7_row18_col1, #T_cf0f7_row18_col2, #T_cf0f7_row18_col3, #T_cf0f7_row18_col4, #T_cf0f7_row18_col5, #T_cf0f7_row18_col6, #T_cf0f7_row19_col0, #T_cf0f7_row19_col1, #T_cf0f7_row19_col2, #T_cf0f7_row19_col3, #T_cf0f7_row19_col4, #T_cf0f7_row19_col5, #T_cf0f7_row19_col6 {
#   text-align: left;
# }
# #T_cf0f7_row0_col2, #T_cf0f7_row0_col3, #T_cf0f7_row0_col5, #T_cf0f7_row2_col4, #T_cf0f7_row4_col1, #T_cf0f7_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cf0f7_row0_col7, #T_cf0f7_row1_col7, #T_cf0f7_row2_col7, #T_cf0f7_row3_col7, #T_cf0f7_row4_col7, #T_cf0f7_row5_col7, #T_cf0f7_row6_col7, #T_cf0f7_row7_col7, #T_cf0f7_row8_col7, #T_cf0f7_row9_col7, #T_cf0f7_row10_col7, #T_cf0f7_row11_col7, #T_cf0f7_row12_col7, #T_cf0f7_row13_col7, #T_cf0f7_row15_col7, #T_cf0f7_row16_col7, #T_cf0f7_row17_col7, #T_cf0f7_row18_col7, #T_cf0f7_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cf0f7_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cf0f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf0f7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cf0f7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cf0f7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cf0f7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cf0f7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cf0f7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cf0f7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cf0f7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf0f7_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_cf0f7_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cf0f7_row0_col1" class="data row0 col1" >1.0259</td>
#       <td id="T_cf0f7_row0_col2" class="data row0 col2" >1.7223</td>
#       <td id="T_cf0f7_row0_col3" class="data row0 col3" >1.2437</td>
#       <td id="T_cf0f7_row0_col4" class="data row0 col4" >0.2809</td>
#       <td id="T_cf0f7_row0_col5" class="data row0 col5" >0.0681</td>
#       <td id="T_cf0f7_row0_col6" class="data row0 col6" >0.0591</td>
#       <td id="T_cf0f7_row0_col7" class="data row0 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_cf0f7_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_cf0f7_row1_col1" class="data row1 col1" >1.0273</td>
#       <td id="T_cf0f7_row1_col2" class="data row1 col2" >1.8311</td>
#       <td id="T_cf0f7_row1_col3" class="data row1 col3" >1.2762</td>
#       <td id="T_cf0f7_row1_col4" class="data row1 col4" >0.3216</td>
#       <td id="T_cf0f7_row1_col5" class="data row1 col5" >0.0685</td>
#       <td id="T_cf0f7_row1_col6" class="data row1 col6" >0.0578</td>
#       <td id="T_cf0f7_row1_col7" class="data row1 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_cf0f7_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_cf0f7_row2_col1" class="data row2 col1" >1.0490</td>
#       <td id="T_cf0f7_row2_col2" class="data row2 col2" >1.9096</td>
#       <td id="T_cf0f7_row2_col3" class="data row2 col3" >1.2806</td>
#       <td id="T_cf0f7_row2_col4" class="data row2 col4" >0.3944</td>
#       <td id="T_cf0f7_row2_col5" class="data row2 col5" >0.0692</td>
#       <td id="T_cf0f7_row2_col6" class="data row2 col6" >0.0592</td>
#       <td id="T_cf0f7_row2_col7" class="data row2 col7" >0.7080</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_cf0f7_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_cf0f7_row3_col1" class="data row3 col1" >1.0320</td>
#       <td id="T_cf0f7_row3_col2" class="data row3 col2" >1.8848</td>
#       <td id="T_cf0f7_row3_col3" class="data row3 col3" >1.2951</td>
#       <td id="T_cf0f7_row3_col4" class="data row3 col4" >0.3148</td>
#       <td id="T_cf0f7_row3_col5" class="data row3 col5" >0.0696</td>
#       <td id="T_cf0f7_row3_col6" class="data row3 col6" >0.0581</td>
#       <td id="T_cf0f7_row3_col7" class="data row3 col7" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_cf0f7_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cf0f7_row4_col1" class="data row4 col1" >0.9968</td>
#       <td id="T_cf0f7_row4_col2" class="data row4 col2" >1.9424</td>
#       <td id="T_cf0f7_row4_col3" class="data row4 col3" >1.3108</td>
#       <td id="T_cf0f7_row4_col4" class="data row4 col4" >0.3023</td>
#       <td id="T_cf0f7_row4_col5" class="data row4 col5" >0.0701</td>
#       <td id="T_cf0f7_row4_col6" class="data row4 col6" >0.0551</td>
#       <td id="T_cf0f7_row4_col7" class="data row4 col7" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_cf0f7_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_cf0f7_row5_col1" class="data row5 col1" >1.0600</td>
#       <td id="T_cf0f7_row5_col2" class="data row5 col2" >1.9717</td>
#       <td id="T_cf0f7_row5_col3" class="data row

# %%
# 定义需要包含的模型简称集合
include_models = {'rf','xgboost','et','lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}

# %%
print(f'当前调优模型: {", ".join(model_dict.keys())}')

# 调优
tune_models = tune(model_dict)
# Out:
# 当前调优模型: lightgbm, rf, catboost, gbr, xgboost, et
# 当前调优模型: lightgbm , 结果如下:
# <style type="text/css">
# #T_d146f_row5_col0, #T_d146f_row5_col1, #T_d146f_row5_col2, #T_d146f_row5_col3, #T_d146f_row5_col4, #T_d146f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d146f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d146f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d146f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d146f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d146f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d146f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d146f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d146f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d146f_row0_col0" class="data row0 col0" >0.6811</td>
#       <td id="T_d146f_row0_col1" class="data row0 col1" >0.8617</td>
#       <td id="T_d146f_row0_col2" class="data row0 col2" >0.9283</td>
#       <td id="T_d146f_row0_col3" class="data row0 col3" >0.6699</td>
#       <td id="T_d146f_row0_col4" class="data row0 col4" >0.0504</td>
#       <td id="T_d146f_row0_col5" class="data row0 col5" >0.0394</td>
#     </tr>
#     <tr>
#       <th id="T_d146f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d146f_row1_col0" class="data row1 col0" >0.9599</td>
#       <td id="T_d146f_row1_col1" class="data row1 col1" >1.3360</td>
#       <td id="T_d146f_row1_col2" class="data row1 col2" >1.1559</td>
#       <td id="T_d146f_row1_col3" class="data row1 col3" >-0.4254</td>
#       <td id="T_d146f_row1_col4" class="data row1 col4" >0.0653</td>
#       <td id="T_d146f_row1_col5" class="data row1 col5" >0.0562</td>
#     </tr>
#     <tr>
#       <th id="T_d146f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d146f_row2_col0" class="data row2 col0" >0.9043</td>
#       <td id="T_d146f_row2_col1" class="data row2 col1" >1.2009</td>
#       <td id="T_d146f_row2_col2" class="data row2 col2" >1.0959</td>
#       <td id="T_d146f_row2_col3" class="data row2 col3" >0.7050</td>
#       <td id="T_d146f_row2_col4" class="data row2 col4" >0.0652</td>
#       <td id="T_d146f_row2_col5" class="data row2 col5" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_d146f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d146f_row3_col0" class="data row3 col0" >0.7690</td>
#       <td id="T_d146f_row3_col1" class="data row3 col1" >0.7964</td>
#       <td id="T_d146f_row3_col2" class="data row3 col2" >0.8924</td>
#       <td id="T_d146f_row3_col3" class="data row3 col3" >0.7790</td>
#       <td id="T_d146f_row3_col4" class="data row3 col4" >0.0506</td>
#       <td id="T_d146f_row3_col5" class="data row3 col5" >0.0456</td>
#     </tr>
#     <tr>
#       <th id="T_d146f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d146f_row4_col0" class="data row4 col0" >1.8785</td>
#       <td id="T_d146f_row4_col1" class="data row4 col1" >4.7579</td>
#       <td id="T_d146f_row4_col2" class="data row4 col2" >2.1813</td>
#       <td id="T_d146f_row4_col3" class="data row4 col3" >0.4003</td>
#       <td id="T_d146f_row4_col4" class="data row4 col4" >0.1075</td>
#       <td id="T_d146f_row4_col5" class="data row4 col5" >0.0953</td>
#     </tr>
#     <tr>
#       <th id="T_d146f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d146f_row5_col0" class="data row5 col0" >1.0386</td>
#       <td id="T_d146f_row5_col1" class="data row5 col1" >1.7906</td>
#       <td id="T_d146f_row5_col2" class="data row5 col2" >1.2507</td>
#       <td id="T_d146f_row5_col3" class="data row5 col3" >0.4257</td>
#       <td id="T_d146f_row5_col4" class="data row5 col4" >0.0678</td>
#       <td id="T_d146f_row5_col5" class="data row5 col5" >0.0589</td>
#     </tr>
#     <tr>
#       <th id="T_d146f_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d146f_row6_col0" class="data row6 col0" >0.4313</td>
#       <td id="T_d146f_row6_col1" class="data row6 col1" >1.4974</td>
#       <td id="T_d146f_row6_col2" class="data row6 col2" >0.4757</td>
#       <td id="T_d146f_row6_col3" class="data row6 col3" >0.4444</td>
#       <td id="T_d146f_row6_col4" class="data row6 col4" >0.0209</td>
#       <td id="T_d146f_row6_col5" class="data row6 col5" >0.0194</td>
#     </tr>
#   </tbody>
# </table>
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_8b8c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b8c5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8b8c5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8b8c5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8b8c5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8b8c5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8b8c5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8b8c5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b8c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b8c5_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8b8c5_row0_col1" class="data row0 col1" >0.7360</td>
#       <td id="T_8b8c5_row0_col2" class="data row0 col2" >0.7731</td>
#       <td id="T_8b8c5_row0_col3" class="data row0 col3" >0.8793</td>
#       <td id="T_8b8c5_row0_col4" class="data row0 col4" >0.6463</td>
#       <td id="T_8b8c5_row0_col5" class="data row0 col5" >0.0471</td>
#       <td id="T_8b8c5_row0_col6" class="data row0 col6" >0.0405</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: rf , 结果如下:
# <style type="text/css">
# #T_14f6c_row5_col0, #T_14f6c_row5_col1, #T_14f6c_row5_col2, #T_14f6c_row5_col3, #T_14f6c_row5_col4, #T_14f6c_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_14f6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14f6c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_14f6c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_14f6c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_14f6c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_14f6c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_14f6c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14f6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14f6c_row0_col0" class="data row0 col0" >0.9085</td>
#       <td id="T_14f6c_row0_col1" class="data row0 col1" >1.2495</td>
#       <td id="T_14f6c_row0_col2" class="data row0 col2" >1.1178</td>
#       <td id="T_14f6c_row0_col3" class="data row0 col3" >0.5213</td>
#       <td id="T_14f6c_row0_col4" class="data row0 col4" >0.0600</td>
#       <td id="T_14f6c_row0_col5" class="data row0 col5" >0.0525</td>
#     </tr>
#     <tr>
#       <th id="T_14f6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14f6c_row1_col0" class="data row1 col0" >0.9978</td>
#       <td id="T_14f6c_row1_col1" class="data row1 col1" >1.6686</td>
#       <td id="T_14f6c_row1_col2" class="data row1 col2" >1.2918</td>
#       <td id="T_14f6c_row1_col3" class="data row1 col3" >-0.7803</td>
#       <td id="T_14f6c_row1_col4" class="data row1 col4" >0.0732</td>
#       <td id="T_14f6c_row1_col5" class="data row1 col5" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_14f6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14f6c_row2_col0" class="data row2 col0" >0.8703</td>
#       <td id="T_14f6c_row2_col1" class="data row2 col1" >1.0583</td>
#       <td id="T_14f6c_row2_col2" class="data row2 col2" >1.0287</td>
#       <td id="T_14f6c_row2_col3" class="data row2 col3" >0.7400</td>
#       <td id="T_14f6c_row2_col4" class="data row2 col4" >0.0601</td>
#       <td id="T_14f6c_row2_col5" class="data row2 col5" >0.0549</td>
#     </tr>
#     <tr>
#       <th id="T_14f6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14f6c_row3_col0" class="data row3 col0" >0.7106</td>
#       <td id="T_14f6c_row3_col1" class="data row3 col1" >0.7615</td>
#       <td id="T_14f6c_row3_col2" class="data row3 col2" >0.8726</td>
#       <td id="T_14f6c_row3_col3" class="data row3 col3" >0.7887</td>
#       <td id="T_14f6c_row3_col4" class="data row3 col4" >0.0492</td>
#       <td id="T_14f6c_row3_col5" class="data row3 col5" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_14f6c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14f6c_row4_col0" class="data row4 col0" >1.5903</td>
#       <td id="T_14f6c_row4_col1" class="data row4 col1" >3.6622</td>
#       <td id="T_14f6c_row4_col2" class="data row4 col2" >1.9137</td>
#       <td id="T_14f6c_row4_col3" class="data row4 col3" >0.5384</td>
#       <td id="T_14f6c_row4_col4" class="data row4 col4" >0.0941</td>
#       <td id="T_14f6c_row4_col5" class="data row4 col5" >0.0807</td>
#     </tr>
#     <tr>
#       <th id="T_14f6c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_14f6c_row5_col0" class="data row5 col0" >1.0155</td>
#       <td id="T_14f6c_row5_col1" class="data row5 col1" >1.6800</td>
#       <td id="T_14f6c_row5_col2" class="data row5 col2" >1.2449</td>
#       <td id="T_14f6c_row5_col3" class="data row5 col3" >0.3616</td>
#       <td id="T_14f6c_row5_col4" class="data row5 col4" >0.0673</td>
#       <td id="T_14f6c_row5_col5" class="data row5 col5" >0.0578</td>
#     </tr>
#     <tr>
#       <th id="T_14f6c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_14f6c_row6_col0" class="data row6 col0" >0.3020</td>
#       <td id="T_14f6c_row6_col1" class="data row6 col1" >1.0339</td>
#       <td id="T_14f6c_row6_col2" class="data row6 col2" >0.3608</td>
#       <td id="T_14f6c_row6_col3" class="data row6 col3" >0.5807</td>
#       <td id="T_14f6c_row6_col4" class="data row6 col4" >0.0154</td>
#       <td id="T_14f6c_row6_col5" class="data row6 col5" >0.0127</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_464f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_464f9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_464f9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_464f9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_464f9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_464f9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_464f9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_464f9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_464f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_464f9_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_464f9_row0_col1" class="data row0 col1" >1.0990</td>
#       <td id="T_464f9_row0_col2" class="data row0 col2" >1.5826</td>
#       <td id="T_464f9_row0_col3" class="data row0 col3" >1.2580</td>
#       <td id="T_464f9_row0_col4" class="data row0 col4" >0.2760</td>
#       <td id="T_464f9_row0_col5" class="data row0 col5" >0.0672</td>
#       <td id="T_464f9_row0_col6" class="data row0 col6" >0.0604</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: catboost , 结果如下:
# <style type="text/css">
# #T_eb61d_row5_col0, #T_eb61d_row5_col1, #T_eb61d_row5_col2, #T_eb61d_row5_col3, #T_eb61d_row5_col4, #T_eb61d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eb61d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb61d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_eb61d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_eb61d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_eb61d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_eb61d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_eb61d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb61d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb61d_row0_col0" class="data row0 col0" >0.9781</td>
#       <td id="T_eb61d_row0_col1" class="data row0 col1" >1.3775</td>
#       <td id="T_eb61d_row0_col2" class="data row0 col2" >1.1737</td>
#       <td id="T_eb61d_row0_col3" class="data row0 col3" >0.4723</td>
#       <td id="T_eb61d_row0_col4" class="data row0 col4" >0.0640</td>
#       <td id="T_eb61d_row0_col5" class="data row0 col5" >0.0579</td>
#     </tr>
#     <tr>
#       <th id="T_eb61d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb61d_row1_col0" class="data row1 col0" >0.9044</td>
#       <td id="T_eb61d_row1_col1" class="data row1 col1" >1.3467</td>
#       <td id="T_eb61d_row1_col2" class="data row1 col2" >1.1605</td>
#       <td id="T_eb61d_row1_col3" class="data row1 col3" >-0.4368</td>
#       <td id="T_eb61d_row1_col4" class="data row1 col4" >0.0661</td>
#       <td id="T_eb61d_row1_col5" class="data row1 col5" >0.0531</td>
#     </tr>
#     <tr>
#       <th id="T_eb61d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb61d_row2_col0" class="data row2 col0" >0.7062</td>
#       <td id="T_eb61d_row2_col1" class="data row2 col1" >0.7110</td>
#       <td id="T_eb61d_row2_col2" class="data row2 col2" >0.8432</td>
#       <td id="T_eb61d_row2_col3" class="data row2 col3" >0.8254</td>
#       <td id="T_eb61d_row2_col4" class="data row2 col4" >0.0486</td>
#       <td id="T_eb61d_row2_col5" class="data row2 col5" >0.0438</td>
#     </tr>
#     <tr>
#       <th id="T_eb61d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb61d_row3_col0" class="data row3 col0" >0.5908</td>
#       <td id="T_eb61d_row3_col1" class="data row3 col1" >0.4693</td>
#       <td id="T_eb61d_row3_col2" class="data row3 col2" >0.6851</td>
#       <td id="T_eb61d_row3_col3" class="data row3 col3" >0.8698</td>
#       <td id="T_eb61d_row3_col4" class="data row3 col4" >0.0389</td>
#       <td id="T_eb61d_row3_col5" class="data row3 col5" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_eb61d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb61d_row4_col0" class="data row4 col0" >1.8783</td>
#       <td id="T_eb61d_row4_col1" class="data row4 col1" >4.5625</td>
#       <td id="T_eb61d_row4_col2" class="data row4 col2" >2.1360</td>
#       <td id="T_eb61d_row4_col3" class="data row4 col3" >0.4249</td>
#       <td id="T_eb61d_row4_col4" class="data row4 col4" >0.1077</td>
#       <td id="T_eb61d_row4_col5" class="data row4 col5" >0.0983</td>
#     </tr>
#     <tr>
#       <th id="T_eb61d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_eb61d_row5_col0" class="data row5 col0" >1.0116</td>
#       <td id="T_eb61d_row5_col1" class="data row5 col1" >1.6934</td>
#       <td id="T_eb61d_row5_col2" class="data row5 col2" >1.1997</td>
#       <td id="T_eb61d_row5_col3" class="data row5 col3" >0.4311</td>
#       <td id="T_eb61d_row5_col4" class="data row5 col4" >0.0651</td>
#       <td id="T_eb61d_row5_col5" class="data row5 col5" >0.0576</td>
#     </tr>
#     <tr>
#       <th id="T_eb61d_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_eb61d_row6_col0" class="data row6 col0" >0.4548</td>
#       <td id="T_eb61d_row6_col1" class="data row6 col1" >1.4775</td>
#       <td id="T_eb61d_row6_col2" class="data row6 col2" >0.5041</td>
#       <td id="T_eb61d_row6_col3" class="data row6 col3" >0.4697</td>
#       <td id="T_eb61d_row6_col4" class="data row6 col4" >0.0236</td>
#       <td id="T_eb61d_row6_col5" class="data row6 col5" >0.0218</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d6be6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6be6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d6be6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d6be6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d6be6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d6be6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d6be6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d6be6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6be6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6be6_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_d6be6_row0_col1" class="data row0 col1" >0.7661</td>
#       <td id="T_d6be6_row0_col2" class="data row0 col2" >0.8386</td>
#       <td id="T_d6be6_row0_col3" class="data row0 col3" >0.9158</td>
#       <td id="T_d6be6_row0_col4" class="data row0 col4" >0.6163</td>
#       <td id="T_d6be6_row0_col5" class="data row0 col5" >0.0490</td>
#       <td id="T_d6be6_row0_col6" class="data row0 col6" >0.0420</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: gbr , 结果如下:
# <style type="text/css">
# #T_b0d71_row5_col0, #T_b0d71_row5_col1, #T_b0d71_row5_col2, #T_b0d71_row5_col3, #T_b0d71_row5_col4, #T_b0d71_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b0d71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0d71_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b0d71_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b0d71_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b0d71_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b0d71_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b0d71_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0d71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0d71_row0_col0" class="data row0 col0" >0.9317</td>
#       <td id="T_b0d71_row0_col1" class="data row0 col1" >1.2087</td>
#       <td id="T_b0d71_row0_col2" class="data row0 col2" >1.0994</td>
#       <td id="T_b0d71_row0_col3" class="data row0 col3" >0.5369</td>
#       <td id="T_b0d71_row0_col4" class="data row0 col4" >0.0593</td>
#       <td id="T_b0d71_row0_col5" class="data row0 col5" >0.0545</td>
#     </tr>
#     <tr>
#       <th id="T_b0d71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0d71_row1_col0" class="data row1 col0" >0.8285</td>
#       <td id="T_b0d71_row1_col1" class="data row1 col1" >1.4287</td>
#       <td id="T_b0d71_row1_col2" class="data row1 col2" >1.1953</td>
#       <td id="T_b0d71_row1_col3" class="data row1 col3" >-0.5243</td>
#       <td id="T_b0d71_row1_col4" class="data row1 col4" >0.0693</td>
#       <td id="T_b0d71_row1_col5" class="data row1 col5" >0.0485</td>
#     </tr>
#     <tr>
#       <th id="T_b0d71_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b0d71_row2_col0" class="data row2 col0" >0.7472</td>
#       <td id="T_b0d71_row2_col1" class="data row2 col1" >0.7482</td>
#       <td id="T_b0d71_row2_col2" class="data row2 col2" >0.8650</td>
#       <td id="T_b0d71_row2_col3" class="data row2 col3" >0.8162</td>
#       <td id="T_b0d71_row2_col4" class="data row2 col4" >0.0491</td>
#       <td id="T_b0d71_row2_col5" class="data row2 col5" >0.0457</td>
#     </tr>
#     <tr>
#       <th id="T_b0d71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b0d71_row3_col0" class="data row3 col0" >0.6001</td>
#       <td id="T_b0d71_row3_col1" class="data row3 col1" >0.4907</td>
#       <td id="T_b0d71_row3_col2" class="data row3 col2" >0.7005</td>
#       <td id="T_b0d71_row3_col3" class="data row3 col3" >0.8638</td>
#       <td id="T_b0d71_row3_col4" class="data row3 col4" >0.0408</td>
#       <td id="T_b0d71_row3_col5" class="data row3 col5" >0.0362</td>
#     </tr>
#     <tr>
#       <th id="T_b0d71_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b0d71_row4_col0" class="data row4 col0" >1.3065</td>
#       <td id="T_b0d71_row4_col1" class="data row4 col1" >2.4358</td>
#       <td id="T_b0d71_row4_col2" class="data row4 col2" >1.5607</td>
#       <td id="T_b0d71_row4_col3" class="data row4 col3" >0.6930</td>
#       <td id="T_b0d71_row4_col4" class="data row4 col4" >0.0754</td>
#       <td id="T_b0d71_row4_col5" class="data row4 col5" >0.0659</td>
#     </tr>
#     <tr>
#       <th id="T_b0d71_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b0d71_row5_col0" class="data row5 col0" >0.8828</td>
#       <td id="T_b0d71_row5_col1" class="data row5 col1" >1.2624</td>
#       <td id="T_b0d71_row5_col2" class="data row5 col2" >1.0842</td>
#       <td id="T_b0d71_row5_col3" class="data row5 col3" >0.4771</td>
#       <td id="T_b0d71_row5_col4" class="data row5 col4" >0.0588</td>
#       <td id="T_b0d71_row5_col5" class="data row5 col5" >0.0502</td>
#     </tr>
#     <tr>
#       <th id="T_b0d71_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b0d71_row6_col0" class="data row6 col0" >0.2380</td>
#       <td id="T_b0d71_row6_col1" class="data row6 col1" >0.6734</td>
#       <td id="T_b0d71_row6_col2" class="data row6 col2" >0.2949</td>
#       <td id="T_b0d71_row6_col3" class="data row6 col3" >0.5133</td>
#       <td id="T_b0d71_row6_col4" class="data row6 col4" >0.0127</td>
#       <td id="T_b0d71_row6_col5" class="data row6 col5" >0.0098</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f3b1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3b1f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f3b1f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f3b1f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f3b1f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f3b1f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f3b1f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f3b1f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3b1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3b1f_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f3b1f_row0_col1" class="data row0 col1" >0.8258</td>
#       <td id="T_f3b1f_row0_col2" class="data row0 col2" >1.0524</td>
#       <td id="T_f3b1f_row0_col3" class="data row0 col3" >1.0259</td>
#       <td id="T_f3b1f_row0_col4" class="data row0 col4" >0.5185</td>
#       <td id="T_f3b1f_row0_col5" class="data row0 col5" >0.0558</td>
#       <td id="T_f3b1f_row0_col6" class="data row0 col6" >0.0461</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: xgboost , 结果如下:
# <style type="text/css">
# #T_582de_row5_col0, #T_582de_row5_col1, #T_582de_row5_col2, #T_582de_row5_col3, #T_582de_row5_col4, #T_582de_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_582de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_582de_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_582de_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_582de_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_582de_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_582de_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_582de_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_582de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_582de_row0_col0" class="data row0 col0" >0.7434</td>
#       <td id="T_582de_row0_col1" class="data row0 col1" >1.3149</td>
#       <td id="T_582de_row0_col2" class="data row0 col2" >1.1467</td>
#       <td id="T_582de_row0_col3" class="data row0 col3" >0.4963</td>
#       <td id="T_582de_row0_col4" class="data row0 col4" >0.0619</td>
#       <td id="T_582de_row0_col5" class="data row0 col5" >0.0416</td>
#     </tr>
#     <tr>
#       <th id="T_582de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_582de_row1_col0" class="data row1 col0" >0.9377</td>
#       <td id="T_582de_row1_col1" class="data row1 col1" >1.7071</td>
#       <td id="T_582de_row1_col2" class="data row1 col2" >1.3066</td>
#       <td id="T_582de_row1_col3" class="data row1 col3" >-0.8214</td>
#       <td id="T_582de_row1_col4" class="data row1 col4" >0.0742</td>
#       <td id="T_582de_row1_col5" class="data row1 col5" >0.0551</td>
#     </tr>
#     <tr>
#       <th id="T_582de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_582de_row2_col0" class="data row2 col0" >0.7939</td>
#       <td id="T_582de_row2_col1" class="data row2 col1" >0.9341</td>
#       <td id="T_582de_row2_col2" class="data row2 col2" >0.9665</td>
#       <td id="T_582de_row2_col3" class="data row2 col3" >0.7706</td>
#       <td id="T_582de_row2_col4" class="data row2 col4" >0.0576</td>
#       <td id="T_582de_row2_col5" class="data row2 col5" >0.0504</td>
#     </tr>
#     <tr>
#       <th id="T_582de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_582de_row3_col0" class="data row3 col0" >0.4808</td>
#       <td id="T_582de_row3_col1" class="data row3 col1" >0.3250</td>
#       <td id="T_582de_row3_col2" class="data row3 col2" >0.5700</td>
#       <td id="T_582de_row3_col3" class="data row3 col3" >0.9098</td>
#       <td id="T_582de_row3_col4" class="data row3 col4" >0.0312</td>
#       <td id="T_582de_row3_col5" class="data row3 col5" >0.0278</td>
#     </tr>
#     <tr>
#       <th id="T_582de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_582de_row4_col0" class="data row4 col0" >1.3274</td>
#       <td id="T_582de_row4_col1" class="data row4 col1" >2.5424</td>
#       <td id="T_582de_row4_col2" class="data row4 col2" >1.5945</td>
#       <td id="T_582de_row4_col3" class="data row4 col3" >0.6795</td>
#       <td id="T_582de_row4_col4" class="data row4 col4" >0.0770</td>
#       <td id="T_582de_row4_col5" class="data row4 col5" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_582de_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_582de_row5_col0" class="data row5 col0" >0.8567</td>
#       <td id="T_582de_row5_col1" class="data row5 col1" >1.3647</td>
#       <td id="T_582de_row5_col2" class="data row5 col2" >1.1168</td>
#       <td id="T_582de_row5_col3" class="data row5 col3" >0.4070</td>
#       <td id="T_582de_row5_col4" class="data row5 col4" >0.0604</td>
#       <td id="T_582de_row5_col5" class="data row5 col5" >0.0484</td>
#     </tr>
#     <tr>
#       <th id="T_582de_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_582de_row6_col0" class="data row6 col0" >0.2779</td>
#       <td id="T_582de_row6_col1" class="data row6 col1" >0.7447</td>
#       <td id="T_582de_row6_col2" class="data row6 col2" >0.3425</td>
#       <td id="T_582de_row6_col3" class="data row6 col3" >0.6287</td>
#       <td id="T_582de_row6_col4" class="data row6 col4" >0.0163</td>
#       <td id="T_582de_row6_col5" class="data row6 col5" >0.0131</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5d264">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d264_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5d264_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5d264_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5d264_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5d264_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5d264_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5d264_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d264_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d264_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_5d264_row0_col1" class="data row0 col1" >0.8015</td>
#       <td id="T_5d264_row0_col2" class="data row0 col2" >0.9931</td>
#       <td id="T_5d264_row0_col3" class="data row0 col3" >0.9965</td>
#       <td id="T_5d264_row0_col4" class="data row0 col4" >0.5457</td>
#       <td id="T_5d264_row0_col5" class="data row0 col5" >0.0547</td>
#       <td id="T_5d264_row0_col6" class="data row0 col6" >0.0449</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: et , 结果如下:
# <style type="text/css">
# #T_f1839_row5_col0, #T_f1839_row5_col1, #T_f1839_row5_col2, #T_f1839_row5_col3, #T_f1839_row5_col4, #T_f1839_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f1839">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1839_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f1839_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f1839_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f1839_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f1839_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f1839_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1839_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1839_row0_col0" class="data row0 col0" >1.0331</td>
#       <td id="T_f1839_row0_col1" class="data row0 col1" >1.7150</td>
#       <td id="T_f1839_row0_col2" class="data row0 col2" >1.3096</td>
#       <td id="T_f1839_row0_col3" class="data row0 col3" >0.3430</td>
#       <td id="T_f1839_row0_col4" class="data row0 col4" >0.0710</td>
#       <td id="T_f1839_row0_col5" class="data row0 col5" >0.0595</td>
#     </tr>
#     <tr>
#       <th id="T_f1839_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1839_row1_col0" class="data row1 col0" >0.9865</td>
#       <td id="T_f1839_row1_col1" class="data row1 col1" >1.7926</td>
#       <td id="T_f1839_row1_col2" class="data row1 col2" >1.3389</td>
#       <td id="T_f1839_row1_col3" class="data row1 col3" >-0.9126</td>
#       <td id="T_f1839_row1_col4" class="data row1 col4" >0.0762</td>
#       <td id="T_f1839_row1_col5" class="data row1 col5" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_f1839_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1839_row2_col0" class="data row2 col0" >0.6367</td>
#       <td id="T_f1839_row2_col1" class="data row2 col1" >0.5543</td>
#       <td id="T_f1839_row2_col2" class="data row2 col2" >0.7445</td>
#       <td id="T_f1839_row2_col3" class="data row2 col3" >0.8638</td>
#       <td id="T_f1839_row2_col4" class="data row2 col4" >0.0422</td>
#       <td id="T_f1839_row2_col5" class="data row2 col5" >0.0392</td>
#     </tr>
#     <tr>
#       <th id="T_f1839_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1839_row3_col0" class="data row3 col0" >0.6652</td>
#       <td id="T_f1839_row3_col1" class="data row3 col1" >0.6552</td>
#       <td id="T_f1839_row3_col2" class="data row3 col2" >0.8094</td>
#       <td id="T_f1839_row3_col3" class="data row3 col3" >0.8182</td>
#       <td id="T_f1839_row3_col4" class="data row3 col4" >0.0460</td>
#       <td id="T_f1839_row3_col5" class="data row3 col5" >0.0395</td>
#     </tr>
#     <tr>
#       <th id="T_f1839_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1839_row4_col0" class="data row4 col0" >1.6363</td>
#       <td id="T_f1839_row4_col1" class="data row4 col1" >3.7402</td>
#       <td id="T_f1839_row4_col2" class="data row4 col2" >1.9340</td>
#       <td id="T_f1839_row4_col3" class="data row4 col3" >0.5285</td>
#       <td id="T_f1839_row4_col4" class="data row4 col4" >0.0946</td>
#       <td id="T_f1839_row4_col5" class="data row4 col5" >0.0828</td>
#     </tr>
#     <tr>
#       <th id="T_f1839_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_f1839_row5_col0" class="data row5 col0" >0.9916</td>
#       <td id="T_f1839_row5_col1" class="data row5 col1" >1.6915</td>
#       <td id="T_f1839_row5_col2" class="data row5 col2" >1.2273</td>
#       <td id="T_f1839_row5_col3" class="data row5 col3" >0.3282</td>
#       <td id="T_f1839_row5_col4" class="data row5 col4" >0.0660</td>
#       <td id="T_f1839_row5_col5" class="data row5 col5" >0.0558</td>
#     </tr>
#     <tr>
#       <th id="T_f1839_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_f1839_row6_col0" class="data row6 col0" >0.3605</td>
#       <td id="T_f1839_row6_col1" class="data row6 col1" >1.1467</td>
#       <td id="T_f1839_row6_col2" class="data row6 col2" >0.4304</td>
#       <td id="T_f1839_row6_col3" class="data row6 col3" >0.6491</td>
#       <td id="T_f1839_row6_col4" class="data row6 col4" >0.0196</td>
#       <td id="T_f1839_row6_col5" class="data row6 col5" >0.0161</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9400c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9400c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9400c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9400c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9400c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9400c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9400c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9400c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9400c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9400c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_9400c_row0_col1" class="data row0 col1" >0.8000</td>
#       <td id="T_9400c_row0_col2" class="data row0 col2" >0.9999</td>
#       <td id="T_9400c_row0_col3" class="data row0 col3" >0.9999</td>
#       <td id="T_9400c_row0_col4" class="data row0 col4" >0.5426</td>
#       <td id="T_9400c_row0_col5" class="data row0 col5" >0.0538</td>
#       <td id="T_9400c_row0_col6" class="data row0 col6" >0.0436</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 集成
models = ensemble(tune_models)
# Out:
# <style type="text/css">
# #T_367d9_row5_col0, #T_367d9_row5_col1, #T_367d9_row5_col2, #T_367d9_row5_col3, #T_367d9_row5_col4, #T_367d9_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_367d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_367d9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_367d9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_367d9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_367d9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_367d9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_367d9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_367d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_367d9_row0_col0" class="data row0 col0" >0.8808</td>
#       <td id="T_367d9_row0_col1" class="data row0 col1" >1.1036</td>
#       <td id="T_367d9_row0_col2" class="data row0 col2" >1.0505</td>
#       <td id="T_367d9_row0_col3" class="data row0 col3" >0.5772</td>
#       <td id="T_367d9_row0_col4" class="data row0 col4" >0.0571</td>
#       <td id="T_367d9_row0_col5" class="data row0 col5" >0.0514</td>
#     </tr>
#     <tr>
#       <th id="T_367d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_367d9_row1_col0" class="data row1 col0" >0.9227</td>
#       <td id="T_367d9_row1_col1" class="data row1 col1" >1.5965</td>
#       <td id="T_367d9_row1_col2" class="data row1 col2" >1.2635</td>
#       <td id="T_367d9_row1_col3" class="data row1 col3" >-0.7034</td>
#       <td id="T_367d9_row1_col4" class="data row1 col4" >0.0722</td>
#       <td id="T_367d9_row1_col5" class="data row1 col5" >0.0541</td>
#     </tr>
#     <tr>
#       <th id="T_367d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_367d9_row2_col0" class="data row2 col0" >0.7092</td>
#       <td id="T_367d9_row2_col1" class="data row2 col1" >0.7698</td>
#       <td id="T_367d9_row2_col2" class="data row2 col2" >0.8774</td>
#       <td id="T_367d9_row2_col3" class="data row2 col3" >0.8109</td>
#       <td id="T_367d9_row2_col4" class="data row2 col4" >0.0503</td>
#       <td id="T_367d9_row2_col5" class="data row2 col5" >0.0439</td>
#     </tr>
#     <tr>
#       <th id="T_367d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_367d9_row3_col0" class="data row3 col0" >0.5576</td>
#       <td id="T_367d9_row3_col1" class="data row3 col1" >0.4206</td>
#       <td id="T_367d9_row3_col2" class="data row3 col2" >0.6485</td>
#       <td id="T_367d9_row3_col3" class="data row3 col3" >0.8833</td>
#       <td id="T_367d9_row3_col4" class="data row3 col4" >0.0365</td>
#       <td id="T_367d9_row3_col5" class="data row3 col5" >0.0328</td>
#     </tr>
#     <tr>
#       <th id="T_367d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_367d9_row4_col0" class="data row4 col0" >1.5437</td>
#       <td id="T_367d9_row4_col1" class="data row4 col1" >3.3332</td>
#       <td id="T_367d9_row4_col2" class="data row4 col2" >1.8257</td>
#       <td id="T_367d9_row4_col3" class="data row4 col3" >0.5798</td>
#       <td id="T_367d9_row4_col4" class="data row4 col4" >0.0894</td>
#       <td id="T_367d9_row4_col5" class="data row4 col5" >0.0786</td>
#     </tr>
#     <tr>
#       <th id="T_367d9_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_367d9_row5_col0" class="data row5 col0" >0.9228</td>
#       <td id="T_367d9_row5_col1" class="data row5 col1" >1.4447</td>
#       <td id="T_367d9_row5_col2" class="data row5 col2" >1.1331</td>
#       <td id="T_367d9_row5_col3" class="data row5 col3" >0.4296</td>
#       <td id="T_367d9_row5_col4" class="data row5 col4" >0.0611</td>
#       <td id="T_367d9_row5_col5" class="data row5 col5" >0.0522</td>
#     </tr>
#     <tr>
#       <th id="T_367d9_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_367d9_row6_col0" class="data row6 col0" >0.3365</td>
#       <td id="T_367d9_row6_col1" class="data row6 col1" >1.0208</td>
#       <td id="T_367d9_row6_col2" class="data row6 col2" >0.4009</td>
#       <td id="T_367d9_row6_col3" class="data row6 col3" >0.5795</td>
#       <td id="T_367d9_row6_col4" class="data row6 col4" >0.0182</td>
#       <td id="T_367d9_row6_col5" class="data row6 col5" >0.0151</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_43cea th {
#   text-align: left;
# }
# #T_43cea_row0_col0, #T_43cea_row0_col1, #T_43cea_row0_col6, #T_43cea_row1_col0, #T_43cea_row1_col1, #T_43cea_row1_col2, #T_43cea_row1_col3, #T_43cea_row1_col4, #T_43cea_row1_col5, #T_43cea_row1_col6, #T_43cea_row2_col0, #T_43cea_row2_col1, #T_43cea_row2_col2, #T_43cea_row2_col3, #T_43cea_row2_col4, #T_43cea_row2_col5, #T_43cea_row2_col6, #T_43cea_row3_col0, #T_43cea_row3_col2, #T_43cea_row3_col3, #T_43cea_row3_col4, #T_43cea_row3_col5, #T_43cea_row4_col0, #T_43cea_row4_col1, #T_43cea_row4_col2, #T_43cea_row4_col3, #T_43cea_row4_col4, #T_43cea_row4_col5, #T_43cea_row4_col6, #T_43cea_row5_col0, #T_43cea_row5_col1, #T_43cea_row5_col2, #T_43cea_row5_col3, #T_43cea_row5_col4, #T_43cea_row5_col5, #T_43cea_row5_col6, #T_43cea_row6_col0, #T_43cea_row6_col1, #T_43cea_row6_col2, #T_43cea_row6_col3, #T_43cea_row6_col4, #T_43cea_row6_col5, #T_43cea_row6_col6 {
#   text-align: left;
# }
# #T_43cea_row0_col2, #T_43cea_row0_col3, #T_43cea_row0_col4, #T_43cea_row0_col5, #T_43cea_row3_col1, #T_43cea_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_43cea_row0_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_43cea_row1_col7, #T_43cea_row2_col7, #T_43cea_row3_col7, #T_43cea_row4_col7, #T_43cea_row5_col7, #T_43cea_row6_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_43cea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43cea_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_43cea_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_43cea_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_43cea_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_43cea_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_43cea_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_43cea_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_43cea_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43cea_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_43cea_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_43cea_row0_col1" class="data row0 col1" >0.8828</td>
#       <td id="T_43cea_row0_col2" class="data row0 col2" >1.2624</td>
#       <td id="T_43cea_row0_col3" class="data row0 col3" >1.0842</td>
#       <td id="T_43cea_row0_col4" class="data row0 col4" >0.4771</td>
#       <td id="T_43cea_row0_col5" class="data row0 col5" >0.0588</td>
#       <td id="T_43cea_row0_col6" class="data row0 col6" >0.0502</td>
#       <td id="T_43cea_row0_col7" class="data row0 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_43cea_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_43cea_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_43cea_row1_col1" class="data row1 col1" >1.0116</td>
#       <td id="T_43cea_row1_col2" class="data row1 col2" >1.6934</td>
#       <td id="T_43cea_row1_col3" class="data row1 col3" >1.1997</td>
#       <td id="T_43cea_row1_col4" class="data row1 col4" >0.4311</td>
#       <td id="T_43cea_row1_col5" class="data row1 col5" >0.0651</td>
#       <td id="T_43cea_row1_col6" class="data row1 col6" >0.0576</td>
#       <td id="T_43cea_row1_col7" class="data row1 col7" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_43cea_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_43cea_row2_col0" class="data row2 col0" >Voting Regressor</td>
#       <td id="T_43cea_row2_col1" class="data row2 col1" >0.9228</td>
#       <td id="T_43cea_row2_col2" class="data row2 col2" >1.4447</td>
#       <td id="T_43cea_row2_col3" class="data row2 col3" >1.1331</td>
#       <td id="T_43cea_row2_col4" class="data row2 col4" >0.4296</td>
#       <td id="T_43cea_row2_col5" class="data row2 col5" >0.0611</td>
#       <td id="T_43cea_row2_col6" class="data row2 col6" >0.0522</td>
#       <td id="T_43cea_row2_col7" class="data row2 col7" >0.2580</td>
#     </tr>
#     <tr>
#       <th id="T_43cea_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_43cea_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_43cea_row3_col1" class="data row3 col1" >0.8567</td>
#       <td id="T_43cea_row3_col2" class="data row3 col2" >1.3647</td>
#       <td id="T_43cea_row3_col3" class="data row3 col3" >1.1168</td>
#       <td id="T_43cea_row3_col4" class="data row3 col4" >0.4070</td>
#       <td id="T_43cea_row3_col5" class="data row3 col5" >0.0604</td>
#       <td id="T_43cea_row3_col6" class="data row3 col6" >0.0484</td>
#       <td id="T_43cea_row3_col7" class="data row3 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_43cea_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_43cea_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_43cea_row4_col1" class="data row4 col1" >1.0155</td>
#       <td id="T_43cea_row4_col2" class="data row4 col2" >1.6800</td>
#       <td id="T_43cea_row4_col3" class="data row4 col3" >1.2449</td>
#       <td id="T_43cea_row4_col4" class="data row4 col4" >0.3616</td>
#       <td id="T_43cea_row4_col5" class="data row4 col5" >0.0673</td>
#       <td id="T_43cea_row4_col6" class="data row4 col6" >0.0578</td>
#       <td id="T_43cea_row4_col7" class="data row4 col7" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_43cea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43cea_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_43cea_row5_col1" class="data row5 col1" >0.9916</td>
#       <td id="T_43cea_row5_col2" class="data row5 col2" >1.6915</td>
#       <td id="T_43cea_row5_col3" class="data row5 col3" >1.2273</td>
#       <td id="T_43cea_row5_col4" class="data row5 col4" >0.3282</td>
#       <td id="T_43cea_row5_col5" class="data row5 col5" >0.0660</td>
#       <td id="T_43cea_row5_col6" class="data row5 col6" >0.0558</td>
#       <td id="T_43cea_row5_col7" class="data row5 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_43cea_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_43cea_row6_col0" class="data row6 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_43cea_row6_col1" class="data row6 col1" >1.0259</td>
#       <td id="T_43cea_row6_col2" class="data row6 col2" >1.7223</td>
#       <td id="T_43cea_row6_col3" class="data row6 col3" >1.2437</td>
#       <td id="T_43cea_row6_col4" class="data row6 col4" >0.2809</td>
#       <td id="T_43cea_row6_col5" class="data row6 col5" >0.0681</td>
#       <td id="T_43cea_row6_col6" class="data row6 col6" >0.0591</td>
#       <td id="T_43cea_row6_col7" class="data row6 col7" >0.0360</td>
#     </tr>
#   </tbody>
# </table>

# %%
for model_name, model in models.items():
    print(f"\n{'-'*30}")
    print(f"正在分析模型: {model_name.upper()}")
    print(f"{'-'*30}")
    
    # SHAP值解释（需要安装shap包）
    try:
        interpret_model(model)
        plot_model(model, plot = 'feature')
    except:
        print(f"{model_name} 不支持SHAP分析")
# Out:
# ------------------------------
# 正在分析模型: LIGHTGBM
# ------------------------------
# ------------------------------
# 正在分析模型: RF
# ------------------------------
# ------------------------------
# 正在分析模型: CATBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: GBR
# ------------------------------
# gbr 不支持SHAP分析
#
# ------------------------------
# 正在分析模型: XGBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: ET
# ------------------------------
# ------------------------------
# 正在分析模型: BLEND
# ------------------------------
# blend 不支持SHAP分析

# %%
# 定义需要包含的模型简称集合
include_models = {'lightgbm','catboost'}

# 生成过滤后的有序字典
seleced_model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}
# 集成
seleced_models = ensemble(seleced_model_dict)
# Out:
# <style type="text/css">
# #T_db247_row5_col0, #T_db247_row5_col1, #T_db247_row5_col2, #T_db247_row5_col3, #T_db247_row5_col4, #T_db247_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_db247">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db247_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_db247_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_db247_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_db247_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_db247_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_db247_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db247_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db247_row0_col0" class="data row0 col0" >0.9442</td>
#       <td id="T_db247_row0_col1" class="data row0 col1" >1.2216</td>
#       <td id="T_db247_row0_col2" class="data row0 col2" >1.1053</td>
#       <td id="T_db247_row0_col3" class="data row0 col3" >0.5320</td>
#       <td id="T_db247_row0_col4" class="data row0 col4" >0.0614</td>
#       <td id="T_db247_row0_col5" class="data row0 col5" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_db247_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db247_row1_col0" class="data row1 col0" >1.0377</td>
#       <td id="T_db247_row1_col1" class="data row1 col1" >1.6989</td>
#       <td id="T_db247_row1_col2" class="data row1 col2" >1.3034</td>
#       <td id="T_db247_row1_col3" class="data row1 col3" >-0.8126</td>
#       <td id="T_db247_row1_col4" class="data row1 col4" >0.0745</td>
#       <td id="T_db247_row1_col5" class="data row1 col5" >0.0609</td>
#     </tr>
#     <tr>
#       <th id="T_db247_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db247_row2_col0" class="data row2 col0" >0.7635</td>
#       <td id="T_db247_row2_col1" class="data row2 col1" >0.9356</td>
#       <td id="T_db247_row2_col2" class="data row2 col2" >0.9673</td>
#       <td id="T_db247_row2_col3" class="data row2 col3" >0.7702</td>
#       <td id="T_db247_row2_col4" class="data row2 col4" >0.0562</td>
#       <td id="T_db247_row2_col5" class="data row2 col5" >0.0482</td>
#     </tr>
#     <tr>
#       <th id="T_db247_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db247_row3_col0" class="data row3 col0" >0.5421</td>
#       <td id="T_db247_row3_col1" class="data row3 col1" >0.4042</td>
#       <td id="T_db247_row3_col2" class="data row3 col2" >0.6357</td>
#       <td id="T_db247_row3_col3" class="data row3 col3" >0.8878</td>
#       <td id="T_db247_row3_col4" class="data row3 col4" >0.0359</td>
#       <td id="T_db247_row3_col5" class="data row3 col5" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_db247_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db247_row4_col0" class="data row4 col0" >1.7473</td>
#       <td id="T_db247_row4_col1" class="data row4 col1" >4.0110</td>
#       <td id="T_db247_row4_col2" class="data row4 col2" >2.0028</td>
#       <td id="T_db247_row4_col3" class="data row4 col3" >0.4944</td>
#       <td id="T_db247_row4_col4" class="data row4 col4" >0.0994</td>
#       <td id="T_db247_row4_col5" class="data row4 col5" >0.0901</td>
#     </tr>
#     <tr>
#       <th id="T_db247_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_db247_row5_col0" class="data row5 col0" >1.0070</td>
#       <td id="T_db247_row5_col1" class="data row5 col1" >1.6543</td>
#       <td id="T_db247_row5_col2" class="data row5 col2" >1.2029</td>
#       <td id="T_db247_row5_col3" class="data row5 col3" >0.3744</td>
#       <td id="T_db247_row5_col4" class="data row5 col4" >0.0655</td>
#       <td id="T_db247_row5_col5" class="data row5 col5" >0.0576</td>
#     </tr>
#     <tr>
#       <th id="T_db247_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_db247_row6_col0" class="data row6 col0" >0.4070</td>
#       <td id="T_db247_row6_col1" class="data row6 col1" >1.2508</td>
#       <td id="T_db247_row6_col2" class="data row6 col2" >0.4553</td>
#       <td id="T_db247_row6_col3" class="data row6 col3" >0.6113</td>
#       <td id="T_db247_row6_col4" class="data row6 col4" >0.0210</td>
#       <td id="T_db247_row6_col5" class="data row6 col5" >0.0190</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_32ae7 th {
#   text-align: left;
# }
# #T_32ae7_row0_col0, #T_32ae7_row0_col1, #T_32ae7_row0_col2, #T_32ae7_row1_col0, #T_32ae7_row1_col3, #T_32ae7_row1_col4, #T_32ae7_row1_col5, #T_32ae7_row2_col0, #T_32ae7_row2_col1, #T_32ae7_row2_col2, #T_32ae7_row2_col3, #T_32ae7_row2_col4, #T_32ae7_row2_col5, #T_32ae7_row2_col6 {
#   text-align: left;
# }
# #T_32ae7_row0_col3, #T_32ae7_row0_col4, #T_32ae7_row0_col5, #T_32ae7_row0_col6, #T_32ae7_row1_col1, #T_32ae7_row1_col2, #T_32ae7_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_32ae7_row0_col7, #T_32ae7_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_32ae7_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_32ae7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32ae7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_32ae7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_32ae7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_32ae7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_32ae7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_32ae7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_32ae7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_32ae7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32ae7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_32ae7_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_32ae7_row0_col1" class="data row0 col1" >1.0116</td>
#       <td id="T_32ae7_row0_col2" class="data row0 col2" >1.6934</td>
#       <td id="T_32ae7_row0_col3" class="data row0 col3" >1.1997</td>
#       <td id="T_32ae7_row0_col4" class="data row0 col4" >0.4311</td>
#       <td id="T_32ae7_row0_col5" class="data row0 col5" >0.0651</td>
#       <td id="T_32ae7_row0_col6" class="data row0 col6" >0.0576</td>
#       <td id="T_32ae7_row0_col7" class="data row0 col7" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_32ae7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_32ae7_row1_col0" class="data row1 col0" >Voting Regressor</td>
#       <td id="T_32ae7_row1_col1" class="data row1 col1" >1.0070</td>
#       <td id="T_32ae7_row1_col2" class="data row1 col2" >1.6543</td>
#       <td id="T_32ae7_row1_col3" class="data row1 col3" >1.2029</td>
#       <td id="T_32ae7_row1_col4" class="data row1 col4" >0.3744</td>
#       <td id="T_32ae7_row1_col5" class="data row1 col5" >0.0655</td>
#       <td id="T_32ae7_row1_col6" class="data row1 col6" >0.0576</td>
#       <td id="T_32ae7_row1_col7" class="data row1 col7" >0.1280</td>
#     </tr>
#     <tr>
#       <th id="T_32ae7_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_32ae7_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_32ae7_row2_col1" class="data row2 col1" >1.0259</td>
#       <td id="T_32ae7_row2_col2" class="data row2 col2" >1.7223</td>
#       <td id="T_32ae7_row2_col3" class="data row2 col3" >1.2437</td>
#       <td id="T_32ae7_row2_col4" class="data row2 col4" >0.2809</td>
#       <td id="T_32ae7_row2_col5" class="data row2 col5" >0.0681</td>
#       <td id="T_32ae7_row2_col6" class="data row2 col6" >0.0591</td>
#       <td id="T_32ae7_row2_col7" class="data row2 col7" >0.0360</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_model = save_models(seleced_models)
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
