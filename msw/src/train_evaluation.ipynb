# %%
import sys
import os
current_dir = os.getcwd()  
project_root = os.path.dirname(current_dir)  
sys.path.insert(0, project_root) 
from pathlib import Path
import warnings
import pandas as pd
from pycaret.regression import *
from src.config.config import Config
from src.data.data_loader import DataLoader
from src.models.model_evaluator import ModelEvaluator

def train_models(train: pd.DataFrame,val: pd.DataFrame,target_column: str):
    """训练模型流程
    Args:
        data_path: 可选的数据文件路径
    """
    model_evaluator.setup_experiment(
        train_size=Config.MODEL_CONFIG['train_size'],
        train_data=train,
        val_data = val,
        target_column = target_column,
        categorical_features = Config.FEATURE_CONFIG['categorical_columns']
    )

    # 训练模型并返回最佳模型字典
    return model_evaluator.train_top_models(n_models=Config.MODEL_CONFIG['n_top_models'])

def tune(models: dict):
    """模型调优和集成"""
    # 对top模型进行调优
    tuned_models = model_evaluator.tune_models(models)

    return tuned_models

def ensemble(models: dict):
    """模型集成"""
    # 对top模型进行集成
    blended_model = model_evaluator.ensemble_models(models)

    return blended_model    
    # 模型
    
def save_models(models: dict):

    model_evaluator.saved_models(models)

# %%
# 示例用法
df = pd.read_csv(Path(Config.PATH_CONFIG['features_dir'])  / 'training_data.csv')
data_loader = DataLoader()
model_evaluator = ModelEvaluator()

# 划分数据集
train_data, val_data, country_test_data = data_loader.split_data_by_countries(
    df,
    train_size=Config.DATA_CONFIG['country_train_size'],
    val_size=Config.DATA_CONFIG['country_val_size'],
    random_state=Config.DATA_CONFIG['random_state']
)

train_data, time_test_data = data_loader.split_data_by_time(train_data,
    test_size=Config.DATA_CONFIG['time_test_size'])

# 数据分析
print('\n训练集统计信息:')
data_loader.analyze_datasets(train_data)
print('\n验证集统计信息:')
data_loader.analyze_datasets(val_data)
print('\n外部国家测试集统计信息:')
data_loader.analyze_datasets(country_test_data)
print('\n外部时间测试集统计信息:')
data_loader.analyze_datasets(time_test_data)
#合并验证集和外部国家测试集作为测试集
test_data = pd.concat([val_data, country_test_data])
print('\n合并，作为测试集统计信息:')
data_loader.analyze_datasets(test_data)
# Out:
# 训练集统计信息:
# 总数据条数: 1312
# 国家总数: 57
# 包含的国家: Albania, Argentina, Austria, Bangladesh, Belgium, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, China, Colombia, Congo, Dem. Rep., Croatia, Cyprus, Czechia, Denmark, Estonia, Ethiopia, Greece, Hungary, Iceland, Indonesia, Iran, Islamic Rep., Iraq, Ireland, Italy, Japan, Korea, Rep., Latvia, Lithuania, Luxembourg, Malaysia, Malta, Mexico, Montenegro, Morocco, Netherlands, Nigeria, North Macedonia, Norway, Peru, Philippines, Poland, Romania, Russian Federation, Saudi Arabia, Serbia, Slovak Republic, Slovenia, South Africa, Spain, Sweden, Switzerland, Tanzania, Turkiye, Uganda, United Kingdom
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:30 | 1991.0:30 | 1992.0:30 | 1993.0:30 | 1994.0:30 | 1995.0:51 | 1996.0:51 | 1997.0:52 | 1998.0:51 | 1999.0:51 | 2000.0:52 | 2001.0:51 | 2002.0:51 | 2003.0:51 | 2004.0:52 | 2005.0:52 | 2006.0:53 | 2007.0:53 | 2008.0:55 | 2009.0:55 | 2010.0:54 | 2011.0:56 | 2012.0:56 | 2013.0:56 | 2014.0:57 | 2015.0:33 | 2016.0:33 | 2017.0:22 | 2018.0:6 | 2019.0:5 | 2020.0:3
#
# 验证集统计信息:
# 总数据条数: 185
# 国家总数: 6
# 包含的国家: Egypt, Arab Rep., Finland, France, India, Thailand, Ukraine
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:5 | 1991.0:5 | 1992.0:5 | 1993.0:5 | 1994.0:5 | 1995.0:6 | 1996.0:6 | 1997.0:6 | 1998.0:6 | 1999.0:6 | 2000.0:6 | 2001.0:6 | 2002.0:6 | 2003.0:6 | 2004.0:6 | 2005.0:6 | 2006.0:6 | 2007.0:6 | 2008.0:6 | 2009.0:6 | 2010.0:6 | 2011.0:6 | 2012.0:6 | 2013.0:6 | 2014.0:6 | 2015.0:6 | 2016.0:6 | 2017.0:6 | 2018.0:6 | 2019.0:6 | 2020.0:6 | 2021.0:2 | 2022.0:2
#
# 外部国家测试集统计信息:
# 总数据条数: 185
# 国家总数: 6
# 包含的国家: Algeria, Australia, Germany, Pakistan, Portugal, United States
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:5 | 1991.0:5 | 1992.0:5 | 1993.0:5 | 1994.0:5 | 1995.0:6 | 1996.0:6 | 1997.0:6 | 1998.0:6 | 1999.0:6 | 2000.0:6 | 2001.0:6 | 2002.0:6 | 2003.0:6 | 2004.0:6 | 2005.0:6 | 2006.0:6 | 2007.0:6 | 2008.0:6 | 2009.0:6 | 2010.0:6 | 2011.0:6 | 2012.0:6 | 2013.0:6 | 2014.0:6 | 2015.0:6 | 2016.0:6 | 2017.0:6 | 2018.0:6 | 2019.0:6 | 2020.0:6 | 2021.0:2 | 2022.0:2
#
# 外部时间测试集统计信息:
# 总数据条数: 300
# 国家总数: 57
# 包含的国家: Albania, Argentina, Austria, Bangladesh, Belgium, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, China, Colombia, Congo, Dem. Rep., Croatia, Cyprus, Czechia, Denmark, Estonia, Ethiopia, Greece, Hungary, Iceland, Indonesia, Iran, Islamic Rep., Iraq, Ireland, Italy, Japan, Korea, Rep., Latvia, Lithuania, Luxembourg, Malaysia, Malta, Mexico, Montenegro, Morocco, Netherlands, Nigeria, North Macedonia, Norway, Peru, Philippines, Poland, Romania, Russian Federation, Saudi Arabia, Serbia, Slovak Republic, Slovenia, South Africa, Spain, Sweden, Switzerland, Tanzania, Turkiye, Uganda, United Kingdom
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 2015.0:23 | 2016.0:23 | 2017.0:34 | 2018.0:51 | 2019.0:51 | 2020.0:54 | 2021.0:33 | 2022.0:31
#
# 合并，作为测试集统计信息:
# 总数据条数: 370
# 国家总数: 12
# 包含的国家: Algeria, Australia, Egypt, Arab Rep., Finland, France, Germany, India, Pakistan, Portugal, Thailand, Ukraine, United States
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:10 | 1991.0:10 | 1992.0:10 | 1993.0:10 | 1994.0:10 | 1995.0:12 | 1996.0:12 | 1997.0:12 | 1998.0:12 | 1999.0:12 | 2000.0:12 | 2001.0:12 | 2002.0:12 | 2003.0:12 | 2004.0:12 | 2005.0:12 | 2006.0:12 | 2007.0:12 | 2008.0:12 | 2009.0:12 | 2010.0:12 | 2011.0:12 | 2012.0:12 | 2013.0:12 | 2014.0:12 | 2015.0:12 | 2016.0:12 | 2017.0:12 | 2018.0:12 | 2019.0:12 | 2020.0:12 | 2021.0:4 | 2022.0:4

# %%
train_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'train.csv'), index=False)
test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'test.csv'), index=False)
time_test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'time_test_data.csv'), index=False)

# 排除不需要的列
feature_cols = [col for col in train_data.columns 
                if col not in [Config.DATA_CONFIG['target_column'], 'Country Name', 'Year','Region', 'Income Group']]

train = train_data[feature_cols]
test = test_data[feature_cols]
time_test_data = time_test_data[feature_cols] 

target_column = Config.DATA_CONFIG['target_column']
method = Config.FEATURE_CONFIG['target_transform_method']
transformed_column = f'{target_column}_{method}'

# %%
# 训练模型
models = train_models(train,test,transformed_column)
# Out:
# <style type="text/css">
# #T_d49b8_row8_col1, #T_d49b8_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d49b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d49b8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d49b8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d49b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d49b8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d49b8_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d49b8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d49b8_row1_col1" class="data row1 col1" >MSW_log</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d49b8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d49b8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d49b8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d49b8_row3_col1" class="data row3 col1" >(1682, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d49b8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d49b8_row4_col1" class="data row4 col1" >(1682, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d49b8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d49b8_row5_col1" class="data row5 col1" >(1312, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d49b8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d49b8_row6_col1" class="data row6 col1" >(370, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d49b8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d49b8_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d49b8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d49b8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d49b8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d49b8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d49b8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d49b8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d49b8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d49b8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d49b8_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_d49b8_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d49b8_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_d49b8_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d49b8_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_d49b8_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d49b8_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_d49b8_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d49b8_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_d49b8_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d49b8_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_d49b8_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d49b8_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_d49b8_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d49b8_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_d49b8_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d49b8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d49b8_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_d49b8_row20_col1" class="data row20 col1" >dc17</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a5e64 th {
#   text-align: left;
# }
# #T_a5e64_row0_col0, #T_a5e64_row0_col1, #T_a5e64_row0_col6, #T_a5e64_row1_col0, #T_a5e64_row1_col2, #T_a5e64_row1_col3, #T_a5e64_row1_col4, #T_a5e64_row1_col5, #T_a5e64_row2_col0, #T_a5e64_row2_col1, #T_a5e64_row2_col2, #T_a5e64_row2_col3, #T_a5e64_row2_col4, #T_a5e64_row2_col5, #T_a5e64_row2_col6, #T_a5e64_row3_col0, #T_a5e64_row3_col1, #T_a5e64_row3_col2, #T_a5e64_row3_col3, #T_a5e64_row3_col4, #T_a5e64_row3_col5, #T_a5e64_row3_col6, #T_a5e64_row4_col0, #T_a5e64_row4_col1, #T_a5e64_row4_col2, #T_a5e64_row4_col3, #T_a5e64_row4_col4, #T_a5e64_row4_col5, #T_a5e64_row4_col6, #T_a5e64_row5_col0, #T_a5e64_row5_col1, #T_a5e64_row5_col2, #T_a5e64_row5_col3, #T_a5e64_row5_col4, #T_a5e64_row5_col5, #T_a5e64_row5_col6, #T_a5e64_row6_col0, #T_a5e64_row6_col1, #T_a5e64_row6_col2, #T_a5e64_row6_col3, #T_a5e64_row6_col4, #T_a5e64_row6_col5, #T_a5e64_row6_col6, #T_a5e64_row7_col0, #T_a5e64_row7_col1, #T_a5e64_row7_col2, #T_a5e64_row7_col3, #T_a5e64_row7_col4, #T_a5e64_row7_col5, #T_a5e64_row7_col6, #T_a5e64_row8_col0, #T_a5e64_row8_col1, #T_a5e64_row8_col2, #T_a5e64_row8_col3, #T_a5e64_row8_col4, #T_a5e64_row8_col5, #T_a5e64_row8_col6, #T_a5e64_row9_col0, #T_a5e64_row9_col1, #T_a5e64_row9_col2, #T_a5e64_row9_col3, #T_a5e64_row9_col4, #T_a5e64_row9_col5, #T_a5e64_row9_col6, #T_a5e64_row10_col0, #T_a5e64_row10_col1, #T_a5e64_row10_col2, #T_a5e64_row10_col3, #T_a5e64_row10_col4, #T_a5e64_row10_col5, #T_a5e64_row10_col6, #T_a5e64_row11_col0, #T_a5e64_row11_col1, #T_a5e64_row11_col2, #T_a5e64_row11_col3, #T_a5e64_row11_col4, #T_a5e64_row11_col5, #T_a5e64_row11_col6, #T_a5e64_row12_col0, #T_a5e64_row12_col1, #T_a5e64_row12_col2, #T_a5e64_row12_col3, #T_a5e64_row12_col4, #T_a5e64_row12_col5, #T_a5e64_row12_col6, #T_a5e64_row13_col0, #T_a5e64_row13_col1, #T_a5e64_row13_col2, #T_a5e64_row13_col3, #T_a5e64_row13_col4, #T_a5e64_row13_col5, #T_a5e64_row13_col6, #T_a5e64_row14_col0, #T_a5e64_row14_col1, #T_a5e64_row14_col2, #T_a5e64_row14_col3, #T_a5e64_row14_col4, #T_a5e64_row14_col5, #T_a5e64_row14_col6, #T_a5e64_row15_col0, #T_a5e64_row15_col1, #T_a5e64_row15_col2, #T_a5e64_row15_col3, #T_a5e64_row15_col4, #T_a5e64_row15_col5, #T_a5e64_row15_col6, #T_a5e64_row16_col0, #T_a5e64_row16_col1, #T_a5e64_row16_col2, #T_a5e64_row16_col3, #T_a5e64_row16_col4, #T_a5e64_row16_col5, #T_a5e64_row16_col6, #T_a5e64_row17_col0, #T_a5e64_row17_col1, #T_a5e64_row17_col2, #T_a5e64_row17_col3, #T_a5e64_row17_col4, #T_a5e64_row17_col5, #T_a5e64_row17_col6, #T_a5e64_row18_col0, #T_a5e64_row18_col1, #T_a5e64_row18_col2, #T_a5e64_row18_col3, #T_a5e64_row18_col4, #T_a5e64_row18_col5, #T_a5e64_row18_col6, #T_a5e64_row19_col0, #T_a5e64_row19_col1, #T_a5e64_row19_col2, #T_a5e64_row19_col3, #T_a5e64_row19_col4, #T_a5e64_row19_col5, #T_a5e64_row19_col6 {
#   text-align: left;
# }
# #T_a5e64_row0_col2, #T_a5e64_row0_col3, #T_a5e64_row0_col4, #T_a5e64_row0_col5, #T_a5e64_row1_col1, #T_a5e64_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a5e64_row0_col7, #T_a5e64_row1_col7, #T_a5e64_row2_col7, #T_a5e64_row3_col7, #T_a5e64_row4_col7, #T_a5e64_row5_col7, #T_a5e64_row6_col7, #T_a5e64_row7_col7, #T_a5e64_row8_col7, #T_a5e64_row9_col7, #T_a5e64_row10_col7, #T_a5e64_row11_col7, #T_a5e64_row12_col7, #T_a5e64_row13_col7, #T_a5e64_row15_col7, #T_a5e64_row16_col7, #T_a5e64_row17_col7, #T_a5e64_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a5e64_row14_col7, #T_a5e64_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a5e64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5e64_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a5e64_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a5e64_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a5e64_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a5e64_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a5e64_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a5e64_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a5e64_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5e64_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_a5e64_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a5e64_row0_col1" class="data row0 col1" >0.4122</td>
#       <td id="T_a5e64_row0_col2" class="data row0 col2" >0.2755</td>
#       <td id="T_a5e64_row0_col3" class="data row0 col3" >0.5022</td>
#       <td id="T_a5e64_row0_col4" class="data row0 col4" >0.8646</td>
#       <td id="T_a5e64_row0_col5" class="data row0 col5" >0.0299</td>
#       <td id="T_a5e64_row0_col6" class="data row0 col6" >0.0261</td>
#       <td id="T_a5e64_row0_col7" class="data row0 col7" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_a5e64_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_a5e64_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_a5e64_row1_col1" class="data row1 col1" >0.4053</td>
#       <td id="T_a5e64_row1_col2" class="data row1 col2" >0.3001</td>
#       <td id="T_a5e64_row1_col3" class="data row1 col3" >0.5068</td>
#       <td id="T_a5e64_row1_col4" class="data row1 col4" >0.8637</td>
#       <td id="T_a5e64_row1_col5" class="data row1 col5" >0.0301</td>
#       <td id="T_a5e64_row1_col6" class="data row1 col6" >0.0255</td>
#       <td id="T_a5e64_row1_col7" class="data row1 col7" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_a5e64_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_a5e64_row2_col0" class="data row2 col0" >AdaBoost Regressor</td>
#       <td id="T_a5e64_row2_col1" class="data row2 col1" >0.4367</td>
#       <td id="T_a5e64_row2_col2" class="data row2 col2" >0.3204</td>
#       <td id="T_a5e64_row2_col3" class="data row2 col3" >0.5256</td>
#       <td id="T_a5e64_row2_col4" class="data row2 col4" >0.8513</td>
#       <td id="T_a5e64_row2_col5" class="data row2 col5" >0.0310</td>
#       <td id="T_a5e64_row2_col6" class="data row2 col6" >0.0274</td>
#       <td id="T_a5e64_row2_col7" class="data row2 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_a5e64_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_a5e64_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a5e64_row3_col1" class="data row3 col1" >0.4419</td>
#       <td id="T_a5e64_row3_col2" class="data row3 col2" >0.3262</td>
#       <td id="T_a5e64_row3_col3" class="data row3 col3" >0.5464</td>
#       <td id="T_a5e64_row3_col4" class="data row3 col4" >0.8396</td>
#       <td id="T_a5e64_row3_col5" class="data row3 col5" >0.0324</td>
#       <td id="T_a5e64_row3_col6" class="data row3 col6" >0.0278</td>
#       <td id="T_a5e64_row3_col7" class="data row3 col7" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_a5e64_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_a5e64_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a5e64_row4_col1" class="data row4 col1" >0.4504</td>
#       <td id="T_a5e64_row4_col2" class="data row4 col2" >0.3220</td>
#       <td id="T_a5e64_row4_col3" class="data row4 col3" >0.5567</td>
#       <td id="T_a5e64_row4_col4" class="data row4 col4" >0.8337</td>
#       <td id="T_a5e64_row4_col5" class="data row4 col5" >0.0332</td>
#       <td id="T_a5e64_row4_col6" class="data row4 col6" >0.0286</td>
#       <td id="T_a5e64_row4_col7" class="data row4 col7" >0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_a5e64_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_a5e64_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_a5e64_row5_col1" class="data row5 col1" >0.4572</td>
#       <td id="T_a5e64_row5_col2" class="data row5 col2" >0.3748</td>
#       <td id="T_a5e64_row5_col3" class="data row5

# %%
# 定义需要包含的模型简称集合
include_models = {'rf','xgboost','et','lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}

# %%
print(f'当前调优模型: {", ".join(model_dict.keys())}')

# 调优
tune_models = tune(model_dict)
# Out:
# 当前调优模型: gbr, et, lightgbm, xgboost, catboost, rf
# 当前调优模型: gbr , 结果如下:
# <style type="text/css">
# #T_0cb4a_row5_col0, #T_0cb4a_row5_col1, #T_0cb4a_row5_col2, #T_0cb4a_row5_col3, #T_0cb4a_row5_col4, #T_0cb4a_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0cb4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cb4a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0cb4a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0cb4a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0cb4a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0cb4a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0cb4a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cb4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cb4a_row0_col0" class="data row0 col0" >0.3743</td>
#       <td id="T_0cb4a_row0_col1" class="data row0 col1" >0.2179</td>
#       <td id="T_0cb4a_row0_col2" class="data row0 col2" >0.4668</td>
#       <td id="T_0cb4a_row0_col3" class="data row0 col3" >0.8011</td>
#       <td id="T_0cb4a_row0_col4" class="data row0 col4" >0.0303</td>
#       <td id="T_0cb4a_row0_col5" class="data row0 col5" >0.0254</td>
#     </tr>
#     <tr>
#       <th id="T_0cb4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cb4a_row1_col0" class="data row1 col0" >0.5188</td>
#       <td id="T_0cb4a_row1_col1" class="data row1 col1" >0.3968</td>
#       <td id="T_0cb4a_row1_col2" class="data row1 col2" >0.6299</td>
#       <td id="T_0cb4a_row1_col3" class="data row1 col3" >0.8281</td>
#       <td id="T_0cb4a_row1_col4" class="data row1 col4" >0.0357</td>
#       <td id="T_0cb4a_row1_col5" class="data row1 col5" >0.0312</td>
#     </tr>
#     <tr>
#       <th id="T_0cb4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cb4a_row2_col0" class="data row2 col0" >0.5098</td>
#       <td id="T_0cb4a_row2_col1" class="data row2 col1" >0.3442</td>
#       <td id="T_0cb4a_row2_col2" class="data row2 col2" >0.5866</td>
#       <td id="T_0cb4a_row2_col3" class="data row2 col3" >0.8761</td>
#       <td id="T_0cb4a_row2_col4" class="data row2 col4" >0.0347</td>
#       <td id="T_0cb4a_row2_col5" class="data row2 col5" >0.0321</td>
#     </tr>
#     <tr>
#       <th id="T_0cb4a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cb4a_row3_col0" class="data row3 col0" >0.1912</td>
#       <td id="T_0cb4a_row3_col1" class="data row3 col1" >0.0525</td>
#       <td id="T_0cb4a_row3_col2" class="data row3 col2" >0.2292</td>
#       <td id="T_0cb4a_row3_col3" class="data row3 col3" >0.9709</td>
#       <td id="T_0cb4a_row3_col4" class="data row3 col4" >0.0144</td>
#       <td id="T_0cb4a_row3_col5" class="data row3 col5" >0.0127</td>
#     </tr>
#     <tr>
#       <th id="T_0cb4a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cb4a_row4_col0" class="data row4 col0" >0.4269</td>
#       <td id="T_0cb4a_row4_col1" class="data row4 col1" >0.3087</td>
#       <td id="T_0cb4a_row4_col2" class="data row4 col2" >0.5556</td>
#       <td id="T_0cb4a_row4_col3" class="data row4 col3" >0.8765</td>
#       <td id="T_0cb4a_row4_col4" class="data row4 col4" >0.0327</td>
#       <td id="T_0cb4a_row4_col5" class="data row4 col5" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_0cb4a_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_0cb4a_row5_col0" class="data row5 col0" >0.4042</td>
#       <td id="T_0cb4a_row5_col1" class="data row5 col1" >0.2640</td>
#       <td id="T_0cb4a_row5_col2" class="data row5 col2" >0.4936</td>
#       <td id="T_0cb4a_row5_col3" class="data row5 col3" >0.8706</td>
#       <td id="T_0cb4a_row5_col4" class="data row5 col4" >0.0296</td>
#       <td id="T_0cb4a_row5_col5" class="data row5 col5" >0.0257</td>
#     </tr>
#     <tr>
#       <th id="T_0cb4a_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_0cb4a_row6_col0" class="data row6 col0" >0.1192</td>
#       <td id="T_0cb4a_row6_col1" class="data row6 col1" >0.1208</td>
#       <td id="T_0cb4a_row6_col2" class="data row6 col2" >0.1426</td>
#       <td id="T_0cb4a_row6_col3" class="data row6 col3" >0.0579</td>
#       <td id="T_0cb4a_row6_col4" class="data row6 col4" >0.0078</td>
#       <td id="T_0cb4a_row6_col5" class="data row6 col5" >0.0069</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ff0fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff0fe_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff0fe_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff0fe_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff0fe_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff0fe_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff0fe_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff0fe_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff0fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff0fe_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ff0fe_row0_col1" class="data row0 col1" >0.3766</td>
#       <td id="T_ff0fe_row0_col2" class="data row0 col2" >0.2960</td>
#       <td id="T_ff0fe_row0_col3" class="data row0 col3" >0.5440</td>
#       <td id="T_ff0fe_row0_col4" class="data row0 col4" >0.8111</td>
#       <td id="T_ff0fe_row0_col5" class="data row0 col5" >0.0287</td>
#       <td id="T_ff0fe_row0_col6" class="data row0 col6" >0.0211</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: et , 结果如下:
# <style type="text/css">
# #T_4f1d3_row5_col0, #T_4f1d3_row5_col1, #T_4f1d3_row5_col2, #T_4f1d3_row5_col3, #T_4f1d3_row5_col4, #T_4f1d3_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4f1d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f1d3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4f1d3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4f1d3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4f1d3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4f1d3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4f1d3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f1d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f1d3_row0_col0" class="data row0 col0" >0.3059</td>
#       <td id="T_4f1d3_row0_col1" class="data row0 col1" >0.1369</td>
#       <td id="T_4f1d3_row0_col2" class="data row0 col2" >0.3700</td>
#       <td id="T_4f1d3_row0_col3" class="data row0 col3" >0.8750</td>
#       <td id="T_4f1d3_row0_col4" class="data row0 col4" >0.0242</td>
#       <td id="T_4f1d3_row0_col5" class="data row0 col5" >0.0208</td>
#     </tr>
#     <tr>
#       <th id="T_4f1d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f1d3_row1_col0" class="data row1 col0" >0.6210</td>
#       <td id="T_4f1d3_row1_col1" class="data row1 col1" >0.5331</td>
#       <td id="T_4f1d3_row1_col2" class="data row1 col2" >0.7302</td>
#       <td id="T_4f1d3_row1_col3" class="data row1 col3" >0.7691</td>
#       <td id="T_4f1d3_row1_col4" class="data row1 col4" >0.0412</td>
#       <td id="T_4f1d3_row1_col5" class="data row1 col5" >0.0371</td>
#     </tr>
#     <tr>
#       <th id="T_4f1d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f1d3_row2_col0" class="data row2 col0" >0.5630</td>
#       <td id="T_4f1d3_row2_col1" class="data row2 col1" >0.4557</td>
#       <td id="T_4f1d3_row2_col2" class="data row2 col2" >0.6750</td>
#       <td id="T_4f1d3_row2_col3" class="data row2 col3" >0.8360</td>
#       <td id="T_4f1d3_row2_col4" class="data row2 col4" >0.0401</td>
#       <td id="T_4f1d3_row2_col5" class="data row2 col5" >0.0353</td>
#     </tr>
#     <tr>
#       <th id="T_4f1d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f1d3_row3_col0" class="data row3 col0" >0.1483</td>
#       <td id="T_4f1d3_row3_col1" class="data row3 col1" >0.0321</td>
#       <td id="T_4f1d3_row3_col2" class="data row3 col2" >0.1792</td>
#       <td id="T_4f1d3_row3_col3" class="data row3 col3" >0.9822</td>
#       <td id="T_4f1d3_row3_col4" class="data row3 col4" >0.0115</td>
#       <td id="T_4f1d3_row3_col5" class="data row3 col5" >0.0099</td>
#     </tr>
#     <tr>
#       <th id="T_4f1d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f1d3_row4_col0" class="data row4 col0" >0.3436</td>
#       <td id="T_4f1d3_row4_col1" class="data row4 col1" >0.2238</td>
#       <td id="T_4f1d3_row4_col2" class="data row4 col2" >0.4731</td>
#       <td id="T_4f1d3_row4_col3" class="data row4 col3" >0.9105</td>
#       <td id="T_4f1d3_row4_col4" class="data row4 col4" >0.0268</td>
#       <td id="T_4f1d3_row4_col5" class="data row4 col5" >0.0212</td>
#     </tr>
#     <tr>
#       <th id="T_4f1d3_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_4f1d3_row5_col0" class="data row5 col0" >0.3963</td>
#       <td id="T_4f1d3_row5_col1" class="data row5 col1" >0.2763</td>
#       <td id="T_4f1d3_row5_col2" class="data row5 col2" >0.4855</td>
#       <td id="T_4f1d3_row5_col3" class="data row5 col3" >0.8746</td>
#       <td id="T_4f1d3_row5_col4" class="data row5 col4" >0.0288</td>
#       <td id="T_4f1d3_row5_col5" class="data row5 col5" >0.0249</td>
#     </tr>
#     <tr>
#       <th id="T_4f1d3_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_4f1d3_row6_col0" class="data row6 col0" >0.1736</td>
#       <td id="T_4f1d3_row6_col1" class="data row6 col1" >0.1897</td>
#       <td id="T_4f1d3_row6_col2" class="data row6 col2" >0.2015</td>
#       <td id="T_4f1d3_row6_col3" class="data row6 col3" >0.0714</td>
#       <td id="T_4f1d3_row6_col4" class="data row6 col4" >0.0110</td>
#       <td id="T_4f1d3_row6_col5" class="data row6 col5" >0.0101</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_01f5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01f5f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_01f5f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_01f5f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_01f5f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_01f5f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_01f5f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_01f5f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01f5f_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_01f5f_row0_col1" class="data row0 col1" >0.4153</td>
#       <td id="T_01f5f_row0_col2" class="data row0 col2" >0.3805</td>
#       <td id="T_01f5f_row0_col3" class="data row0 col3" >0.6168</td>
#       <td id="T_01f5f_row0_col4" class="data row0 col4" >0.7572</td>
#       <td id="T_01f5f_row0_col5" class="data row0 col5" >0.0324</td>
#       <td id="T_01f5f_row0_col6" class="data row0 col6" >0.0231</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: lightgbm , 结果如下:
# <style type="text/css">
# #T_af6f8_row5_col0, #T_af6f8_row5_col1, #T_af6f8_row5_col2, #T_af6f8_row5_col3, #T_af6f8_row5_col4, #T_af6f8_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_af6f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af6f8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_af6f8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_af6f8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_af6f8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_af6f8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_af6f8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af6f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af6f8_row0_col0" class="data row0 col0" >0.4173</td>
#       <td id="T_af6f8_row0_col1" class="data row0 col1" >0.2334</td>
#       <td id="T_af6f8_row0_col2" class="data row0 col2" >0.4831</td>
#       <td id="T_af6f8_row0_col3" class="data row0 col3" >0.7870</td>
#       <td id="T_af6f8_row0_col4" class="data row0 col4" >0.0301</td>
#       <td id="T_af6f8_row0_col5" class="data row0 col5" >0.0274</td>
#     </tr>
#     <tr>
#       <th id="T_af6f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af6f8_row1_col0" class="data row1 col0" >0.5895</td>
#       <td id="T_af6f8_row1_col1" class="data row1 col1" >0.4734</td>
#       <td id="T_af6f8_row1_col2" class="data row1 col2" >0.6881</td>
#       <td id="T_af6f8_row1_col3" class="data row1 col3" >0.7950</td>
#       <td id="T_af6f8_row1_col4" class="data row1 col4" >0.0391</td>
#       <td id="T_af6f8_row1_col5" class="data row1 col5" >0.0356</td>
#     </tr>
#     <tr>
#       <th id="T_af6f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af6f8_row2_col0" class="data row2 col0" >0.5798</td>
#       <td id="T_af6f8_row2_col1" class="data row2 col1" >0.4444</td>
#       <td id="T_af6f8_row2_col2" class="data row2 col2" >0.6666</td>
#       <td id="T_af6f8_row2_col3" class="data row2 col3" >0.8400</td>
#       <td id="T_af6f8_row2_col4" class="data row2 col4" >0.0393</td>
#       <td id="T_af6f8_row2_col5" class="data row2 col5" >0.0365</td>
#     </tr>
#     <tr>
#       <th id="T_af6f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af6f8_row3_col0" class="data row3 col0" >0.2046</td>
#       <td id="T_af6f8_row3_col1" class="data row3 col1" >0.0706</td>
#       <td id="T_af6f8_row3_col2" class="data row3 col2" >0.2657</td>
#       <td id="T_af6f8_row3_col3" class="data row3 col3" >0.9609</td>
#       <td id="T_af6f8_row3_col4" class="data row3 col4" >0.0161</td>
#       <td id="T_af6f8_row3_col5" class="data row3 col5" >0.0134</td>
#     </tr>
#     <tr>
#       <th id="T_af6f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_af6f8_row4_col0" class="data row4 col0" >0.3679</td>
#       <td id="T_af6f8_row4_col1" class="data row4 col1" >0.2569</td>
#       <td id="T_af6f8_row4_col2" class="data row4 col2" >0.5068</td>
#       <td id="T_af6f8_row4_col3" class="data row4 col3" >0.8972</td>
#       <td id="T_af6f8_row4_col4" class="data row4 col4" >0.0299</td>
#       <td id="T_af6f8_row4_col5" class="data row4 col5" >0.0234</td>
#     </tr>
#     <tr>
#       <th id="T_af6f8_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_af6f8_row5_col0" class="data row5 col0" >0.4318</td>
#       <td id="T_af6f8_row5_col1" class="data row5 col1" >0.2957</td>
#       <td id="T_af6f8_row5_col2" class="data row5 col2" >0.5221</td>
#       <td id="T_af6f8_row5_col3" class="data row5 col3" >0.8560</td>
#       <td id="T_af6f8_row5_col4" class="data row5 col4" >0.0309</td>
#       <td id="T_af6f8_row5_col5" class="data row5 col5" >0.0273</td>
#     </tr>
#     <tr>
#       <th id="T_af6f8_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_af6f8_row6_col0" class="data row6 col0" >0.1433</td>
#       <td id="T_af6f8_row6_col1" class="data row6 col1" >0.1482</td>
#       <td id="T_af6f8_row6_col2" class="data row6 col2" >0.1523</td>
#       <td id="T_af6f8_row6_col3" class="data row6 col3" >0.0655</td>
#       <td id="T_af6f8_row6_col4" class="data row6 col4" >0.0085</td>
#       <td id="T_af6f8_row6_col5" class="data row6 col5" >0.0085</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.8312783918031971, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8312783918031971
# [LightGBM] [Warning] bagging_fraction is set=0.9911572192162996, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9911572192162996
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# <style type="text/css">
# </style>
# <table id="T_c30a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c30a6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c30a6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c30a6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c30a6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c30a6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c30a6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c30a6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c30a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c30a6_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c30a6_row0_col1" class="data row0 col1" >0.3801</td>
#       <td id="T_c30a6_row0_col2" class="data row0 col2" >0.2463</td>
#       <td id="T_c30a6_row0_col3" class="data row0 col3" >0.4962</td>
#       <td id="T_c30a6_row0_col4" class="data row0 col4" >0.8429</td>
#       <td id="T_c30a6_row0_col5" class="data row0 col5" >0.0269</td>
#       <td id="T_c30a6_row0_col6" class="data row0 col6" >0.0217</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.8312783918031971, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8312783918031971
# [LightGBM] [Warning] bagging_fraction is set=0.9911572192162996, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9911572192162996
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 当前调优模型: xgboost , 结果如下:
# <style type="text/css">
# #T_3b2f9_row5_col0, #T_3b2f9_row5_col1, #T_3b2f9_row5_col2, #T_3b2f9_row5_col3, #T_3b2f9_row5_col4, #T_3b2f9_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3b2f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b2f9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3b2f9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3b2f9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3b2f9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3b2f9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3b2f9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b2f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b2f9_row0_col0" class="data row0 col0" >0.4261</td>
#       <td id="T_3b2f9_row0_col1" class="data row0 col1" >0.2765</td>
#       <td id="T_3b2f9_row0_col2" class="data row0 col2" >0.5258</td>
#       <td id="T_3b2f9_row0_col3" class="data row0 col3" >0.7476</td>
#       <td id="T_3b2f9_row0_col4" class="data row0 col4" >0.0334</td>
#       <td id="T_3b2f9_row0_col5" class="data row0 col5" >0.0284</td>
#     </tr>
#     <tr>
#       <th id="T_3b2f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b2f9_row1_col0" class="data row1 col0" >0.5654</td>
#       <td id="T_3b2f9_row1_col1" class="data row1 col1" >0.4784</td>
#       <td id="T_3b2f9_row1_col2" class="data row1 col2" >0.6917</td>
#       <td id="T_3b2f9_row1_col3" class="data row1 col3" >0.7928</td>
#       <td id="T_3b2f9_row1_col4" class="data row1 col4" >0.0391</td>
#       <td id="T_3b2f9_row1_col5" class="data row1 col5" >0.0338</td>
#     </tr>
#     <tr>
#       <th id="T_3b2f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b2f9_row2_col0" class="data row2 col0" >0.5062</td>
#       <td id="T_3b2f9_row2_col1" class="data row2 col1" >0.3430</td>
#       <td id="T_3b2f9_row2_col2" class="data row2 col2" >0.5857</td>
#       <td id="T_3b2f9_row2_col3" class="data row2 col3" >0.8765</td>
#       <td id="T_3b2f9_row2_col4" class="data row2 col4" >0.0345</td>
#       <td id="T_3b2f9_row2_col5" class="data row2 col5" >0.0318</td>
#     </tr>
#     <tr>
#       <th id="T_3b2f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3b2f9_row3_col0" class="data row3 col0" >0.1759</td>
#       <td id="T_3b2f9_row3_col1" class="data row3 col1" >0.0441</td>
#       <td id="T_3b2f9_row3_col2" class="data row3 col2" >0.2100</td>
#       <td id="T_3b2f9_row3_col3" class="data row3 col3" >0.9756</td>
#       <td id="T_3b2f9_row3_col4" class="data row3 col4" >0.0129</td>
#       <td id="T_3b2f9_row3_col5" class="data row3 col5" >0.0116</td>
#     </tr>
#     <tr>
#       <th id="T_3b2f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3b2f9_row4_col0" class="data row4 col0" >0.4219</td>
#       <td id="T_3b2f9_row4_col1" class="data row4 col1" >0.2903</td>
#       <td id="T_3b2f9_row4_col2" class="data row4 col2" >0.5388</td>
#       <td id="T_3b2f9_row4_col3" class="data row4 col3" >0.8839</td>
#       <td id="T_3b2f9_row4_col4" class="data row4 col4" >0.0319</td>
#       <td id="T_3b2f9_row4_col5" class="data row4 col5" >0.0268</td>
#     </tr>
#     <tr>
#       <th id="T_3b2f9_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_3b2f9_row5_col0" class="data row5 col0" >0.4191</td>
#       <td id="T_3b2f9_row5_col1" class="data row5 col1" >0.2865</td>
#       <td id="T_3b2f9_row5_col2" class="data row5 col2" >0.5104</td>
#       <td id="T_3b2f9_row5_col3" class="data row5 col3" >0.8553</td>
#       <td id="T_3b2f9_row5_col4" class="data row5 col4" >0.0304</td>
#       <td id="T_3b2f9_row5_col5" class="data row5 col5" >0.0265</td>
#     </tr>
#     <tr>
#       <th id="T_3b2f9_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_3b2f9_row6_col0" class="data row6 col0" >0.1328</td>
#       <td id="T_3b2f9_row6_col1" class="data row6 col1" >0.1406</td>
#       <td id="T_3b2f9_row6_col2" class="data row6 col2" >0.1611</td>
#       <td id="T_3b2f9_row6_col3" class="data row6 col3" >0.0790</td>
#       <td id="T_3b2f9_row6_col4" class="data row6 col4" >0.0090</td>
#       <td id="T_3b2f9_row6_col5" class="data row6 col5" >0.0079</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c7c6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7c6c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c7c6c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c7c6c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c7c6c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c7c6c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c7c6c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c7c6c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7c6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7c6c_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c7c6c_row0_col1" class="data row0 col1" >0.4250</td>
#       <td id="T_c7c6c_row0_col2" class="data row0 col2" >0.3392</td>
#       <td id="T_c7c6c_row0_col3" class="data row0 col3" >0.5824</td>
#       <td id="T_c7c6c_row0_col4" class="data row0 col4" >0.7836</td>
#       <td id="T_c7c6c_row0_col5" class="data row0 col5" >0.0308</td>
#       <td id="T_c7c6c_row0_col6" class="data row0 col6" >0.0240</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: catboost , 结果如下:
# <style type="text/css">
# #T_918b0_row5_col0, #T_918b0_row5_col1, #T_918b0_row5_col2, #T_918b0_row5_col3, #T_918b0_row5_col4, #T_918b0_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_918b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_918b0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_918b0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_918b0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_918b0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_918b0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_918b0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_918b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_918b0_row0_col0" class="data row0 col0" >0.4139</td>
#       <td id="T_918b0_row0_col1" class="data row0 col1" >0.2475</td>
#       <td id="T_918b0_row0_col2" class="data row0 col2" >0.4975</td>
#       <td id="T_918b0_row0_col3" class="data row0 col3" >0.7741</td>
#       <td id="T_918b0_row0_col4" class="data row0 col4" >0.0323</td>
#       <td id="T_918b0_row0_col5" class="data row0 col5" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_918b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_918b0_row1_col0" class="data row1 col0" >0.5050</td>
#       <td id="T_918b0_row1_col1" class="data row1 col1" >0.3717</td>
#       <td id="T_918b0_row1_col2" class="data row1 col2" >0.6097</td>
#       <td id="T_918b0_row1_col3" class="data row1 col3" >0.8390</td>
#       <td id="T_918b0_row1_col4" class="data row1 col4" >0.0345</td>
#       <td id="T_918b0_row1_col5" class="data row1 col5" >0.0303</td>
#     </tr>
#     <tr>
#       <th id="T_918b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_918b0_row2_col0" class="data row2 col0" >0.6154</td>
#       <td id="T_918b0_row2_col1" class="data row2 col1" >0.5874</td>
#       <td id="T_918b0_row2_col2" class="data row2 col2" >0.7664</td>
#       <td id="T_918b0_row2_col3" class="data row2 col3" >0.7886</td>
#       <td id="T_918b0_row2_col4" class="data row2 col4" >0.0458</td>
#       <td id="T_918b0_row2_col5" class="data row2 col5" >0.0388</td>
#     </tr>
#     <tr>
#       <th id="T_918b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_918b0_row3_col0" class="data row3 col0" >0.1662</td>
#       <td id="T_918b0_row3_col1" class="data row3 col1" >0.0406</td>
#       <td id="T_918b0_row3_col2" class="data row3 col2" >0.2016</td>
#       <td id="T_918b0_row3_col3" class="data row3 col3" >0.9775</td>
#       <td id="T_918b0_row3_col4" class="data row3 col4" >0.0127</td>
#       <td id="T_918b0_row3_col5" class="data row3 col5" >0.0111</td>
#     </tr>
#     <tr>
#       <th id="T_918b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_918b0_row4_col0" class="data row4 col0" >0.4272</td>
#       <td id="T_918b0_row4_col1" class="data row4 col1" >0.3052</td>
#       <td id="T_918b0_row4_col2" class="data row4 col2" >0.5525</td>
#       <td id="T_918b0_row4_col3" class="data row4 col3" >0.8779</td>
#       <td id="T_918b0_row4_col4" class="data row4 col4" >0.0319</td>
#       <td id="T_918b0_row4_col5" class="data row4 col5" >0.0266</td>
#     </tr>
#     <tr>
#       <th id="T_918b0_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_918b0_row5_col0" class="data row5 col0" >0.4255</td>
#       <td id="T_918b0_row5_col1" class="data row5 col1" >0.3105</td>
#       <td id="T_918b0_row5_col2" class="data row5 col2" >0.5255</td>
#       <td id="T_918b0_row5_col3" class="data row5 col3" >0.8514</td>
#       <td id="T_918b0_row5_col4" class="data row5 col4" >0.0314</td>
#       <td id="T_918b0_row5_col5" class="data row5 col5" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_918b0_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_918b0_row6_col0" class="data row6 col0" >0.1482</td>
#       <td id="T_918b0_row6_col1" class="data row6 col1" >0.1773</td>
#       <td id="T_918b0_row6_col2" class="data row6 col2" >0.1852</td>
#       <td id="T_918b0_row6_col3" class="data row6 col3" >0.0730</td>
#       <td id="T_918b0_row6_col4" class="data row6 col4" >0.0107</td>
#       <td id="T_918b0_row6_col5" class="data row6 col5" >0.0090</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6388c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6388c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6388c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6388c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6388c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6388c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6388c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6388c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6388c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6388c_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_6388c_row0_col1" class="data row0 col1" >0.3606</td>
#       <td id="T_6388c_row0_col2" class="data row0 col2" >0.2723</td>
#       <td id="T_6388c_row0_col3" class="data row0 col3" >0.5219</td>
#       <td id="T_6388c_row0_col4" class="data row0 col4" >0.8262</td>
#       <td id="T_6388c_row0_col5" class="data row0 col5" >0.0275</td>
#       <td id="T_6388c_row0_col6" class="data row0 col6" >0.0202</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: rf , 结果如下:
# <style type="text/css">
# #T_a5491_row5_col0, #T_a5491_row5_col1, #T_a5491_row5_col2, #T_a5491_row5_col3, #T_a5491_row5_col4, #T_a5491_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a5491">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5491_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a5491_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a5491_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a5491_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a5491_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a5491_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5491_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5491_row0_col0" class="data row0 col0" >0.4458</td>
#       <td id="T_a5491_row0_col1" class="data row0 col1" >0.2746</td>
#       <td id="T_a5491_row0_col2" class="data row0 col2" >0.5241</td>
#       <td id="T_a5491_row0_col3" class="data row0 col3" >0.7493</td>
#       <td id="T_a5491_row0_col4" class="data row0 col4" >0.0337</td>
#       <td id="T_a5491_row0_col5" class="data row0 col5" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_a5491_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5491_row1_col0" class="data row1 col0" >0.5375</td>
#       <td id="T_a5491_row1_col1" class="data row1 col1" >0.4300</td>
#       <td id="T_a5491_row1_col2" class="data row1 col2" >0.6558</td>
#       <td id="T_a5491_row1_col3" class="data row1 col3" >0.8138</td>
#       <td id="T_a5491_row1_col4" class="data row1 col4" >0.0374</td>
#       <td id="T_a5491_row1_col5" class="data row1 col5" >0.0325</td>
#     </tr>
#     <tr>
#       <th id="T_a5491_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5491_row2_col0" class="data row2 col0" >0.5019</td>
#       <td id="T_a5491_row2_col1" class="data row2 col1" >0.3660</td>
#       <td id="T_a5491_row2_col2" class="data row2 col2" >0.6050</td>
#       <td id="T_a5491_row2_col3" class="data row2 col3" >0.8683</td>
#       <td id="T_a5491_row2_col4" class="data row2 col4" >0.0354</td>
#       <td id="T_a5491_row2_col5" class="data row2 col5" >0.0312</td>
#     </tr>
#     <tr>
#       <th id="T_a5491_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5491_row3_col0" class="data row3 col0" >0.2379</td>
#       <td id="T_a5491_row3_col1" class="data row3 col1" >0.0859</td>
#       <td id="T_a5491_row3_col2" class="data row3 col2" >0.2930</td>
#       <td id="T_a5491_row3_col3" class="data row3 col3" >0.9524</td>
#       <td id="T_a5491_row3_col4" class="data row3 col4" >0.0181</td>
#       <td id="T_a5491_row3_col5" class="data row3 col5" >0.0158</td>
#     </tr>
#     <tr>
#       <th id="T_a5491_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5491_row4_col0" class="data row4 col0" >0.3636</td>
#       <td id="T_a5491_row4_col1" class="data row4 col1" >0.2381</td>
#       <td id="T_a5491_row4_col2" class="data row4 col2" >0.4879</td>
#       <td id="T_a5491_row4_col3" class="data row4 col3" >0.9048</td>
#       <td id="T_a5491_row4_col4" class="data row4 col4" >0.0287</td>
#       <td id="T_a5491_row4_col5" class="data row4 col5" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_a5491_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_a5491_row5_col0" class="data row5 col0" >0.4173</td>
#       <td id="T_a5491_row5_col1" class="data row5 col1" >0.2789</td>
#       <td id="T_a5491_row5_col2" class="data row5 col2" >0.5132</td>
#       <td id="T_a5491_row5_col3" class="data row5 col3" >0.8577</td>
#       <td id="T_a5491_row5_col4" class="data row5 col4" >0.0307</td>
#       <td id="T_a5491_row5_col5" class="data row5 col5" >0.0265</td>
#     </tr>
#     <tr>
#       <th id="T_a5491_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_a5491_row6_col0" class="data row6 col0" >0.1072</td>
#       <td id="T_a5491_row6_col1" class="data row6 col1" >0.1178</td>
#       <td id="T_a5491_row6_col2" class="data row6 col2" >0.1249</td>
#       <td id="T_a5491_row6_col3" class="data row6 col3" >0.0707</td>
#       <td id="T_a5491_row6_col4" class="data row6 col4" >0.0069</td>
#       <td id="T_a5491_row6_col5" class="data row6 col5" >0.0063</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bb738">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb738_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bb738_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bb738_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bb738_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bb738_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bb738_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bb738_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb738_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb738_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_bb738_row0_col1" class="data row0 col1" >0.4466</td>
#       <td id="T_bb738_row0_col2" class="data row0 col2" >0.3455</td>
#       <td id="T_bb738_row0_col3" class="data row0 col3" >0.5878</td>
#       <td id="T_bb738_row0_col4" class="data row0 col4" >0.7796</td>
#       <td id="T_bb738_row0_col5" class="data row0 col5" >0.0316</td>
#       <td id="T_bb738_row0_col6" class="data row0 col6" >0.0254</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 集成
models = ensemble(tune_models)
# Out:
# <style type="text/css">
# #T_b58ef_row5_col0, #T_b58ef_row5_col1, #T_b58ef_row5_col2, #T_b58ef_row5_col3, #T_b58ef_row5_col4, #T_b58ef_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b58ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b58ef_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b58ef_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b58ef_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b58ef_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b58ef_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b58ef_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b58ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b58ef_row0_col0" class="data row0 col0" >0.3880</td>
#       <td id="T_b58ef_row0_col1" class="data row0 col1" >0.2010</td>
#       <td id="T_b58ef_row0_col2" class="data row0 col2" >0.4483</td>
#       <td id="T_b58ef_row0_col3" class="data row0 col3" >0.8165</td>
#       <td id="T_b58ef_row0_col4" class="data row0 col4" >0.0288</td>
#       <td id="T_b58ef_row0_col5" class="data row0 col5" >0.0261</td>
#     </tr>
#     <tr>
#       <th id="T_b58ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b58ef_row1_col0" class="data row1 col0" >0.5535</td>
#       <td id="T_b58ef_row1_col1" class="data row1 col1" >0.4403</td>
#       <td id="T_b58ef_row1_col2" class="data row1 col2" >0.6636</td>
#       <td id="T_b58ef_row1_col3" class="data row1 col3" >0.8093</td>
#       <td id="T_b58ef_row1_col4" class="data row1 col4" >0.0376</td>
#       <td id="T_b58ef_row1_col5" class="data row1 col5" >0.0332</td>
#     </tr>
#     <tr>
#       <th id="T_b58ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b58ef_row2_col0" class="data row2 col0" >0.5395</td>
#       <td id="T_b58ef_row2_col1" class="data row2 col1" >0.3968</td>
#       <td id="T_b58ef_row2_col2" class="data row2 col2" >0.6299</td>
#       <td id="T_b58ef_row2_col3" class="data row2 col3" >0.8572</td>
#       <td id="T_b58ef_row2_col4" class="data row2 col4" >0.0372</td>
#       <td id="T_b58ef_row2_col5" class="data row2 col5" >0.0339</td>
#     </tr>
#     <tr>
#       <th id="T_b58ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b58ef_row3_col0" class="data row3 col0" >0.1687</td>
#       <td id="T_b58ef_row3_col1" class="data row3 col1" >0.0404</td>
#       <td id="T_b58ef_row3_col2" class="data row3 col2" >0.2010</td>
#       <td id="T_b58ef_row3_col3" class="data row3 col3" >0.9776</td>
#       <td id="T_b58ef_row3_col4" class="data row3 col4" >0.0125</td>
#       <td id="T_b58ef_row3_col5" class="data row3 col5" >0.0112</td>
#     </tr>
#     <tr>
#       <th id="T_b58ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b58ef_row4_col0" class="data row4 col0" >0.3787</td>
#       <td id="T_b58ef_row4_col1" class="data row4 col1" >0.2583</td>
#       <td id="T_b58ef_row4_col2" class="data row4 col2" >0.5083</td>
#       <td id="T_b58ef_row4_col3" class="data row4 col3" >0.8967</td>
#       <td id="T_b58ef_row4_col4" class="data row4 col4" >0.0297</td>
#       <td id="T_b58ef_row4_col5" class="data row4 col5" >0.0239</td>
#     </tr>
#     <tr>
#       <th id="T_b58ef_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b58ef_row5_col0" class="data row5 col0" >0.4057</td>
#       <td id="T_b58ef_row5_col1" class="data row5 col1" >0.2674</td>
#       <td id="T_b58ef_row5_col2" class="data row5 col2" >0.4902</td>
#       <td id="T_b58ef_row5_col3" class="data row5 col3" >0.8715</td>
#       <td id="T_b58ef_row5_col4" class="data row5 col4" >0.0291</td>
#       <td id="T_b58ef_row5_col5" class="data row5 col5" >0.0256</td>
#     </tr>
#     <tr>
#       <th id="T_b58ef_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b58ef_row6_col0" class="data row6 col0" >0.1393</td>
#       <td id="T_b58ef_row6_col1" class="data row6 col1" >0.1433</td>
#       <td id="T_b58ef_row6_col2" class="data row6 col2" >0.1645</td>
#       <td id="T_b58ef_row6_col3" class="data row6 col3" >0.0616</td>
#       <td id="T_b58ef_row6_col4" class="data row6 col4" >0.0091</td>
#       <td id="T_b58ef_row6_col5" class="data row6 col5" >0.0082</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.8312783918031971, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8312783918031971
# [LightGBM] [Warning] bagging_fraction is set=0.9911572192162996, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9911572192162996
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# <style type="text/css">
# #T_d4c7f th {
#   text-align: left;
# }
# #T_d4c7f_row0_col0, #T_d4c7f_row0_col2, #T_d4c7f_row1_col0, #T_d4c7f_row1_col1, #T_d4c7f_row1_col2, #T_d4c7f_row1_col3, #T_d4c7f_row1_col4, #T_d4c7f_row1_col5, #T_d4c7f_row1_col6, #T_d4c7f_row2_col0, #T_d4c7f_row2_col1, #T_d4c7f_row2_col3, #T_d4c7f_row2_col4, #T_d4c7f_row2_col5, #T_d4c7f_row2_col6, #T_d4c7f_row3_col0, #T_d4c7f_row3_col1, #T_d4c7f_row3_col2, #T_d4c7f_row3_col3, #T_d4c7f_row3_col4, #T_d4c7f_row3_col5, #T_d4c7f_row3_col6, #T_d4c7f_row4_col0, #T_d4c7f_row4_col1, #T_d4c7f_row4_col2, #T_d4c7f_row4_col3, #T_d4c7f_row4_col4, #T_d4c7f_row4_col5, #T_d4c7f_row4_col6, #T_d4c7f_row5_col0, #T_d4c7f_row5_col1, #T_d4c7f_row5_col2, #T_d4c7f_row5_col3, #T_d4c7f_row5_col4, #T_d4c7f_row5_col5, #T_d4c7f_row5_col6, #T_d4c7f_row6_col0, #T_d4c7f_row6_col1, #T_d4c7f_row6_col2, #T_d4c7f_row6_col3, #T_d4c7f_row6_col4, #T_d4c7f_row6_col5, #T_d4c7f_row6_col6 {
#   text-align: left;
# }
# #T_d4c7f_row0_col1, #T_d4c7f_row0_col3, #T_d4c7f_row0_col4, #T_d4c7f_row0_col5, #T_d4c7f_row0_col6, #T_d4c7f_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d4c7f_row0_col7, #T_d4c7f_row1_col7, #T_d4c7f_row2_col7, #T_d4c7f_row3_col7, #T_d4c7f_row5_col7, #T_d4c7f_row6_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d4c7f_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d4c7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4c7f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d4c7f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d4c7f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d4c7f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d4c7f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d4c7f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d4c7f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d4c7f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4c7f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d4c7f_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_d4c7f_row0_col1" class="data row0 col1" >0.3963</td>
#       <td id="T_d4c7f_row0_col2" class="data row0 col2" >0.2763</td>
#       <td id="T_d4c7f_row0_col3" class="data row0 col3" >0.4855</td>
#       <td id="T_d4c7f_row0_col4" class="data row0 col4" >0.8746</td>
#       <td id="T_d4c7f_row0_col5" class="data row0 col5" >0.0288</td>
#       <td id="T_d4c7f_row0_col6" class="data row0 col6" >0.0249</td>
#       <td id="T_d4c7f_row0_col7" class="data row0 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_d4c7f_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_d4c7f_row1_col0" class="data row1 col0" >Voting Regressor</td>
#       <td id="T_d4c7f_row1_col1" class="data row1 col1" >0.4057</td>
#       <td id="T_d4c7f_row1_col2" class="data row1 col2" >0.2674</td>
#       <td id="T_d4c7f_row1_col3" class="data row1 col3" >0.4902</td>
#       <td id="T_d4c7f_row1_col4" class="data row1 col4" >0.8715</td>
#       <td id="T_d4c7f_row1_col5" class="data row1 col5" >0.0291</td>
#       <td id="T_d4c7f_row1_col6" class="data row1 col6" >0.0256</td>
#       <td id="T_d4c7f_row1_col7" class="data row1 col7" >0.1940</td>
#     </tr>
#     <tr>
#       <th id="T_d4c7f_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_d4c7f_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d4c7f_row2_col1" class="data row2 col1" >0.4042</td>
#       <td id="T_d4c7f_row2_col2" class="data row2 col2" >0.2640</td>
#       <td id="T_d4c7f_row2_col3" class="data row2 col3" >0.4936</td>
#       <td id="T_d4c7f_row2_col4" class="data row2 col4" >0.8706</td>
#       <td id="T_d4c7f_row2_col5" class="data row2 col5" >0.0296</td>
#       <td id="T_d4c7f_row2_col6" class="data row2 col6" >0.0257</td>
#       <td id="T_d4c7f_row2_col7" class="data row2 col7" >0.1280</td>
#     </tr>
#     <tr>
#       <th id="T_d4c7f_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_d4c7f_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_d4c7f_row3_col1" class="data row3 col1" >0.4173</td>
#       <td id="T_d4c7f_row3_col2" class="data row3 col2" >0.2789</td>
#       <td id="T_d4c7f_row3_col3" class="data row3 col3" >0.5132</td>
#       <td id="T_d4c7f_row3_col4" class="data row3 col4" >0.8577</td>
#       <td id="T_d4c7f_row3_col5" class="data row3 col5" >0.0307</td>
#       <td id="T_d4c7f_row3_col6" class="data row3 col6" >0.0265</td>
#       <td id="T_d4c7f_row3_col7" class="data row3 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_d4c7f_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_d4c7f_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d4c7f_row4_col1" class="data row4 col1" >0.4318</td>
#       <td id="T_d4c7f_row4_col2" class="data row4 col2" >0.2957</td>
#       <td id="T_d4c7f_row4_col3" class="data row4 col3" >0.5221</td>
#       <td id="T_d4c7f_row4_col4" class="data row4 col4" >0.8560</td>
#       <td id="T_d4c7f_row4_col5" class="data row4 col5" >0.0309</td>
#       <td id="T_d4c7f_row4_col6" class="data row4 col6" >0.0273</td>
#       <td id="T_d4c7f_row4_col7" class="data row4 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_d4c7f_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_d4c7f_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_d4c7f_row5_col1" class="data row5 col1" >0.4191</td>
#       <td id="T_d4c7f_row5_col2" class="data row5 col2" >0.2865</td>
#       <td id="T_d4c7f_row5_col3" class="data row5 col3" >0.5104</td>
#       <td id="T_d4c7f_row5_col4" class="data row5 col4" >0.8553</td>
#       <td id="T_d4c7f_row5_col5" class="data row5 col5" >0.0304</td>
#       <td id="T_d4c7f_row5_col6" class="data row5 col6" >0.0265</td>
#       <td id="T_d4c7f_row5_col7" class="data row5 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_d4c7f_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_d4c7f_row6_col0" class="data row6 col0" >CatBoost Regressor</td>
#       <td id="T_d4c7f_row6_col1" class="data row6 col1" >0.4255</td>
#       <td id="T_d4c7f_row6_col2" class="data row6 col2" >0.3105</td>
#       <td id="T_d4c7f_row6_col3" class="data row6 col3" >0.5255</td>
#       <td id="T_d4c7f_row6_col4" class="data row6 col4" >0.8514</td>
#       <td id="T_d4c7f_row6_col5" class="data row6 col5" >0.0314</td>
#       <td id="T_d4c7f_row6_col6" class="data row6 col6" >0.0270</td>
#       <td id="T_d4c7f_row6_col7" class="data row6 col7" >0.1060</td>
#     </tr>
#   </tbody>
# </table>

# %%
for model_name, model in models.items():
    print(f"\n{'-'*30}")
    print(f"正在分析模型: {model_name.upper()}")
    print(f"{'-'*30}")
    
    # SHAP值解释（需要安装shap包）
    try:
        interpret_model(model)
        plot_model(model, plot = 'feature')
    except:
        print(f"{model_name} 不支持SHAP分析")
# Out:
# ------------------------------
# 正在分析模型: GBR
# ------------------------------
# gbr 不支持SHAP分析
#
# ------------------------------
# 正在分析模型: ET
# ------------------------------
# ------------------------------
# 正在分析模型: LIGHTGBM
# ------------------------------
# ------------------------------
# 正在分析模型: XGBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: CATBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: RF
# ------------------------------
# ------------------------------
# 正在分析模型: BLEND
# ------------------------------
# blend 不支持SHAP分析

# %%
# 定义需要包含的模型简称集合
include_models = {'lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
seleced_model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}
# 集成
seleced_models = ensemble(seleced_model_dict)
# Out:
# <style type="text/css">
# #T_01f3d_row5_col0, #T_01f3d_row5_col1, #T_01f3d_row5_col2, #T_01f3d_row5_col3, #T_01f3d_row5_col4, #T_01f3d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_01f3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01f3d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_01f3d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_01f3d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_01f3d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_01f3d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_01f3d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01f3d_row0_col0" class="data row0 col0" >0.3930</td>
#       <td id="T_01f3d_row0_col1" class="data row0 col1" >0.2090</td>
#       <td id="T_01f3d_row0_col2" class="data row0 col2" >0.4572</td>
#       <td id="T_01f3d_row0_col3" class="data row0 col3" >0.8092</td>
#       <td id="T_01f3d_row0_col4" class="data row0 col4" >0.0293</td>
#       <td id="T_01f3d_row0_col5" class="data row0 col5" >0.0264</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01f3d_row1_col0" class="data row1 col0" >0.5351</td>
#       <td id="T_01f3d_row1_col1" class="data row1 col1" >0.4092</td>
#       <td id="T_01f3d_row1_col2" class="data row1 col2" >0.6397</td>
#       <td id="T_01f3d_row1_col3" class="data row1 col3" >0.8228</td>
#       <td id="T_01f3d_row1_col4" class="data row1 col4" >0.0362</td>
#       <td id="T_01f3d_row1_col5" class="data row1 col5" >0.0322</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01f3d_row2_col0" class="data row2 col0" >0.5674</td>
#       <td id="T_01f3d_row2_col1" class="data row2 col1" >0.4267</td>
#       <td id="T_01f3d_row2_col2" class="data row2 col2" >0.6532</td>
#       <td id="T_01f3d_row2_col3" class="data row2 col3" >0.8464</td>
#       <td id="T_01f3d_row2_col4" class="data row2 col4" >0.0387</td>
#       <td id="T_01f3d_row2_col5" class="data row2 col5" >0.0357</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01f3d_row3_col0" class="data row3 col0" >0.1820</td>
#       <td id="T_01f3d_row3_col1" class="data row3 col1" >0.0468</td>
#       <td id="T_01f3d_row3_col2" class="data row3 col2" >0.2163</td>
#       <td id="T_01f3d_row3_col3" class="data row3 col3" >0.9741</td>
#       <td id="T_01f3d_row3_col4" class="data row3 col4" >0.0135</td>
#       <td id="T_01f3d_row3_col5" class="data row3 col5" >0.0121</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01f3d_row4_col0" class="data row4 col0" >0.3970</td>
#       <td id="T_01f3d_row4_col1" class="data row4 col1" >0.2814</td>
#       <td id="T_01f3d_row4_col2" class="data row4 col2" >0.5305</td>
#       <td id="T_01f3d_row4_col3" class="data row4 col3" >0.8874</td>
#       <td id="T_01f3d_row4_col4" class="data row4 col4" >0.0310</td>
#       <td id="T_01f3d_row4_col5" class="data row4 col5" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_01f3d_row5_col0" class="data row5 col0" >0.4149</td>
#       <td id="T_01f3d_row5_col1" class="data row5 col1" >0.2746</td>
#       <td id="T_01f3d_row5_col2" class="data row5 col2" >0.4994</td>
#       <td id="T_01f3d_row5_col3" class="data row5 col3" >0.8680</td>
#       <td id="T_01f3d_row5_col4" class="data row5 col4" >0.0298</td>
#       <td id="T_01f3d_row5_col5" class="data row5 col5" >0.0263</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_01f3d_row6_col0" class="data row6 col0" >0.1362</td>
#       <td id="T_01f3d_row6_col1" class="data row6 col1" >0.1396</td>
#       <td id="T_01f3d_row6_col2" class="data row6 col2" >0.1589</td>
#       <td id="T_01f3d_row6_col3" class="data row6 col3" >0.0593</td>
#       <td id="T_01f3d_row6_col4" class="data row6 col4" >0.0088</td>
#       <td id="T_01f3d_row6_col5" class="data row6 col5" >0.0081</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.8312783918031971, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8312783918031971
# [LightGBM] [Warning] bagging_fraction is set=0.9911572192162996, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9911572192162996
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# <style type="text/css">
# #T_dcde4 th {
#   text-align: left;
# }
# #T_dcde4_row0_col0, #T_dcde4_row1_col0, #T_dcde4_row1_col1, #T_dcde4_row1_col2, #T_dcde4_row1_col3, #T_dcde4_row1_col4, #T_dcde4_row1_col5, #T_dcde4_row1_col6, #T_dcde4_row2_col0, #T_dcde4_row2_col1, #T_dcde4_row2_col2, #T_dcde4_row2_col3, #T_dcde4_row2_col4, #T_dcde4_row2_col5, #T_dcde4_row2_col6, #T_dcde4_row3_col0, #T_dcde4_row3_col1, #T_dcde4_row3_col2, #T_dcde4_row3_col3, #T_dcde4_row3_col4, #T_dcde4_row3_col5, #T_dcde4_row3_col6 {
#   text-align: left;
# }
# #T_dcde4_row0_col1, #T_dcde4_row0_col2, #T_dcde4_row0_col3, #T_dcde4_row0_col4, #T_dcde4_row0_col5, #T_dcde4_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dcde4_row0_col7, #T_dcde4_row1_col7, #T_dcde4_row3_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dcde4_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dcde4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcde4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dcde4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dcde4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dcde4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dcde4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dcde4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dcde4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_dcde4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcde4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcde4_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_dcde4_row0_col1" class="data row0 col1" >0.4042</td>
#       <td id="T_dcde4_row0_col2" class="data row0 col2" >0.2640</td>
#       <td id="T_dcde4_row0_col3" class="data row0 col3" >0.4936</td>
#       <td id="T_dcde4_row0_col4" class="data row0 col4" >0.8706</td>
#       <td id="T_dcde4_row0_col5" class="data row0 col5" >0.0296</td>
#       <td id="T_dcde4_row0_col6" class="data row0 col6" >0.0257</td>
#       <td id="T_dcde4_row0_col7" class="data row0 col7" >0.1340</td>
#     </tr>
#     <tr>
#       <th id="T_dcde4_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_dcde4_row1_col0" class="data row1 col0" >Voting Regressor</td>
#       <td id="T_dcde4_row1_col1" class="data row1 col1" >0.4149</td>
#       <td id="T_dcde4_row1_col2" class="data row1 col2" >0.2746</td>
#       <td id="T_dcde4_row1_col3" class="data row1 col3" >0.4994</td>
#       <td id="T_dcde4_row1_col4" class="data row1 col4" >0.8680</td>
#       <td id="T_dcde4_row1_col5" class="data row1 col5" >0.0298</td>
#       <td id="T_dcde4_row1_col6" class="data row1 col6" >0.0263</td>
#       <td id="T_dcde4_row1_col7" class="data row1 col7" >0.1660</td>
#     </tr>
#     <tr>
#       <th id="T_dcde4_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_dcde4_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_dcde4_row2_col1" class="data row2 col1" >0.4318</td>
#       <td id="T_dcde4_row2_col2" class="data row2 col2" >0.2957</td>
#       <td id="T_dcde4_row2_col3" class="data row2 col3" >0.5221</td>
#       <td id="T_dcde4_row2_col4" class="data row2 col4" >0.8560</td>
#       <td id="T_dcde4_row2_col5" class="data row2 col5" >0.0309</td>
#       <td id="T_dcde4_row2_col6" class="data row2 col6" >0.0273</td>
#       <td id="T_dcde4_row2_col7" class="data row2 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_dcde4_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_dcde4_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_dcde4_row3_col1" class="data row3 col1" >0.4255</td>
#       <td id="T_dcde4_row3_col2" class="data row3 col2" >0.3105</td>
#       <td id="T_dcde4_row3_col3" class="data row3 col3" >0.5255</td>
#       <td id="T_dcde4_row3_col4" class="data row3 col4" >0.8514</td>
#       <td id="T_dcde4_row3_col5" class="data row3 col5" >0.0314</td>
#       <td id="T_dcde4_row3_col6" class="data row3 col6" >0.0270</td>
#       <td id="T_dcde4_row3_col7" class="data row3 col7" >0.1140</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_model = save_models(seleced_models)
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
