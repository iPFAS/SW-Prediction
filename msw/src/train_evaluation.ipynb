# %%
import sys
import os
current_dir = os.getcwd()  
project_root = os.path.dirname(current_dir)  
sys.path.insert(0, project_root) 
from pathlib import Path
import warnings
import pandas as pd
from pycaret.regression import *
from src.config.config import Config
from src.data.data_loader import DataLoader
from src.models.model_evaluator import ModelEvaluator

def train_models(train: pd.DataFrame,val: pd.DataFrame,target_column: str):
    """训练模型流程
    Args:
        data_path: 可选的数据文件路径
    """
    model_evaluator.setup_experiment(
        train_size=Config.MODEL_CONFIG['train_size'],
        train_data=train,
        val_data = val,
        target_column = target_column,
        categorical_features = Config.FEATURE_CONFIG['categorical_columns']
    )

    # 训练模型并返回最佳模型字典
    return model_evaluator.train_top_models(n_models=Config.MODEL_CONFIG['n_top_models'])

def tune(models: dict):
    """模型调优和集成"""
    # 对top模型进行调优
    tuned_models = model_evaluator.tune_models(models)

    return tuned_models

def ensemble(models: dict):
    """模型集成"""
    # 对top模型进行集成
    blended_model = model_evaluator.ensemble_models(models)

    return blended_model    
    # 模型
    
def save_models(models: dict):

    model_evaluator.saved_models(models)

# %%
# 示例用法
df = pd.read_csv(Path(Config.PATH_CONFIG['features_dir'])  / 'training_data.csv')
data_loader = DataLoader()
model_evaluator = ModelEvaluator()

# 划分数据集
train_data, val_data, country_test_data = data_loader.split_data_by_countries(
    df,
    train_size=Config.DATA_CONFIG['country_train_size'],
    val_size=Config.DATA_CONFIG['country_val_size'],
    random_state=Config.DATA_CONFIG['random_state']
)

train_data, time_test_data = data_loader.split_data_by_time(train_data,
    test_size=Config.DATA_CONFIG['time_test_size'])

# 数据分析
print('\n训练集统计信息:')
data_loader.analyze_datasets(train_data)
print('\n验证集统计信息:')
data_loader.analyze_datasets(val_data)
print('\n外部国家测试集统计信息:')
data_loader.analyze_datasets(country_test_data)
print('\n外部时间测试集统计信息:')
data_loader.analyze_datasets(time_test_data)
#合并验证集和外部国家测试集作为测试集
test_data = pd.concat([val_data, country_test_data])
print('\n合并，作为测试集统计信息:')
data_loader.analyze_datasets(test_data)
# Out:
# 训练集统计信息:
# 总数据条数: 1399
# 国家总数: 57
# 包含的国家: Albania, Argentina, Austria, Bangladesh, Belgium, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, China, Colombia, Congo, Dem. Rep., Croatia, Cyprus, Czechia, Denmark, Estonia, Ethiopia, Greece, Hungary, Iceland, Indonesia, Iran, Islamic Rep., Iraq, Ireland, Italy, Japan, Korea, Rep., Latvia, Lithuania, Luxembourg, Malaysia, Malta, Mexico, Montenegro, Morocco, Netherlands, Nigeria, North Macedonia, Norway, Peru, Philippines, Poland, Romania, Russian Federation, Saudi Arabia, Serbia, Slovak Republic, Slovenia, South Africa, Spain, Sweden, Switzerland, Tanzania, Turkiye, Uganda, United Kingdom
#
# 特征数量: 71
# 特征列表: MSW, MSW_log, gdp_per_capita_acceleration, gdp_per_capita_growth, gdp_ppp/capita_2017_deviation, gdp_ppp/capita_2017_growth, gdp_ppp/capita_2017_log, gdp_ppp/capita_2017_rolling_mean_3y, gdp_ppp/capita_2017_rolling_std_3y, gdp_ppp/capita_2017_squared, gdp_ppp_2017_deviation, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_rolling_mean_3y, gdp_ppp_2017_rolling_std_3y, gdp_ppp_2017_squared, gdp_volatility, high_error_region, high_error_region_development_phase, high_error_region_relative_development, high_error_region_stability, high_error_region_time_squared, high_error_region_time_trend, income_gdp_interaction, income_group_ordinal, is_south_asia, low_income_flag, low_income_gdp_trend, lower_middle_income_flag, lower_middle_income_gdp_trend, middle_east_north_africa_catchup_index, middle_east_north_africa_development_stage, middle_east_north_africa_flag, middle_east_north_africa_growth_deviation, middle_east_north_africa_inequality_index, middle_east_north_africa_relative_position, middle_east_north_africa_resilience, middle_east_north_africa_stability, middle_east_north_africa_transformation_index, population_density_trend, population_deviation, population_growth, population_log, population_rolling_mean_3y, population_rolling_std_3y, population_squared, region_development_stage, region_economic_weight, region_income_interaction, south_asia_catchup_index, south_asia_development_stage, south_asia_flag, south_asia_gdp_interaction, south_asia_growth_deviation, south_asia_inequality_index, south_asia_population_density, south_asia_relative_position, south_asia_resilience, south_asia_stability, south_asia_transformation_index, sub-saharan_africa_catchup_index, sub-saharan_africa_development_stage, sub-saharan_africa_flag, sub-saharan_africa_growth_deviation, sub-saharan_africa_inequality_index, sub-saharan_africa_relative_position, sub-saharan_africa_resilience, sub-saharan_africa_stability, sub-saharan_africa_transformation_index, upper_middle_income_flag, upper_middle_income_gdp_trend
#
# 年份分布: 1990:30 | 1991:30 | 1992:30 | 1993:30 | 1994:30 | 1995:51 | 1996:51 | 1997:52 | 1998:51 | 1999:51 | 2000:52 | 2001:51 | 2002:51 | 2003:51 | 2004:52 | 2005:52 | 2006:53 | 2007:53 | 2008:55 | 2009:55 | 2010:54 | 2011:56 | 2012:56 | 2013:56 | 2014:57 | 2015:56 | 2016:56 | 2017:33 | 2018:30 | 2019:6 | 2020:5 | 2021:3
#
# 验证集统计信息:
# 总数据条数: 185
# 国家总数: 6
# 包含的国家: Egypt, Arab Rep., Finland, France, India, Thailand, Ukraine
#
# 特征数量: 71
# 特征列表: MSW, MSW_log, gdp_per_capita_acceleration, gdp_per_capita_growth, gdp_ppp/capita_2017_deviation, gdp_ppp/capita_2017_growth, gdp_ppp/capita_2017_log, gdp_ppp/capita_2017_rolling_mean_3y, gdp_ppp/capita_2017_rolling_std_3y, gdp_ppp/capita_2017_squared, gdp_ppp_2017_deviation, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_rolling_mean_3y, gdp_ppp_2017_rolling_std_3y, gdp_ppp_2017_squared, gdp_volatility, high_error_region, high_error_region_development_phase, high_error_region_relative_development, high_error_region_stability, high_error_region_time_squared, high_error_region_time_trend, income_gdp_interaction, income_group_ordinal, is_south_asia, low_income_flag, low_income_gdp_trend, lower_middle_income_flag, lower_middle_income_gdp_trend, middle_east_north_africa_catchup_index, middle_east_north_africa_development_stage, middle_east_north_africa_flag, middle_east_north_africa_growth_deviation, middle_east_north_africa_inequality_index, middle_east_north_africa_relative_position, middle_east_north_africa_resilience, middle_east_north_africa_stability, middle_east_north_africa_transformation_index, population_density_trend, population_deviation, population_growth, population_log, population_rolling_mean_3y, population_rolling_std_3y, population_squared, region_development_stage, region_economic_weight, region_income_interaction, south_asia_catchup_index, south_asia_development_stage, south_asia_flag, south_asia_gdp_interaction, south_asia_growth_deviation, south_asia_inequality_index, south_asia_population_density, south_asia_relative_position, south_asia_resilience, south_asia_stability, south_asia_transformation_index, sub-saharan_africa_catchup_index, sub-saharan_africa_development_stage, sub-saharan_africa_flag, sub-saharan_africa_growth_deviation, sub-saharan_africa_inequality_index, sub-saharan_africa_relative_position, sub-saharan_africa_resilience, sub-saharan_africa_stability, sub-saharan_africa_transformation_index, upper_middle_income_flag, upper_middle_income_gdp_trend
#
# 年份分布: 1990:5 | 1991:5 | 1992:5 | 1993:5 | 1994:5 | 1995:6 | 1996:6 | 1997:6 | 1998:6 | 1999:6 | 2000:6 | 2001:6 | 2002:6 | 2003:6 | 2004:6 | 2005:6 | 2006:6 | 2007:6 | 2008:6 | 2009:6 | 2010:6 | 2011:6 | 2012:6 | 2013:6 | 2014:6 | 2015:6 | 2016:6 | 2017:6 | 2018:6 | 2019:6 | 2020:6 | 2021:2 | 2022:2
#
# 外部国家测试集统计信息:
# 总数据条数: 185
# 国家总数: 6
# 包含的国家: Algeria, Australia, Germany, Pakistan, Portugal, United States
#
# 特征数量: 71
# 特征列表: MSW, MSW_log, gdp_per_capita_acceleration, gdp_per_capita_growth, gdp_ppp/capita_2017_deviation, gdp_ppp/capita_2017_growth, gdp_ppp/capita_2017_log, gdp_ppp/capita_2017_rolling_mean_3y, gdp_ppp/capita_2017_rolling_std_3y, gdp_ppp/capita_2017_squared, gdp_ppp_2017_deviation, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_rolling_mean_3y, gdp_ppp_2017_rolling_std_3y, gdp_ppp_2017_squared, gdp_volatility, high_error_region, high_error_region_development_phase, high_error_region_relative_development, high_error_region_stability, high_error_region_time_squared, high_error_region_time_trend, income_gdp_interaction, income_group_ordinal, is_south_asia, low_income_flag, low_income_gdp_trend, lower_middle_income_flag, lower_middle_income_gdp_trend, middle_east_north_africa_catchup_index, middle_east_north_africa_development_stage, middle_east_north_africa_flag, middle_east_north_africa_growth_deviation, middle_east_north_africa_inequality_index, middle_east_north_africa_relative_position, middle_east_north_africa_resilience, middle_east_north_africa_stability, middle_east_north_africa_transformation_index, population_density_trend, population_deviation, population_growth, population_log, population_rolling_mean_3y, population_rolling_std_3y, population_squared, region_development_stage, region_economic_weight, region_income_interaction, south_asia_catchup_index, south_asia_development_stage, south_asia_flag, south_asia_gdp_interaction, south_asia_growth_deviation, south_asia_inequality_index, south_asia_population_density, south_asia_relative_position, south_asia_resilience, south_asia_stability, south_asia_transformation_index, sub-saharan_africa_catchup_index, sub-saharan_africa_development_stage, sub-saharan_africa_flag, sub-saharan_africa_growth_deviation, sub-saharan_africa_inequality_index, sub-saharan_africa_relative_position, sub-saharan_africa_resilience, sub-saharan_africa_stability, sub-saharan_africa_transformation_index, upper_middle_income_flag, upper_middle_income_gdp_trend
#
# 年份分布: 1990:5 | 1991:5 | 1992:5 | 1993:5 | 1994:5 | 1995:6 | 1996:6 | 1997:6 | 1998:6 | 1999:6 | 2000:6 | 2001:6 | 2002:6 | 2003:6 | 2004:6 | 2005:6 | 2006:6 | 2007:6 | 2008:6 | 2009:6 | 2010:6 | 2011:6 | 2012:6 | 2013:6 | 2014:6 | 2015:6 | 2016:6 | 2017:6 | 2018:6 | 2019:6 | 2020:6 | 2021:2 | 2022:2
#
# 外部时间测试集统计信息:
# 总数据条数: 213
# 国家总数: 57
# 包含的国家: Albania, Argentina, Austria, Bangladesh, Belgium, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, China, Colombia, Congo, Dem. Rep., Croatia, Cyprus, Czechia, Denmark, Estonia, Ethiopia, Greece, Hungary, Iceland, Indonesia, Iran, Islamic Rep., Iraq, Ireland, Italy, Japan, Korea, Rep., Latvia, Lithuania, Luxembourg, Malaysia, Malta, Mexico, Montenegro, Morocco, Netherlands, Nigeria, North Macedonia, Norway, Peru, Philippines, Poland, Romania, Russian Federation, Saudi Arabia, Serbia, Slovak Republic, Slovenia, South Africa, Spain, Sweden, Switzerland, Tanzania, Turkiye, Uganda, United Kingdom
#
# 特征数量: 71
# 特征列表: MSW, MSW_log, gdp_per_capita_acceleration, gdp_per_capita_growth, gdp_ppp/capita_2017_deviation, gdp_ppp/capita_2017_growth, gdp_ppp/capita_2017_log, gdp_ppp/capita_2017_rolling_mean_3y, gdp_ppp/capita_2017_rolling_std_3y, gdp_ppp/capita_2017_squared, gdp_ppp_2017_deviation, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_rolling_mean_3y, gdp_ppp_2017_rolling_std_3y, gdp_ppp_2017_squared, gdp_volatility, high_error_region, high_error_region_development_phase, high_error_region_relative_development, high_error_region_stability, high_error_region_time_squared, high_error_region_time_trend, income_gdp_interaction, income_group_ordinal, is_south_asia, low_income_flag, low_income_gdp_trend, lower_middle_income_flag, lower_middle_income_gdp_trend, middle_east_north_africa_catchup_index, middle_east_north_africa_development_stage, middle_east_north_africa_flag, middle_east_north_africa_growth_deviation, middle_east_north_africa_inequality_index, middle_east_north_africa_relative_position, middle_east_north_africa_resilience, middle_east_north_africa_stability, middle_east_north_africa_transformation_index, population_density_trend, population_deviation, population_growth, population_log, population_rolling_mean_3y, population_rolling_std_3y, population_squared, region_development_stage, region_economic_weight, region_income_interaction, south_asia_catchup_index, south_asia_development_stage, south_asia_flag, south_asia_gdp_interaction, south_asia_growth_deviation, south_asia_inequality_index, south_asia_population_density, south_asia_relative_position, south_asia_resilience, south_asia_stability, south_asia_transformation_index, sub-saharan_africa_catchup_index, sub-saharan_africa_development_stage, sub-saharan_africa_flag, sub-saharan_africa_growth_deviation, sub-saharan_africa_inequality_index, sub-saharan_africa_relative_position, sub-saharan_africa_resilience, sub-saharan_africa_stability, sub-saharan_africa_transformation_index, upper_middle_income_flag, upper_middle_income_gdp_trend
#
# 年份分布: 2017:23 | 2018:27 | 2019:50 | 2020:52 | 2021:30 | 2022:31
#
# 合并，作为测试集统计信息:
# 总数据条数: 370
# 国家总数: 12
# 包含的国家: Algeria, Australia, Egypt, Arab Rep., Finland, France, Germany, India, Pakistan, Portugal, Thailand, Ukraine, United States
#
# 特征数量: 71
# 特征列表: MSW, MSW_log, gdp_per_capita_acceleration, gdp_per_capita_growth, gdp_ppp/capita_2017_deviation, gdp_ppp/capita_2017_growth, gdp_ppp/capita_2017_log, gdp_ppp/capita_2017_rolling_mean_3y, gdp_ppp/capita_2017_rolling_std_3y, gdp_ppp/capita_2017_squared, gdp_ppp_2017_deviation, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_rolling_mean_3y, gdp_ppp_2017_rolling_std_3y, gdp_ppp_2017_squared, gdp_volatility, high_error_region, high_error_region_development_phase, high_error_region_relative_development, high_error_region_stability, high_error_region_time_squared, high_error_region_time_trend, income_gdp_interaction, income_group_ordinal, is_south_asia, low_income_flag, low_income_gdp_trend, lower_middle_income_flag, lower_middle_income_gdp_trend, middle_east_north_africa_catchup_index, middle_east_north_africa_development_stage, middle_east_north_africa_flag, middle_east_north_africa_growth_deviation, middle_east_north_africa_inequality_index, middle_east_north_africa_relative_position, middle_east_north_africa_resilience, middle_east_north_africa_stability, middle_east_north_africa_transformation_index, population_density_trend, population_deviation, population_growth, population_log, population_rolling_mean_3y, population_rolling_std_3y, population_squared, region_development_stage, region_economic_weight, region_income_interaction, south_asia_catchup_index, south_asia_development_stage, south_asia_flag, south_asia_gdp_interaction, south_asia_growth_deviation, south_asia_inequality_index, south_asia_population_density, south_asia_relative_position, south_asia_resilience, south_asia_stability, south_asia_transformation_index, sub-saharan_africa_catchup_index, sub-saharan_africa_development_stage, sub-saharan_africa_flag, sub-saharan_africa_growth_deviation, sub-saharan_africa_inequality_index, sub-saharan_africa_relative_position, sub-saharan_africa_resilience, sub-saharan_africa_stability, sub-saharan_africa_transformation_index, upper_middle_income_flag, upper_middle_income_gdp_trend
#
# 年份分布: 1990:10 | 1991:10 | 1992:10 | 1993:10 | 1994:10 | 1995:12 | 1996:12 | 1997:12 | 1998:12 | 1999:12 | 2000:12 | 2001:12 | 2002:12 | 2003:12 | 2004:12 | 2005:12 | 2006:12 | 2007:12 | 2008:12 | 2009:12 | 2010:12 | 2011:12 | 2012:12 | 2013:12 | 2014:12 | 2015:12 | 2016:12 | 2017:12 | 2018:12 | 2019:12 | 2020:12 | 2021:4 | 2022:4

# %%
train_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'train.csv'), index=False)
test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'test.csv'), index=False)
time_test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'time_test_data.csv'), index=False)

# 排除不需要的列
feature_cols = [col for col in train_data.columns 
                if col not in [Config.DATA_CONFIG['target_column'], 'Country Name', 'Year','Region', 'Income Group']]

train = train_data[feature_cols]
test = test_data[feature_cols]
time_test_data = time_test_data[feature_cols] 

target_column = Config.DATA_CONFIG['target_column']
method = Config.FEATURE_CONFIG['target_transform_method']
transformed_column = f'{target_column}_{method}'

# %%
# 训练模型
models = train_models(train,test,transformed_column)
# Out:
# <style type="text/css">
# #T_e381e_row8_col1, #T_e381e_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e381e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e381e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e381e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e381e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e381e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e381e_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e381e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e381e_row1_col1" class="data row1 col1" >MSW_log</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e381e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e381e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e381e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e381e_row3_col1" class="data row3 col1" >(1769, 73)</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e381e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e381e_row4_col1" class="data row4 col1" >(1769, 73)</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e381e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e381e_row5_col1" class="data row5 col1" >(1399, 73)</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e381e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e381e_row6_col1" class="data row6 col1" >(370, 73)</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e381e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e381e_row7_col1" class="data row7 col1" >72</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e381e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e381e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e381e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e381e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e381e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e381e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e381e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e381e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e381e_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_e381e_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e381e_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_e381e_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e381e_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_e381e_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e381e_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_e381e_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e381e_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_e381e_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e381e_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_e381e_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e381e_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_e381e_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e381e_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_e381e_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e381e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e381e_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_e381e_row20_col1" class="data row20 col1" >e6e0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cedd6 th {
#   text-align: left;
# }
# #T_cedd6_row0_col0, #T_cedd6_row1_col0, #T_cedd6_row1_col1, #T_cedd6_row1_col2, #T_cedd6_row1_col3, #T_cedd6_row1_col4, #T_cedd6_row1_col5, #T_cedd6_row1_col6, #T_cedd6_row2_col0, #T_cedd6_row2_col1, #T_cedd6_row2_col2, #T_cedd6_row2_col3, #T_cedd6_row2_col4, #T_cedd6_row2_col5, #T_cedd6_row2_col6, #T_cedd6_row3_col0, #T_cedd6_row3_col1, #T_cedd6_row3_col2, #T_cedd6_row3_col3, #T_cedd6_row3_col4, #T_cedd6_row3_col5, #T_cedd6_row3_col6, #T_cedd6_row4_col0, #T_cedd6_row4_col1, #T_cedd6_row4_col2, #T_cedd6_row4_col3, #T_cedd6_row4_col4, #T_cedd6_row4_col5, #T_cedd6_row4_col6, #T_cedd6_row5_col0, #T_cedd6_row5_col1, #T_cedd6_row5_col2, #T_cedd6_row5_col3, #T_cedd6_row5_col4, #T_cedd6_row5_col5, #T_cedd6_row5_col6, #T_cedd6_row6_col0, #T_cedd6_row6_col1, #T_cedd6_row6_col2, #T_cedd6_row6_col3, #T_cedd6_row6_col4, #T_cedd6_row6_col5, #T_cedd6_row6_col6, #T_cedd6_row7_col0, #T_cedd6_row7_col1, #T_cedd6_row7_col2, #T_cedd6_row7_col3, #T_cedd6_row7_col4, #T_cedd6_row7_col5, #T_cedd6_row7_col6, #T_cedd6_row8_col0, #T_cedd6_row8_col1, #T_cedd6_row8_col2, #T_cedd6_row8_col3, #T_cedd6_row8_col4, #T_cedd6_row8_col5, #T_cedd6_row8_col6, #T_cedd6_row9_col0, #T_cedd6_row9_col1, #T_cedd6_row9_col2, #T_cedd6_row9_col3, #T_cedd6_row9_col4, #T_cedd6_row9_col5, #T_cedd6_row9_col6, #T_cedd6_row10_col0, #T_cedd6_row10_col1, #T_cedd6_row10_col2, #T_cedd6_row10_col3, #T_cedd6_row10_col4, #T_cedd6_row10_col5, #T_cedd6_row10_col6, #T_cedd6_row11_col0, #T_cedd6_row11_col1, #T_cedd6_row11_col2, #T_cedd6_row11_col3, #T_cedd6_row11_col4, #T_cedd6_row11_col5, #T_cedd6_row11_col6, #T_cedd6_row12_col0, #T_cedd6_row12_col1, #T_cedd6_row12_col2, #T_cedd6_row12_col3, #T_cedd6_row12_col4, #T_cedd6_row12_col5, #T_cedd6_row12_col6, #T_cedd6_row13_col0, #T_cedd6_row13_col1, #T_cedd6_row13_col2, #T_cedd6_row13_col3, #T_cedd6_row13_col4, #T_cedd6_row13_col5, #T_cedd6_row13_col6, #T_cedd6_row14_col0, #T_cedd6_row14_col1, #T_cedd6_row14_col2, #T_cedd6_row14_col3, #T_cedd6_row14_col4, #T_cedd6_row14_col5, #T_cedd6_row14_col6, #T_cedd6_row15_col0, #T_cedd6_row15_col1, #T_cedd6_row15_col2, #T_cedd6_row15_col3, #T_cedd6_row15_col4, #T_cedd6_row15_col5, #T_cedd6_row15_col6, #T_cedd6_row16_col0, #T_cedd6_row16_col1, #T_cedd6_row16_col2, #T_cedd6_row16_col3, #T_cedd6_row16_col4, #T_cedd6_row16_col5, #T_cedd6_row16_col6, #T_cedd6_row17_col0, #T_cedd6_row17_col1, #T_cedd6_row17_col2, #T_cedd6_row17_col3, #T_cedd6_row17_col4, #T_cedd6_row17_col5, #T_cedd6_row17_col6, #T_cedd6_row18_col0, #T_cedd6_row18_col1, #T_cedd6_row18_col2, #T_cedd6_row18_col3, #T_cedd6_row18_col4, #T_cedd6_row18_col5, #T_cedd6_row18_col6, #T_cedd6_row19_col0, #T_cedd6_row19_col1, #T_cedd6_row19_col2, #T_cedd6_row19_col3, #T_cedd6_row19_col4, #T_cedd6_row19_col5, #T_cedd6_row19_col6 {
#   text-align: left;
# }
# #T_cedd6_row0_col1, #T_cedd6_row0_col2, #T_cedd6_row0_col3, #T_cedd6_row0_col4, #T_cedd6_row0_col5, #T_cedd6_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cedd6_row0_col7, #T_cedd6_row1_col7, #T_cedd6_row2_col7, #T_cedd6_row3_col7, #T_cedd6_row4_col7, #T_cedd6_row5_col7, #T_cedd6_row6_col7, #T_cedd6_row7_col7, #T_cedd6_row8_col7, #T_cedd6_row9_col7, #T_cedd6_row10_col7, #T_cedd6_row11_col7, #T_cedd6_row12_col7, #T_cedd6_row13_col7, #T_cedd6_row14_col7, #T_cedd6_row15_col7, #T_cedd6_row17_col7, #T_cedd6_row18_col7, #T_cedd6_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cedd6_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cedd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cedd6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cedd6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cedd6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cedd6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cedd6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cedd6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cedd6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cedd6_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cedd6_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_cedd6_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_cedd6_row0_col1" class="data row0 col1" >0.3066</td>
#       <td id="T_cedd6_row0_col2" class="data row0 col2" >0.1915</td>
#       <td id="T_cedd6_row0_col3" class="data row0 col3" >0.4086</td>
#       <td id="T_cedd6_row0_col4" class="data row0 col4" >0.8575</td>
#       <td id="T_cedd6_row0_col5" class="data row0 col5" >0.0259</td>
#       <td id="T_cedd6_row0_col6" class="data row0 col6" >0.0205</td>
#       <td id="T_cedd6_row0_col7" class="data row0 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_cedd6_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_cedd6_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_cedd6_row1_col1" class="data row1 col1" >0.3368</td>
#       <td id="T_cedd6_row1_col2" class="data row1 col2" >0.2180</td>
#       <td id="T_cedd6_row1_col3" class="data row1 col3" >0.4381</td>
#       <td id="T_cedd6_row1_col4" class="data row1 col4" >0.8416</td>
#       <td id="T_cedd6_row1_col5" class="data row1 col5" >0.0278</td>
#       <td id="T_cedd6_row1_col6" class="data row1 col6" >0.0225</td>
#       <td id="T_cedd6_row1_col7" class="data row1 col7" >0.1860</td>
#     </tr>
#     <tr>
#       <th id="T_cedd6_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_cedd6_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cedd6_row2_col1" class="data row2 col1" >0.3399</td>
#       <td id="T_cedd6_row2_col2" class="data row2 col2" >0.2182</td>
#       <td id="T_cedd6_row2_col3" class="data row2 col3" >0.4449</td>
#       <td id="T_cedd6_row2_col4" class="data row2 col4" >0.8461</td>
#       <td id="T_cedd6_row2_col5" class="data row2 col5" >0.0281</td>
#       <td id="T_cedd6_row2_col6" class="data row2 col6" >0.0226</td>
#       <td id="T_cedd6_row2_col7" class="data row2 col7" >0.1140</td>
#     </tr>
#     <tr>
#       <th id="T_cedd6_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_cedd6_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_cedd6_row3_col1" class="data row3 col1" >0.3473</td>
#       <td id="T_cedd6_row3_col2" class="data row3 col2" >0.2202</td>
#       <td id="T_cedd6_row3_col3" class="data row3 col3" >0.4508</td>
#       <td id="T_cedd6_row3_col4" class="data row3 col4" >0.8450</td>
#       <td id="T_cedd6_row3_col5" class="data row3 col5" >0.0285</td>
#       <td id="T_cedd6_row3_col6" class="data row3 col6" >0.0231</td>
#       <td id="T_cedd6_row3_col7" class="data row3 col7" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_cedd6_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_cedd6_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cedd6_row4_col1" class="data row4 col1" >0.3514</td>
#       <td id="T_cedd6_row4_col2" class="data row4 col2" >0.2264</td>
#       <td id="T_cedd6_row4_col3" class="data row4 col3" >0.4550</td>
#       <td id="T_cedd6_row4_col4" class="data row4 col4" >0.8455</td>
#       <td id="T_cedd6_row4_col5" class="data row4 col5" >0.0286</td>
#       <td id="T_cedd6_row4_col6" class="data row4 col6" >0.0232</td>
#       <td id="T_cedd6_row4_col7" class="data row4 col7" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_cedd6_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_cedd6_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_cedd6_row5_col1" class="data row5 col1" >0.3857</td>
#       <td id="T_cedd6_row5_col2" class="data row5 col2" >0.2590</td>
#       <td id="T_cedd6_row5_col3" class="data row5 c

# %%
# 定义需要包含的模型简称集合
include_models = {'rf','xgboost','et','lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}

# %%
print(f'当前调优模型: {", ".join(model_dict.keys())}')

# 调优
tune_models = tune(model_dict)
# Out:
# 当前调优模型: et, gbr, lightgbm, rf, xgboost, catboost
# 当前调优模型: et , 结果如下:
# <style type="text/css">
# #T_34007_row5_col0, #T_34007_row5_col1, #T_34007_row5_col2, #T_34007_row5_col3, #T_34007_row5_col4, #T_34007_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_34007">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34007_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_34007_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_34007_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_34007_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_34007_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_34007_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34007_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34007_row0_col0" class="data row0 col0" >0.5041</td>
#       <td id="T_34007_row0_col1" class="data row0 col1" >0.4840</td>
#       <td id="T_34007_row0_col2" class="data row0 col2" >0.6957</td>
#       <td id="T_34007_row0_col3" class="data row0 col3" >0.5545</td>
#       <td id="T_34007_row0_col4" class="data row0 col4" >0.0459</td>
#       <td id="T_34007_row0_col5" class="data row0 col5" >0.0358</td>
#     </tr>
#     <tr>
#       <th id="T_34007_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34007_row1_col0" class="data row1 col0" >0.3213</td>
#       <td id="T_34007_row1_col1" class="data row1 col1" >0.2098</td>
#       <td id="T_34007_row1_col2" class="data row1 col2" >0.4580</td>
#       <td id="T_34007_row1_col3" class="data row1 col3" >0.9374</td>
#       <td id="T_34007_row1_col4" class="data row1 col4" >0.0309</td>
#       <td id="T_34007_row1_col5" class="data row1 col5" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_34007_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34007_row2_col0" class="data row2 col0" >0.1970</td>
#       <td id="T_34007_row2_col1" class="data row2 col1" >0.0957</td>
#       <td id="T_34007_row2_col2" class="data row2 col2" >0.3094</td>
#       <td id="T_34007_row2_col3" class="data row2 col3" >0.9675</td>
#       <td id="T_34007_row2_col4" class="data row2 col4" >0.0187</td>
#       <td id="T_34007_row2_col5" class="data row2 col5" >0.0129</td>
#     </tr>
#     <tr>
#       <th id="T_34007_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34007_row3_col0" class="data row3 col0" >0.2882</td>
#       <td id="T_34007_row3_col1" class="data row3 col1" >0.1082</td>
#       <td id="T_34007_row3_col2" class="data row3 col2" >0.3290</td>
#       <td id="T_34007_row3_col3" class="data row3 col3" >0.8937</td>
#       <td id="T_34007_row3_col4" class="data row3 col4" >0.0200</td>
#       <td id="T_34007_row3_col5" class="data row3 col5" >0.0187</td>
#     </tr>
#     <tr>
#       <th id="T_34007_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34007_row4_col0" class="data row4 col0" >0.1963</td>
#       <td id="T_34007_row4_col1" class="data row4 col1" >0.0587</td>
#       <td id="T_34007_row4_col2" class="data row4 col2" >0.2423</td>
#       <td id="T_34007_row4_col3" class="data row4 col3" >0.9468</td>
#       <td id="T_34007_row4_col4" class="data row4 col4" >0.0139</td>
#       <td id="T_34007_row4_col5" class="data row4 col5" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_34007_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_34007_row5_col0" class="data row5 col0" >0.3014</td>
#       <td id="T_34007_row5_col1" class="data row5 col1" >0.1913</td>
#       <td id="T_34007_row5_col2" class="data row5 col2" >0.4069</td>
#       <td id="T_34007_row5_col3" class="data row5 col3" >0.8600</td>
#       <td id="T_34007_row5_col4" class="data row5 col4" >0.0259</td>
#       <td id="T_34007_row5_col5" class="data row5 col5" >0.0203</td>
#     </tr>
#     <tr>
#       <th id="T_34007_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_34007_row6_col0" class="data row6 col0" >0.1128</td>
#       <td id="T_34007_row6_col1" class="data row6 col1" >0.1547</td>
#       <td id="T_34007_row6_col2" class="data row6 col2" >0.1605</td>
#       <td id="T_34007_row6_col3" class="data row6 col3" >0.1546</td>
#       <td id="T_34007_row6_col4" class="data row6 col4" >0.0114</td>
#       <td id="T_34007_row6_col5" class="data row6 col5" >0.0086</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4d17a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d17a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4d17a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4d17a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4d17a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4d17a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4d17a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4d17a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d17a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d17a_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_4d17a_row0_col1" class="data row0 col1" >0.4548</td>
#       <td id="T_4d17a_row0_col2" class="data row0 col2" >0.4508</td>
#       <td id="T_4d17a_row0_col3" class="data row0 col3" >0.6714</td>
#       <td id="T_4d17a_row0_col4" class="data row0 col4" >0.7123</td>
#       <td id="T_4d17a_row0_col5" class="data row0 col5" >0.0355</td>
#       <td id="T_4d17a_row0_col6" class="data row0 col6" >0.0254</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: gbr , 结果如下:
# <style type="text/css">
# #T_3a89e_row5_col0, #T_3a89e_row5_col1, #T_3a89e_row5_col2, #T_3a89e_row5_col3, #T_3a89e_row5_col4, #T_3a89e_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3a89e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a89e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3a89e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3a89e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3a89e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3a89e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3a89e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a89e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a89e_row0_col0" class="data row0 col0" >0.4976</td>
#       <td id="T_3a89e_row0_col1" class="data row0 col1" >0.4133</td>
#       <td id="T_3a89e_row0_col2" class="data row0 col2" >0.6428</td>
#       <td id="T_3a89e_row0_col3" class="data row0 col3" >0.6196</td>
#       <td id="T_3a89e_row0_col4" class="data row0 col4" >0.0412</td>
#       <td id="T_3a89e_row0_col5" class="data row0 col5" >0.0341</td>
#     </tr>
#     <tr>
#       <th id="T_3a89e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a89e_row1_col0" class="data row1 col0" >0.3056</td>
#       <td id="T_3a89e_row1_col1" class="data row1 col1" >0.2211</td>
#       <td id="T_3a89e_row1_col2" class="data row1 col2" >0.4702</td>
#       <td id="T_3a89e_row1_col3" class="data row1 col3" >0.9341</td>
#       <td id="T_3a89e_row1_col4" class="data row1 col4" >0.0325</td>
#       <td id="T_3a89e_row1_col5" class="data row1 col5" >0.0215</td>
#     </tr>
#     <tr>
#       <th id="T_3a89e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a89e_row2_col0" class="data row2 col0" >0.2901</td>
#       <td id="T_3a89e_row2_col1" class="data row2 col1" >0.1511</td>
#       <td id="T_3a89e_row2_col2" class="data row2 col2" >0.3887</td>
#       <td id="T_3a89e_row2_col3" class="data row2 col3" >0.9486</td>
#       <td id="T_3a89e_row2_col4" class="data row2 col4" >0.0239</td>
#       <td id="T_3a89e_row2_col5" class="data row2 col5" >0.0191</td>
#     </tr>
#     <tr>
#       <th id="T_3a89e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a89e_row3_col0" class="data row3 col0" >0.3116</td>
#       <td id="T_3a89e_row3_col1" class="data row3 col1" >0.1525</td>
#       <td id="T_3a89e_row3_col2" class="data row3 col2" >0.3905</td>
#       <td id="T_3a89e_row3_col3" class="data row3 col3" >0.8502</td>
#       <td id="T_3a89e_row3_col4" class="data row3 col4" >0.0240</td>
#       <td id="T_3a89e_row3_col5" class="data row3 col5" >0.0204</td>
#     </tr>
#     <tr>
#       <th id="T_3a89e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a89e_row4_col0" class="data row4 col0" >0.2208</td>
#       <td id="T_3a89e_row4_col1" class="data row4 col1" >0.0748</td>
#       <td id="T_3a89e_row4_col2" class="data row4 col2" >0.2735</td>
#       <td id="T_3a89e_row4_col3" class="data row4 col3" >0.9322</td>
#       <td id="T_3a89e_row4_col4" class="data row4 col4" >0.0158</td>
#       <td id="T_3a89e_row4_col5" class="data row4 col5" >0.0136</td>
#     </tr>
#     <tr>
#       <th id="T_3a89e_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_3a89e_row5_col0" class="data row5 col0" >0.3251</td>
#       <td id="T_3a89e_row5_col1" class="data row5 col1" >0.2025</td>
#       <td id="T_3a89e_row5_col2" class="data row5 col2" >0.4331</td>
#       <td id="T_3a89e_row5_col3" class="data row5 col3" >0.8569</td>
#       <td id="T_3a89e_row5_col4" class="data row5 col4" >0.0275</td>
#       <td id="T_3a89e_row5_col5" class="data row5 col5" >0.0217</td>
#     </tr>
#     <tr>
#       <th id="T_3a89e_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_3a89e_row6_col0" class="data row6 col0" >0.0921</td>
#       <td id="T_3a89e_row6_col1" class="data row6 col1" >0.1151</td>
#       <td id="T_3a89e_row6_col2" class="data row6 col2" >0.1222</td>
#       <td id="T_3a89e_row6_col3" class="data row6 col3" >0.1236</td>
#       <td id="T_3a89e_row6_col4" class="data row6 col4" >0.0087</td>
#       <td id="T_3a89e_row6_col5" class="data row6 col5" >0.0067</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0220d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0220d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0220d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0220d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0220d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0220d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0220d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0220d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0220d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0220d_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0220d_row0_col1" class="data row0 col1" >0.3755</td>
#       <td id="T_0220d_row0_col2" class="data row0 col2" >0.2704</td>
#       <td id="T_0220d_row0_col3" class="data row0 col3" >0.5200</td>
#       <td id="T_0220d_row0_col4" class="data row0 col4" >0.8274</td>
#       <td id="T_0220d_row0_col5" class="data row0 col5" >0.0275</td>
#       <td id="T_0220d_row0_col6" class="data row0 col6" >0.0212</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: lightgbm , 结果如下:
# <style type="text/css">
# #T_4f784_row5_col0, #T_4f784_row5_col1, #T_4f784_row5_col2, #T_4f784_row5_col3, #T_4f784_row5_col4, #T_4f784_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4f784">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f784_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4f784_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4f784_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4f784_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4f784_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4f784_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f784_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f784_row0_col0" class="data row0 col0" >0.5335</td>
#       <td id="T_4f784_row0_col1" class="data row0 col1" >0.4678</td>
#       <td id="T_4f784_row0_col2" class="data row0 col2" >0.6840</td>
#       <td id="T_4f784_row0_col3" class="data row0 col3" >0.5694</td>
#       <td id="T_4f784_row0_col4" class="data row0 col4" >0.0440</td>
#       <td id="T_4f784_row0_col5" class="data row0 col5" >0.0366</td>
#     </tr>
#     <tr>
#       <th id="T_4f784_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f784_row1_col0" class="data row1 col0" >0.3903</td>
#       <td id="T_4f784_row1_col1" class="data row1 col1" >0.2636</td>
#       <td id="T_4f784_row1_col2" class="data row1 col2" >0.5134</td>
#       <td id="T_4f784_row1_col3" class="data row1 col3" >0.9214</td>
#       <td id="T_4f784_row1_col4" class="data row1 col4" >0.0340</td>
#       <td id="T_4f784_row1_col5" class="data row1 col5" >0.0262</td>
#     </tr>
#     <tr>
#       <th id="T_4f784_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f784_row2_col0" class="data row2 col0" >0.3602</td>
#       <td id="T_4f784_row2_col1" class="data row2 col1" >0.2220</td>
#       <td id="T_4f784_row2_col2" class="data row2 col2" >0.4711</td>
#       <td id="T_4f784_row2_col3" class="data row2 col3" >0.9245</td>
#       <td id="T_4f784_row2_col4" class="data row2 col4" >0.0286</td>
#       <td id="T_4f784_row2_col5" class="data row2 col5" >0.0236</td>
#     </tr>
#     <tr>
#       <th id="T_4f784_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f784_row3_col0" class="data row3 col0" >0.3666</td>
#       <td id="T_4f784_row3_col1" class="data row3 col1" >0.1951</td>
#       <td id="T_4f784_row3_col2" class="data row3 col2" >0.4417</td>
#       <td id="T_4f784_row3_col3" class="data row3 col3" >0.8084</td>
#       <td id="T_4f784_row3_col4" class="data row3 col4" >0.0271</td>
#       <td id="T_4f784_row3_col5" class="data row3 col5" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_4f784_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f784_row4_col0" class="data row4 col0" >0.2254</td>
#       <td id="T_4f784_row4_col1" class="data row4 col1" >0.0778</td>
#       <td id="T_4f784_row4_col2" class="data row4 col2" >0.2790</td>
#       <td id="T_4f784_row4_col3" class="data row4 col3" >0.9294</td>
#       <td id="T_4f784_row4_col4" class="data row4 col4" >0.0161</td>
#       <td id="T_4f784_row4_col5" class="data row4 col5" >0.0139</td>
#     </tr>
#     <tr>
#       <th id="T_4f784_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_4f784_row5_col0" class="data row5 col0" >0.3752</td>
#       <td id="T_4f784_row5_col1" class="data row5 col1" >0.2453</td>
#       <td id="T_4f784_row5_col2" class="data row5 col2" >0.4778</td>
#       <td id="T_4f784_row5_col3" class="data row5 col3" >0.8306</td>
#       <td id="T_4f784_row5_col4" class="data row5 col4" >0.0300</td>
#       <td id="T_4f784_row5_col5" class="data row5 col5" >0.0248</td>
#     </tr>
#     <tr>
#       <th id="T_4f784_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_4f784_row6_col0" class="data row6 col0" >0.0980</td>
#       <td id="T_4f784_row6_col1" class="data row6 col1" >0.1272</td>
#       <td id="T_4f784_row6_col2" class="data row6 col2" >0.1301</td>
#       <td id="T_4f784_row6_col3" class="data row6 col3" >0.1382</td>
#       <td id="T_4f784_row6_col4" class="data row6 col4" >0.0091</td>
#       <td id="T_4f784_row6_col5" class="data row6 col5" >0.0072</td>
#     </tr>
#   </tbody>
# </table>
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_c51ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c51ea_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c51ea_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c51ea_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c51ea_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c51ea_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c51ea_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c51ea_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c51ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c51ea_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c51ea_row0_col1" class="data row0 col1" >0.3897</td>
#       <td id="T_c51ea_row0_col2" class="data row0 col2" >0.2926</td>
#       <td id="T_c51ea_row0_col3" class="data row0 col3" >0.5409</td>
#       <td id="T_c51ea_row0_col4" class="data row0 col4" >0.8133</td>
#       <td id="T_c51ea_row0_col5" class="data row0 col5" >0.0287</td>
#       <td id="T_c51ea_row0_col6" class="data row0 col6" >0.0221</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: rf , 结果如下:
# <style type="text/css">
# #T_ca9dc_row5_col0, #T_ca9dc_row5_col1, #T_ca9dc_row5_col2, #T_ca9dc_row5_col3, #T_ca9dc_row5_col4, #T_ca9dc_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ca9dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca9dc_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ca9dc_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ca9dc_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ca9dc_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ca9dc_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ca9dc_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca9dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca9dc_row0_col0" class="data row0 col0" >0.5309</td>
#       <td id="T_ca9dc_row0_col1" class="data row0 col1" >0.4653</td>
#       <td id="T_ca9dc_row0_col2" class="data row0 col2" >0.6821</td>
#       <td id="T_ca9dc_row0_col3" class="data row0 col3" >0.5717</td>
#       <td id="T_ca9dc_row0_col4" class="data row0 col4" >0.0436</td>
#       <td id="T_ca9dc_row0_col5" class="data row0 col5" >0.0361</td>
#     </tr>
#     <tr>
#       <th id="T_ca9dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca9dc_row1_col0" class="data row1 col0" >0.3605</td>
#       <td id="T_ca9dc_row1_col1" class="data row1 col1" >0.2332</td>
#       <td id="T_ca9dc_row1_col2" class="data row1 col2" >0.4830</td>
#       <td id="T_ca9dc_row1_col3" class="data row1 col3" >0.9304</td>
#       <td id="T_ca9dc_row1_col4" class="data row1 col4" >0.0327</td>
#       <td id="T_ca9dc_row1_col5" class="data row1 col5" >0.0248</td>
#     </tr>
#     <tr>
#       <th id="T_ca9dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca9dc_row2_col0" class="data row2 col0" >0.3536</td>
#       <td id="T_ca9dc_row2_col1" class="data row2 col1" >0.2128</td>
#       <td id="T_ca9dc_row2_col2" class="data row2 col2" >0.4613</td>
#       <td id="T_ca9dc_row2_col3" class="data row2 col3" >0.9276</td>
#       <td id="T_ca9dc_row2_col4" class="data row2 col4" >0.0284</td>
#       <td id="T_ca9dc_row2_col5" class="data row2 col5" >0.0234</td>
#     </tr>
#     <tr>
#       <th id="T_ca9dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca9dc_row3_col0" class="data row3 col0" >0.2988</td>
#       <td id="T_ca9dc_row3_col1" class="data row3 col1" >0.1493</td>
#       <td id="T_ca9dc_row3_col2" class="data row3 col2" >0.3864</td>
#       <td id="T_ca9dc_row3_col3" class="data row3 col3" >0.8534</td>
#       <td id="T_ca9dc_row3_col4" class="data row3 col4" >0.0239</td>
#       <td id="T_ca9dc_row3_col5" class="data row3 col5" >0.0196</td>
#     </tr>
#     <tr>
#       <th id="T_ca9dc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca9dc_row4_col0" class="data row4 col0" >0.2125</td>
#       <td id="T_ca9dc_row4_col1" class="data row4 col1" >0.0705</td>
#       <td id="T_ca9dc_row4_col2" class="data row4 col2" >0.2655</td>
#       <td id="T_ca9dc_row4_col3" class="data row4 col3" >0.9361</td>
#       <td id="T_ca9dc_row4_col4" class="data row4 col4" >0.0153</td>
#       <td id="T_ca9dc_row4_col5" class="data row4 col5" >0.0131</td>
#     </tr>
#     <tr>
#       <th id="T_ca9dc_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_ca9dc_row5_col0" class="data row5 col0" >0.3513</td>
#       <td id="T_ca9dc_row5_col1" class="data row5 col1" >0.2262</td>
#       <td id="T_ca9dc_row5_col2" class="data row5 col2" >0.4557</td>
#       <td id="T_ca9dc_row5_col3" class="data row5 col3" >0.8438</td>
#       <td id="T_ca9dc_row5_col4" class="data row5 col4" >0.0288</td>
#       <td id="T_ca9dc_row5_col5" class="data row5 col5" >0.0234</td>
#     </tr>
#     <tr>
#       <th id="T_ca9dc_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_ca9dc_row6_col0" class="data row6 col0" >0.1043</td>
#       <td id="T_ca9dc_row6_col1" class="data row6 col1" >0.1323</td>
#       <td id="T_ca9dc_row6_col2" class="data row6 col2" >0.1364</td>
#       <td id="T_ca9dc_row6_col3" class="data row6 col3" >0.1394</td>
#       <td id="T_ca9dc_row6_col4" class="data row6 col4" >0.0094</td>
#       <td id="T_ca9dc_row6_col5" class="data row6 col5" >0.0076</td>
#     </tr>
#   </tbody>
# </table>
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_da870">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da870_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_da870_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_da870_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_da870_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_da870_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_da870_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_da870_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da870_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da870_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_da870_row0_col1" class="data row0 col1" >0.3997</td>
#       <td id="T_da870_row0_col2" class="data row0 col2" >0.3093</td>
#       <td id="T_da870_row0_col3" class="data row0 col3" >0.5562</td>
#       <td id="T_da870_row0_col4" class="data row0 col4" >0.8026</td>
#       <td id="T_da870_row0_col5" class="data row0 col5" >0.0296</td>
#       <td id="T_da870_row0_col6" class="data row0 col6" >0.0226</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: xgboost , 结果如下:
# <style type="text/css">
# #T_672fa_row5_col0, #T_672fa_row5_col1, #T_672fa_row5_col2, #T_672fa_row5_col3, #T_672fa_row5_col4, #T_672fa_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_672fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_672fa_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_672fa_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_672fa_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_672fa_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_672fa_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_672fa_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_672fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_672fa_row0_col0" class="data row0 col0" >0.5701</td>
#       <td id="T_672fa_row0_col1" class="data row0 col1" >0.5287</td>
#       <td id="T_672fa_row0_col2" class="data row0 col2" >0.7271</td>
#       <td id="T_672fa_row0_col3" class="data row0 col3" >0.5134</td>
#       <td id="T_672fa_row0_col4" class="data row0 col4" >0.0468</td>
#       <td id="T_672fa_row0_col5" class="data row0 col5" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_672fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_672fa_row1_col0" class="data row1 col0" >0.3485</td>
#       <td id="T_672fa_row1_col1" class="data row1 col1" >0.2375</td>
#       <td id="T_672fa_row1_col2" class="data row1 col2" >0.4874</td>
#       <td id="T_672fa_row1_col3" class="data row1 col3" >0.9292</td>
#       <td id="T_672fa_row1_col4" class="data row1 col4" >0.0329</td>
#       <td id="T_672fa_row1_col5" class="data row1 col5" >0.0239</td>
#     </tr>
#     <tr>
#       <th id="T_672fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_672fa_row2_col0" class="data row2 col0" >0.2221</td>
#       <td id="T_672fa_row2_col1" class="data row2 col1" >0.1056</td>
#       <td id="T_672fa_row2_col2" class="data row2 col2" >0.3249</td>
#       <td id="T_672fa_row2_col3" class="data row2 col3" >0.9641</td>
#       <td id="T_672fa_row2_col4" class="data row2 col4" >0.0199</td>
#       <td id="T_672fa_row2_col5" class="data row2 col5" >0.0148</td>
#     </tr>
#     <tr>
#       <th id="T_672fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_672fa_row3_col0" class="data row3 col0" >0.2994</td>
#       <td id="T_672fa_row3_col1" class="data row3 col1" >0.1326</td>
#       <td id="T_672fa_row3_col2" class="data row3 col2" >0.3641</td>
#       <td id="T_672fa_row3_col3" class="data row3 col3" >0.8698</td>
#       <td id="T_672fa_row3_col4" class="data row3 col4" >0.0225</td>
#       <td id="T_672fa_row3_col5" class="data row3 col5" >0.0196</td>
#     </tr>
#     <tr>
#       <th id="T_672fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_672fa_row4_col0" class="data row4 col0" >0.1797</td>
#       <td id="T_672fa_row4_col1" class="data row4 col1" >0.0546</td>
#       <td id="T_672fa_row4_col2" class="data row4 col2" >0.2337</td>
#       <td id="T_672fa_row4_col3" class="data row4 col3" >0.9505</td>
#       <td id="T_672fa_row4_col4" class="data row4 col4" >0.0134</td>
#       <td id="T_672fa_row4_col5" class="data row4 col5" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_672fa_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_672fa_row5_col0" class="data row5 col0" >0.3240</td>
#       <td id="T_672fa_row5_col1" class="data row5 col1" >0.2118</td>
#       <td id="T_672fa_row5_col2" class="data row5 col2" >0.4274</td>
#       <td id="T_672fa_row5_col3" class="data row5 col3" >0.8454</td>
#       <td id="T_672fa_row5_col4" class="data row5 col4" >0.0271</td>
#       <td id="T_672fa_row5_col5" class="data row5 col5" >0.0217</td>
#     </tr>
#     <tr>
#       <th id="T_672fa_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_672fa_row6_col0" class="data row6 col0" >0.1364</td>
#       <td id="T_672fa_row6_col1" class="data row6 col1" >0.1693</td>
#       <td id="T_672fa_row6_col2" class="data row6 col2" >0.1706</td>
#       <td id="T_672fa_row6_col3" class="data row6 col3" >0.1691</td>
#       <td id="T_672fa_row6_col4" class="data row6 col4" >0.0117</td>
#       <td id="T_672fa_row6_col5" class="data row6 col5" >0.0097</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c5691">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5691_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c5691_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c5691_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c5691_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c5691_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c5691_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c5691_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5691_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5691_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c5691_row0_col1" class="data row0 col1" >0.3812</td>
#       <td id="T_c5691_row0_col2" class="data row0 col2" >0.3049</td>
#       <td id="T_c5691_row0_col3" class="data row0 col3" >0.5521</td>
#       <td id="T_c5691_row0_col4" class="data row0 col4" >0.8055</td>
#       <td id="T_c5691_row0_col5" class="data row0 col5" >0.0291</td>
#       <td id="T_c5691_row0_col6" class="data row0 col6" >0.0214</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: catboost , 结果如下:
# <style type="text/css">
# #T_213d6_row5_col0, #T_213d6_row5_col1, #T_213d6_row5_col2, #T_213d6_row5_col3, #T_213d6_row5_col4, #T_213d6_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_213d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_213d6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_213d6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_213d6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_213d6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_213d6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_213d6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_213d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_213d6_row0_col0" class="data row0 col0" >0.5412</td>
#       <td id="T_213d6_row0_col1" class="data row0 col1" >0.4779</td>
#       <td id="T_213d6_row0_col2" class="data row0 col2" >0.6913</td>
#       <td id="T_213d6_row0_col3" class="data row0 col3" >0.5601</td>
#       <td id="T_213d6_row0_col4" class="data row0 col4" >0.0453</td>
#       <td id="T_213d6_row0_col5" class="data row0 col5" >0.0379</td>
#     </tr>
#     <tr>
#       <th id="T_213d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_213d6_row1_col0" class="data row1 col0" >0.3852</td>
#       <td id="T_213d6_row1_col1" class="data row1 col1" >0.2503</td>
#       <td id="T_213d6_row1_col2" class="data row1 col2" >0.5003</td>
#       <td id="T_213d6_row1_col3" class="data row1 col3" >0.9253</td>
#       <td id="T_213d6_row1_col4" class="data row1 col4" >0.0336</td>
#       <td id="T_213d6_row1_col5" class="data row1 col5" >0.0261</td>
#     </tr>
#     <tr>
#       <th id="T_213d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_213d6_row2_col0" class="data row2 col0" >0.2689</td>
#       <td id="T_213d6_row2_col1" class="data row2 col1" >0.1160</td>
#       <td id="T_213d6_row2_col2" class="data row2 col2" >0.3407</td>
#       <td id="T_213d6_row2_col3" class="data row2 col3" >0.9605</td>
#       <td id="T_213d6_row2_col4" class="data row2 col4" >0.0220</td>
#       <td id="T_213d6_row2_col5" class="data row2 col5" >0.0184</td>
#     </tr>
#     <tr>
#       <th id="T_213d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_213d6_row3_col0" class="data row3 col0" >0.2870</td>
#       <td id="T_213d6_row3_col1" class="data row3 col1" >0.1224</td>
#       <td id="T_213d6_row3_col2" class="data row3 col2" >0.3498</td>
#       <td id="T_213d6_row3_col3" class="data row3 col3" >0.8798</td>
#       <td id="T_213d6_row3_col4" class="data row3 col4" >0.0214</td>
#       <td id="T_213d6_row3_col5" class="data row3 col5" >0.0188</td>
#     </tr>
#     <tr>
#       <th id="T_213d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_213d6_row4_col0" class="data row4 col0" >0.2249</td>
#       <td id="T_213d6_row4_col1" class="data row4 col1" >0.0848</td>
#       <td id="T_213d6_row4_col2" class="data row4 col2" >0.2913</td>
#       <td id="T_213d6_row4_col3" class="data row4 col3" >0.9231</td>
#       <td id="T_213d6_row4_col4" class="data row4 col4" >0.0169</td>
#       <td id="T_213d6_row4_col5" class="data row4 col5" >0.0139</td>
#     </tr>
#     <tr>
#       <th id="T_213d6_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_213d6_row5_col0" class="data row5 col0" >0.3415</td>
#       <td id="T_213d6_row5_col1" class="data row5 col1" >0.2103</td>
#       <td id="T_213d6_row5_col2" class="data row5 col2" >0.4347</td>
#       <td id="T_213d6_row5_col3" class="data row5 col3" >0.8498</td>
#       <td id="T_213d6_row5_col4" class="data row5 col4" >0.0278</td>
#       <td id="T_213d6_row5_col5" class="data row5 col5" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_213d6_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_213d6_row6_col0" class="data row6 col0" >0.1128</td>
#       <td id="T_213d6_row6_col1" class="data row6 col1" >0.1453</td>
#       <td id="T_213d6_row6_col2" class="data row6 col2" >0.1461</td>
#       <td id="T_213d6_row6_col3" class="data row6 col3" >0.1471</td>
#       <td id="T_213d6_row6_col4" class="data row6 col4" >0.0103</td>
#       <td id="T_213d6_row6_col5" class="data row6 col5" >0.0084</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_58db3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58db3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_58db3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_58db3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_58db3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_58db3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_58db3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_58db3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58db3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58db3_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_58db3_row0_col1" class="data row0 col1" >0.3401</td>
#       <td id="T_58db3_row0_col2" class="data row0 col2" >0.2813</td>
#       <td id="T_58db3_row0_col3" class="data row0 col3" >0.5304</td>
#       <td id="T_58db3_row0_col4" class="data row0 col4" >0.8205</td>
#       <td id="T_58db3_row0_col5" class="data row0 col5" >0.0282</td>
#       <td id="T_58db3_row0_col6" class="data row0 col6" >0.0191</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 集成
models = ensemble(model_dict)
# Out:
# <style type="text/css">
# #T_b6bb9_row5_col0, #T_b6bb9_row5_col1, #T_b6bb9_row5_col2, #T_b6bb9_row5_col3, #T_b6bb9_row5_col4, #T_b6bb9_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b6bb9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6bb9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b6bb9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b6bb9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b6bb9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b6bb9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b6bb9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6bb9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6bb9_row0_col0" class="data row0 col0" >0.5264</td>
#       <td id="T_b6bb9_row0_col1" class="data row0 col1" >0.4667</td>
#       <td id="T_b6bb9_row0_col2" class="data row0 col2" >0.6832</td>
#       <td id="T_b6bb9_row0_col3" class="data row0 col3" >0.5704</td>
#       <td id="T_b6bb9_row0_col4" class="data row0 col4" >0.0445</td>
#       <td id="T_b6bb9_row0_col5" class="data row0 col5" >0.0366</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6bb9_row1_col0" class="data row1 col0" >0.3126</td>
#       <td id="T_b6bb9_row1_col1" class="data row1 col1" >0.2093</td>
#       <td id="T_b6bb9_row1_col2" class="data row1 col2" >0.4575</td>
#       <td id="T_b6bb9_row1_col3" class="data row1 col3" >0.9376</td>
#       <td id="T_b6bb9_row1_col4" class="data row1 col4" >0.0314</td>
#       <td id="T_b6bb9_row1_col5" class="data row1 col5" >0.0216</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6bb9_row2_col0" class="data row2 col0" >0.2130</td>
#       <td id="T_b6bb9_row2_col1" class="data row2 col1" >0.1035</td>
#       <td id="T_b6bb9_row2_col2" class="data row2 col2" >0.3216</td>
#       <td id="T_b6bb9_row2_col3" class="data row2 col3" >0.9648</td>
#       <td id="T_b6bb9_row2_col4" class="data row2 col4" >0.0193</td>
#       <td id="T_b6bb9_row2_col5" class="data row2 col5" >0.0138</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6bb9_row3_col0" class="data row3 col0" >0.2738</td>
#       <td id="T_b6bb9_row3_col1" class="data row3 col1" >0.1200</td>
#       <td id="T_b6bb9_row3_col2" class="data row3 col2" >0.3463</td>
#       <td id="T_b6bb9_row3_col3" class="data row3 col3" >0.8822</td>
#       <td id="T_b6bb9_row3_col4" class="data row3 col4" >0.0214</td>
#       <td id="T_b6bb9_row3_col5" class="data row3 col5" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6bb9_row4_col0" class="data row4 col0" >0.1880</td>
#       <td id="T_b6bb9_row4_col1" class="data row4 col1" >0.0569</td>
#       <td id="T_b6bb9_row4_col2" class="data row4 col2" >0.2385</td>
#       <td id="T_b6bb9_row4_col3" class="data row4 col3" >0.9484</td>
#       <td id="T_b6bb9_row4_col4" class="data row4 col4" >0.0136</td>
#       <td id="T_b6bb9_row4_col5" class="data row4 col5" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb9_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b6bb9_row5_col0" class="data row5 col0" >0.3028</td>
#       <td id="T_b6bb9_row5_col1" class="data row5 col1" >0.1913</td>
#       <td id="T_b6bb9_row5_col2" class="data row5 col2" >0.4094</td>
#       <td id="T_b6bb9_row5_col3" class="data row5 col3" >0.8607</td>
#       <td id="T_b6bb9_row5_col4" class="data row5 col4" >0.0260</td>
#       <td id="T_b6bb9_row5_col5" class="data row5 col5" >0.0203</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb9_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b6bb9_row6_col0" class="data row6 col0" >0.1201</td>
#       <td id="T_b6bb9_row6_col1" class="data row6 col1" >0.1463</td>
#       <td id="T_b6bb9_row6_col2" class="data row6 col2" >0.1537</td>
#       <td id="T_b6bb9_row6_col3" class="data row6 col3" >0.1478</td>
#       <td id="T_b6bb9_row6_col4" class="data row6 col4" >0.0109</td>
#       <td id="T_b6bb9_row6_col5" class="data row6 col5" >0.0089</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e85b7 th {
#   text-align: left;
# }
# #T_e85b7_row0_col0, #T_e85b7_row0_col3, #T_e85b7_row0_col5, #T_e85b7_row1_col0, #T_e85b7_row1_col1, #T_e85b7_row1_col2, #T_e85b7_row1_col4, #T_e85b7_row1_col6, #T_e85b7_row2_col0, #T_e85b7_row2_col1, #T_e85b7_row2_col2, #T_e85b7_row2_col3, #T_e85b7_row2_col4, #T_e85b7_row2_col5, #T_e85b7_row2_col6, #T_e85b7_row3_col0, #T_e85b7_row3_col1, #T_e85b7_row3_col2, #T_e85b7_row3_col3, #T_e85b7_row3_col4, #T_e85b7_row3_col5, #T_e85b7_row3_col6, #T_e85b7_row4_col0, #T_e85b7_row4_col1, #T_e85b7_row4_col2, #T_e85b7_row4_col3, #T_e85b7_row4_col4, #T_e85b7_row4_col5, #T_e85b7_row4_col6, #T_e85b7_row5_col0, #T_e85b7_row5_col1, #T_e85b7_row5_col2, #T_e85b7_row5_col3, #T_e85b7_row5_col4, #T_e85b7_row5_col5, #T_e85b7_row5_col6, #T_e85b7_row6_col0, #T_e85b7_row6_col1, #T_e85b7_row6_col2, #T_e85b7_row6_col3, #T_e85b7_row6_col4, #T_e85b7_row6_col5, #T_e85b7_row6_col6 {
#   text-align: left;
# }
# #T_e85b7_row0_col1, #T_e85b7_row0_col2, #T_e85b7_row0_col4, #T_e85b7_row0_col6, #T_e85b7_row1_col3, #T_e85b7_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e85b7_row0_col7, #T_e85b7_row1_col7, #T_e85b7_row2_col7, #T_e85b7_row4_col7, #T_e85b7_row5_col7, #T_e85b7_row6_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e85b7_row3_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e85b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e85b7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e85b7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e85b7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e85b7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e85b7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e85b7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e85b7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e85b7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e85b7_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_e85b7_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_e85b7_row0_col1" class="data row0 col1" >0.3028</td>
#       <td id="T_e85b7_row0_col2" class="data row0 col2" >0.1913</td>
#       <td id="T_e85b7_row0_col3" class="data row0 col3" >0.4094</td>
#       <td id="T_e85b7_row0_col4" class="data row0 col4" >0.8607</td>
#       <td id="T_e85b7_row0_col5" class="data row0 col5" >0.0260</td>
#       <td id="T_e85b7_row0_col6" class="data row0 col6" >0.0203</td>
#       <td id="T_e85b7_row0_col7" class="data row0 col7" >1.5840</td>
#     </tr>
#     <tr>
#       <th id="T_e85b7_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_e85b7_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_e85b7_row1_col1" class="data row1 col1" >0.3066</td>
#       <td id="T_e85b7_row1_col2" class="data row1 col2" >0.1915</td>
#       <td id="T_e85b7_row1_col3" class="data row1 col3" >0.4086</td>
#       <td id="T_e85b7_row1_col4" class="data row1 col4" >0.8575</td>
#       <td id="T_e85b7_row1_col5" class="data row1 col5" >0.0259</td>
#       <td id="T_e85b7_row1_col6" class="data row1 col6" >0.0205</td>
#       <td id="T_e85b7_row1_col7" class="data row1 col7" >0.4980</td>
#     </tr>
#     <tr>
#       <th id="T_e85b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e85b7_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e85b7_row2_col1" class="data row2 col1" >0.3399</td>
#       <td id="T_e85b7_row2_col2" class="data row2 col2" >0.2182</td>
#       <td id="T_e85b7_row2_col3" class="data row2 col3" >0.4449</td>
#       <td id="T_e85b7_row2_col4" class="data row2 col4" >0.8461</td>
#       <td id="T_e85b7_row2_col5" class="data row2 col5" >0.0281</td>
#       <td id="T_e85b7_row2_col6" class="data row2 col6" >0.0226</td>
#       <td id="T_e85b7_row2_col7" class="data row2 col7" >0.5700</td>
#     </tr>
#     <tr>
#       <th id="T_e85b7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e85b7_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_e85b7_row3_col1" class="data row3 col1" >0.3514</td>
#       <td id="T_e85b7_row3_col2" class="data row3 col2" >0.2264</td>
#       <td id="T_e85b7_row3_col3" class="data row3 col3" >0.4550</td>
#       <td id="T_e85b7_row3_col4" class="data row3 col4" >0.8455</td>
#       <td id="T_e85b7_row3_col5" class="data row3 col5" >0.0286</td>
#       <td id="T_e85b7_row3_col6" class="data row3 col6" >0.0232</td>
#       <td id="T_e85b7_row3_col7" class="data row3 col7" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_e85b7_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_e85b7_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_e85b7_row4_col1" class="data row4 col1" >0.3473</td>
#       <td id="T_e85b7_row4_col2" class="data row4 col2" >0.2202</td>
#       <td id="T_e85b7_row4_col3" class="data row4 col3" >0.4508</td>
#       <td id="T_e85b7_row4_col4" class="data row4 col4" >0.8450</td>
#       <td id="T_e85b7_row4_col5" class="data row4 col5" >0.0285</td>
#       <td id="T_e85b7_row4_col6" class="data row4 col6" >0.0231</td>
#       <td id="T_e85b7_row4_col7" class="data row4 col7" >0.1360</td>
#     </tr>
#     <tr>
#       <th id="T_e85b7_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_e85b7_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e85b7_row5_col1" class="data row5 col1" >0.3368</td>
#       <td id="T_e85b7_row5_col2" class="data row5 col2" >0.2180</td>
#       <td id="T_e85b7_row5_col3" class="data row5 col3" >0.4381</td>
#       <td id="T_e85b7_row5_col4" class="data row5 col4" >0.8416</td>
#       <td id="T_e85b7_row5_col5" class="data row5 col5" >0.0278</td>
#       <td id="T_e85b7_row5_col6" class="data row5 col6" >0.0225</td>
#       <td id="T_e85b7_row5_col7" class="data row5 col7" >0.8840</td>
#     </tr>
#     <tr>
#       <th id="T_e85b7_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_e85b7_row6_col0" class="data row6 col0" >CatBoost Regressor</td>
#       <td id="T_e85b7_row6_col1" class="data row6 col1" >0.3570</td>
#       <td id="T_e85b7_row6_col2" class="data row6 col2" >0.3168</td>
#       <td id="T_e85b7_row6_col3" class="data row6 col3" >0.5030</td>
#       <td id="T_e85b7_row6_col4" class="data row6 col4" >0.7707</td>
#       <td id="T_e85b7_row6_col5" class="data row6 col5" >0.0330</td>
#       <td id="T_e85b7_row6_col6" class="data row6 col6" >0.0248</td>
#       <td id="T_e85b7_row6_col7" class="data row6 col7" >1.2960</td>
#     </tr>
#   </tbody>
# </table>

# %%
for model_name, model in models.items():
    print(f"\n{'-'*30}")
    print(f"正在分析模型: {model_name.upper()}")
    print(f"{'-'*30}")
    
    # SHAP值解释（需要安装shap包）
    try:
        interpret_model(model)
        plot_model(model, plot = 'feature')
    except:
        print(f"{model_name} 不支持SHAP分析")
# Out:
# ------------------------------
# 正在分析模型: ET
# ------------------------------
# ------------------------------
# 正在分析模型: GBR
# ------------------------------
# gbr 不支持SHAP分析
#
# ------------------------------
# 正在分析模型: LIGHTGBM
# ------------------------------
# ------------------------------
# 正在分析模型: RF
# ------------------------------
# ------------------------------
# 正在分析模型: XGBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: CATBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: BLEND
# ------------------------------
# blend 不支持SHAP分析

# %%
save_model = save_models(models)
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
