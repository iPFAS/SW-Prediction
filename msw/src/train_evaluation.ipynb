# %%
import sys
import os
current_dir = os.getcwd()  
project_root = os.path.dirname(current_dir)  
sys.path.insert(0, project_root) 
from pathlib import Path
import warnings
import pandas as pd
from pycaret.regression import *
from src.config.config import Config
from src.data.data_loader import DataLoader
from src.models.model_evaluator import ModelEvaluator

def train_models(train: pd.DataFrame,val: pd.DataFrame,target_column: str):
    """训练模型流程
    Args:
        data_path: 可选的数据文件路径
    """
    model_evaluator.setup_experiment(
        train_size=Config.MODEL_CONFIG['train_size'],
        train_data=train,
        val_data = val,
        target_column = target_column,
        categorical_features = Config.FEATURE_CONFIG['categorical_columns']
    )

    # 训练模型并返回最佳模型字典
    return model_evaluator.train_top_models(n_models=Config.MODEL_CONFIG['n_top_models'])

def tune(models: dict):
    """模型调优和集成"""
    # 对top模型进行调优
    tuned_models = model_evaluator.tune_models(models)

    return tuned_models

def ensemble(models: dict):
    """模型集成"""
    # 对top模型进行集成
    blended_model = model_evaluator.ensemble_models(models)

    return blended_model    
    # 模型
    
def save_models(models: dict):

    model_evaluator.saved_models(models)

# %%
# 示例用法
df = pd.read_csv(Path(Config.PATH_CONFIG['features_dir'])  / 'training_data.csv')
data_loader = DataLoader()
model_evaluator = ModelEvaluator()

# 划分数据集
train_data, val_data, country_test_data = data_loader.split_data_by_countries(
    df,
    train_size=Config.DATA_CONFIG['country_train_size'],
    val_size=Config.DATA_CONFIG['country_val_size'],
    random_state=Config.DATA_CONFIG['random_state']
)

train_data, time_test_data = data_loader.split_data_by_time(train_data,
    test_size=Config.DATA_CONFIG['time_test_size'])

# 数据分析
print('\n训练集统计信息:')
data_loader.analyze_datasets(train_data)
print('\n验证集统计信息:')
data_loader.analyze_datasets(val_data)
print('\n外部国家测试集统计信息:')
data_loader.analyze_datasets(country_test_data)
print('\n外部时间测试集统计信息:')
data_loader.analyze_datasets(time_test_data)
#合并验证集和外部国家测试集作为测试集
test_data = pd.concat([val_data, country_test_data])
print('\n合并，作为测试集统计信息:')
data_loader.analyze_datasets(test_data)
# Out:
# 训练集统计信息:
# 总数据条数: 1399
# 国家总数: 57
# 包含的国家: Albania, Argentina, Austria, Bangladesh, Belgium, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, China, Colombia, Congo, Dem. Rep., Croatia, Cyprus, Czechia, Denmark, Estonia, Ethiopia, Greece, Hungary, Iceland, Indonesia, Iran, Islamic Rep., Iraq, Ireland, Italy, Japan, Korea, Rep., Latvia, Lithuania, Luxembourg, Malaysia, Malta, Mexico, Montenegro, Morocco, Netherlands, Nigeria, North Macedonia, Norway, Peru, Philippines, Poland, Romania, Russian Federation, Saudi Arabia, Serbia, Slovak Republic, Slovenia, South Africa, Spain, Sweden, Switzerland, Tanzania, Turkiye, Uganda, United Kingdom
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:30 | 1991.0:30 | 1992.0:30 | 1993.0:30 | 1994.0:30 | 1995.0:51 | 1996.0:51 | 1997.0:52 | 1998.0:51 | 1999.0:51 | 2000.0:52 | 2001.0:51 | 2002.0:51 | 2003.0:51 | 2004.0:52 | 2005.0:52 | 2006.0:53 | 2007.0:53 | 2008.0:55 | 2009.0:55 | 2010.0:54 | 2011.0:56 | 2012.0:56 | 2013.0:56 | 2014.0:57 | 2015.0:56 | 2016.0:56 | 2017.0:33 | 2018.0:30 | 2019.0:6 | 2020.0:5 | 2021.0:3
#
# 验证集统计信息:
# 总数据条数: 185
# 国家总数: 6
# 包含的国家: Egypt, Arab Rep., Finland, France, India, Thailand, Ukraine
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:5 | 1991.0:5 | 1992.0:5 | 1993.0:5 | 1994.0:5 | 1995.0:6 | 1996.0:6 | 1997.0:6 | 1998.0:6 | 1999.0:6 | 2000.0:6 | 2001.0:6 | 2002.0:6 | 2003.0:6 | 2004.0:6 | 2005.0:6 | 2006.0:6 | 2007.0:6 | 2008.0:6 | 2009.0:6 | 2010.0:6 | 2011.0:6 | 2012.0:6 | 2013.0:6 | 2014.0:6 | 2015.0:6 | 2016.0:6 | 2017.0:6 | 2018.0:6 | 2019.0:6 | 2020.0:6 | 2021.0:2 | 2022.0:2
#
# 外部国家测试集统计信息:
# 总数据条数: 185
# 国家总数: 6
# 包含的国家: Algeria, Australia, Germany, Pakistan, Portugal, United States
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:5 | 1991.0:5 | 1992.0:5 | 1993.0:5 | 1994.0:5 | 1995.0:6 | 1996.0:6 | 1997.0:6 | 1998.0:6 | 1999.0:6 | 2000.0:6 | 2001.0:6 | 2002.0:6 | 2003.0:6 | 2004.0:6 | 2005.0:6 | 2006.0:6 | 2007.0:6 | 2008.0:6 | 2009.0:6 | 2010.0:6 | 2011.0:6 | 2012.0:6 | 2013.0:6 | 2014.0:6 | 2015.0:6 | 2016.0:6 | 2017.0:6 | 2018.0:6 | 2019.0:6 | 2020.0:6 | 2021.0:2 | 2022.0:2
#
# 外部时间测试集统计信息:
# 总数据条数: 213
# 国家总数: 57
# 包含的国家: Albania, Argentina, Austria, Bangladesh, Belgium, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, China, Colombia, Congo, Dem. Rep., Croatia, Cyprus, Czechia, Denmark, Estonia, Ethiopia, Greece, Hungary, Iceland, Indonesia, Iran, Islamic Rep., Iraq, Ireland, Italy, Japan, Korea, Rep., Latvia, Lithuania, Luxembourg, Malaysia, Malta, Mexico, Montenegro, Morocco, Netherlands, Nigeria, North Macedonia, Norway, Peru, Philippines, Poland, Romania, Russian Federation, Saudi Arabia, Serbia, Slovak Republic, Slovenia, South Africa, Spain, Sweden, Switzerland, Tanzania, Turkiye, Uganda, United Kingdom
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 2017.0:23 | 2018.0:27 | 2019.0:50 | 2020.0:52 | 2021.0:30 | 2022.0:31
#
# 合并，作为测试集统计信息:
# 总数据条数: 370
# 国家总数: 12
# 包含的国家: Algeria, Australia, Egypt, Arab Rep., Finland, France, Germany, India, Pakistan, Portugal, Thailand, Ukraine, United States
#
# 特征数量: 30
# 特征列表: MSW, MSW_log, economic_stage, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_momentum, gdp_ppp_2017_relative_change, gdp_ppp_2017_relative_position, gdp_ppp_2017_squared, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_momentum, gdp_ppp_per_capita_2017_relative_change, gdp_ppp_per_capita_2017_relative_position, gdp_ppp_per_capita_2017_squared, high_error_development_phase, high_error_economic_volatility, high_error_population_growth_stability, high_error_region, high_error_region_stability, high_error_region_time, high_error_region_time_squared, income_group_ordinal, population_growth, population_log, population_momentum, population_relative_change, population_relative_position, population_squared, population_stage
#
# 年份分布: 1990.0:10 | 1991.0:10 | 1992.0:10 | 1993.0:10 | 1994.0:10 | 1995.0:12 | 1996.0:12 | 1997.0:12 | 1998.0:12 | 1999.0:12 | 2000.0:12 | 2001.0:12 | 2002.0:12 | 2003.0:12 | 2004.0:12 | 2005.0:12 | 2006.0:12 | 2007.0:12 | 2008.0:12 | 2009.0:12 | 2010.0:12 | 2011.0:12 | 2012.0:12 | 2013.0:12 | 2014.0:12 | 2015.0:12 | 2016.0:12 | 2017.0:12 | 2018.0:12 | 2019.0:12 | 2020.0:12 | 2021.0:4 | 2022.0:4

# %%
train_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'train.csv'), index=False)
test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'test.csv'), index=False)
time_test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'time_test_data.csv'), index=False)

# 排除不需要的列
feature_cols = [col for col in train_data.columns 
                if col not in [Config.DATA_CONFIG['target_column'], 'Country Name', 'Year','Region', 'Income Group']]

train = train_data[feature_cols]
test = test_data[feature_cols]
time_test_data = time_test_data[feature_cols] 

target_column = Config.DATA_CONFIG['target_column']
method = Config.FEATURE_CONFIG['target_transform_method']
transformed_column = f'{target_column}_{method}'

# %%
# 训练模型
models = train_models(train,test,transformed_column)
# Out:
# <style type="text/css">
# #T_a0f70_row8_col1, #T_a0f70_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a0f70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f70_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a0f70_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0f70_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a0f70_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0f70_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a0f70_row1_col1" class="data row1 col1" >MSW_log</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0f70_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a0f70_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0f70_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a0f70_row3_col1" class="data row3 col1" >(1769, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0f70_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a0f70_row4_col1" class="data row4 col1" >(1769, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0f70_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a0f70_row5_col1" class="data row5 col1" >(1399, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0f70_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a0f70_row6_col1" class="data row6 col1" >(370, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a0f70_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a0f70_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a0f70_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a0f70_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a0f70_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a0f70_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a0f70_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a0f70_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a0f70_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a0f70_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a0f70_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_a0f70_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a0f70_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_a0f70_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a0f70_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_a0f70_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a0f70_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_a0f70_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a0f70_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_a0f70_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a0f70_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_a0f70_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a0f70_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_a0f70_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a0f70_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_a0f70_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a0f70_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a0f70_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_a0f70_row20_col1" class="data row20 col1" >9e7e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bb2a9 th {
#   text-align: left;
# }
# #T_bb2a9_row0_col0, #T_bb2a9_row0_col2, #T_bb2a9_row1_col0, #T_bb2a9_row1_col1, #T_bb2a9_row1_col2, #T_bb2a9_row1_col3, #T_bb2a9_row1_col4, #T_bb2a9_row1_col5, #T_bb2a9_row1_col6, #T_bb2a9_row2_col0, #T_bb2a9_row2_col1, #T_bb2a9_row2_col3, #T_bb2a9_row2_col4, #T_bb2a9_row2_col5, #T_bb2a9_row2_col6, #T_bb2a9_row3_col0, #T_bb2a9_row3_col1, #T_bb2a9_row3_col2, #T_bb2a9_row3_col3, #T_bb2a9_row3_col4, #T_bb2a9_row3_col5, #T_bb2a9_row3_col6, #T_bb2a9_row4_col0, #T_bb2a9_row4_col1, #T_bb2a9_row4_col2, #T_bb2a9_row4_col3, #T_bb2a9_row4_col4, #T_bb2a9_row4_col5, #T_bb2a9_row4_col6, #T_bb2a9_row5_col0, #T_bb2a9_row5_col1, #T_bb2a9_row5_col2, #T_bb2a9_row5_col3, #T_bb2a9_row5_col4, #T_bb2a9_row5_col5, #T_bb2a9_row5_col6, #T_bb2a9_row6_col0, #T_bb2a9_row6_col1, #T_bb2a9_row6_col2, #T_bb2a9_row6_col3, #T_bb2a9_row6_col4, #T_bb2a9_row6_col5, #T_bb2a9_row6_col6, #T_bb2a9_row7_col0, #T_bb2a9_row7_col1, #T_bb2a9_row7_col2, #T_bb2a9_row7_col3, #T_bb2a9_row7_col4, #T_bb2a9_row7_col5, #T_bb2a9_row7_col6, #T_bb2a9_row8_col0, #T_bb2a9_row8_col1, #T_bb2a9_row8_col2, #T_bb2a9_row8_col3, #T_bb2a9_row8_col4, #T_bb2a9_row8_col5, #T_bb2a9_row8_col6, #T_bb2a9_row9_col0, #T_bb2a9_row9_col1, #T_bb2a9_row9_col2, #T_bb2a9_row9_col3, #T_bb2a9_row9_col4, #T_bb2a9_row9_col5, #T_bb2a9_row9_col6, #T_bb2a9_row10_col0, #T_bb2a9_row10_col1, #T_bb2a9_row10_col2, #T_bb2a9_row10_col3, #T_bb2a9_row10_col4, #T_bb2a9_row10_col5, #T_bb2a9_row10_col6, #T_bb2a9_row11_col0, #T_bb2a9_row11_col1, #T_bb2a9_row11_col2, #T_bb2a9_row11_col3, #T_bb2a9_row11_col4, #T_bb2a9_row11_col5, #T_bb2a9_row11_col6, #T_bb2a9_row12_col0, #T_bb2a9_row12_col1, #T_bb2a9_row12_col2, #T_bb2a9_row12_col3, #T_bb2a9_row12_col4, #T_bb2a9_row12_col5, #T_bb2a9_row12_col6, #T_bb2a9_row13_col0, #T_bb2a9_row13_col1, #T_bb2a9_row13_col2, #T_bb2a9_row13_col3, #T_bb2a9_row13_col4, #T_bb2a9_row13_col5, #T_bb2a9_row13_col6, #T_bb2a9_row14_col0, #T_bb2a9_row14_col1, #T_bb2a9_row14_col2, #T_bb2a9_row14_col3, #T_bb2a9_row14_col4, #T_bb2a9_row14_col5, #T_bb2a9_row14_col6, #T_bb2a9_row15_col0, #T_bb2a9_row15_col1, #T_bb2a9_row15_col2, #T_bb2a9_row15_col3, #T_bb2a9_row15_col4, #T_bb2a9_row15_col5, #T_bb2a9_row15_col6, #T_bb2a9_row16_col0, #T_bb2a9_row16_col1, #T_bb2a9_row16_col2, #T_bb2a9_row16_col3, #T_bb2a9_row16_col4, #T_bb2a9_row16_col5, #T_bb2a9_row16_col6, #T_bb2a9_row17_col0, #T_bb2a9_row17_col1, #T_bb2a9_row17_col2, #T_bb2a9_row17_col3, #T_bb2a9_row17_col4, #T_bb2a9_row17_col5, #T_bb2a9_row17_col6, #T_bb2a9_row18_col0, #T_bb2a9_row18_col1, #T_bb2a9_row18_col2, #T_bb2a9_row18_col3, #T_bb2a9_row18_col4, #T_bb2a9_row18_col5, #T_bb2a9_row18_col6, #T_bb2a9_row19_col0, #T_bb2a9_row19_col1, #T_bb2a9_row19_col2, #T_bb2a9_row19_col3, #T_bb2a9_row19_col4, #T_bb2a9_row19_col5, #T_bb2a9_row19_col6 {
#   text-align: left;
# }
# #T_bb2a9_row0_col1, #T_bb2a9_row0_col3, #T_bb2a9_row0_col4, #T_bb2a9_row0_col5, #T_bb2a9_row0_col6, #T_bb2a9_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bb2a9_row0_col7, #T_bb2a9_row1_col7, #T_bb2a9_row2_col7, #T_bb2a9_row3_col7, #T_bb2a9_row4_col7, #T_bb2a9_row5_col7, #T_bb2a9_row6_col7, #T_bb2a9_row7_col7, #T_bb2a9_row8_col7, #T_bb2a9_row9_col7, #T_bb2a9_row10_col7, #T_bb2a9_row11_col7, #T_bb2a9_row12_col7, #T_bb2a9_row13_col7, #T_bb2a9_row14_col7, #T_bb2a9_row15_col7, #T_bb2a9_row16_col7, #T_bb2a9_row17_col7, #T_bb2a9_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bb2a9_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bb2a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb2a9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bb2a9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bb2a9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bb2a9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bb2a9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bb2a9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bb2a9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bb2a9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb2a9_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_bb2a9_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_bb2a9_row0_col1" class="data row0 col1" >0.3975</td>
#       <td id="T_bb2a9_row0_col2" class="data row0 col2" >0.2906</td>
#       <td id="T_bb2a9_row0_col3" class="data row0 col3" >0.4997</td>
#       <td id="T_bb2a9_row0_col4" class="data row0 col4" >0.8669</td>
#       <td id="T_bb2a9_row0_col5" class="data row0 col5" >0.0296</td>
#       <td id="T_bb2a9_row0_col6" class="data row0 col6" >0.0249</td>
#       <td id="T_bb2a9_row0_col7" class="data row0 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_bb2a9_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_bb2a9_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_bb2a9_row1_col1" class="data row1 col1" >0.4176</td>
#       <td id="T_bb2a9_row1_col2" class="data row1 col2" >0.2999</td>
#       <td id="T_bb2a9_row1_col3" class="data row1 col3" >0.5079</td>
#       <td id="T_bb2a9_row1_col4" class="data row1 col4" >0.8649</td>
#       <td id="T_bb2a9_row1_col5" class="data row1 col5" >0.0299</td>
#       <td id="T_bb2a9_row1_col6" class="data row1 col6" >0.0261</td>
#       <td id="T_bb2a9_row1_col7" class="data row1 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_bb2a9_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_bb2a9_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_bb2a9_row2_col1" class="data row2 col1" >0.4144</td>
#       <td id="T_bb2a9_row2_col2" class="data row2 col2" >0.2904</td>
#       <td id="T_bb2a9_row2_col3" class="data row2 col3" >0.5161</td>
#       <td id="T_bb2a9_row2_col4" class="data row2 col4" >0.8553</td>
#       <td id="T_bb2a9_row2_col5" class="data row2 col5" >0.0308</td>
#       <td id="T_bb2a9_row2_col6" class="data row2 col6" >0.0262</td>
#       <td id="T_bb2a9_row2_col7" class="data row2 col7" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_bb2a9_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_bb2a9_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_bb2a9_row3_col1" class="data row3 col1" >0.4261</td>
#       <td id="T_bb2a9_row3_col2" class="data row3 col2" >0.3108</td>
#       <td id="T_bb2a9_row3_col3" class="data row3 col3" >0.5333</td>
#       <td id="T_bb2a9_row3_col4" class="data row3 col4" >0.8543</td>
#       <td id="T_bb2a9_row3_col5" class="data row3 col5" >0.0315</td>
#       <td id="T_bb2a9_row3_col6" class="data row3 col6" >0.0268</td>
#       <td id="T_bb2a9_row3_col7" class="data row3 col7" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_bb2a9_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_bb2a9_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_bb2a9_row4_col1" class="data row4 col1" >0.4449</td>
#       <td id="T_bb2a9_row4_col2" class="data row4 col2" >0.3207</td>
#       <td id="T_bb2a9_row4_col3" class="data row4 col3" >0.5507</td>
#       <td id="T_bb2a9_row4_col4" class="data row4 col4" >0.8372</td>
#       <td id="T_bb2a9_row4_col5" class="data row4 col5" >0.0326</td>
#       <td id="T_bb2a9_row4_col6" class="data row4 col6" >0.0280</td>
#       <td id="T_bb2a9_row4_col7" class="data row4 col7" >0.0980</td>
#     </tr>
#     <tr>
#       <th id="T_bb2a9_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_bb2a9_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_bb2a9_row5_col1" class="data row5 col1" >0.4382</td>
#       <td id="T_bb2a9_row5_col2" class="data row5 col2" >0.3574</td>
#       <td id="T_bb2a9_row5_col3" class="data row5

# %%
# 定义需要包含的模型简称集合
include_models = {'rf','xgboost','et','lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}

# %%
print(f'当前调优模型: {", ".join(model_dict.keys())}')

# 调优
tune_models = tune(model_dict)
# Out:
# 当前调优模型: et, gbr, lightgbm, xgboost, catboost, rf
# 当前调优模型: et , 结果如下:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   18:43:48
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .      Extra Trees Regressor
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# 集成
models = ensemble(model_dict)

# %%
for model_name, model in models.items():
    print(f"\n{'-'*30}")
    print(f"正在分析模型: {model_name.upper()}")
    print(f"{'-'*30}")
    
    # SHAP值解释（需要安装shap包）
    try:
        interpret_model(model)
        plot_model(model, plot = 'feature')
    except:
        print(f"{model_name} 不支持SHAP分析")

# %%
save_model = save_models(models)
