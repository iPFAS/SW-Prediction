# %%
import sys
import os
current_dir = os.getcwd()  
project_root = os.path.dirname(current_dir)  
sys.path.insert(0, project_root) 
from pathlib import Path
import warnings
import pandas as pd
from pycaret.regression import *
from src.config.config import Config
from src.data.data_loader import DataLoader
from src.models.model_evaluator import ModelEvaluator

def train_models(train: pd.DataFrame,val: pd.DataFrame,target_column: str):
    """训练模型流程
    Args:
        data_path: 可选的数据文件路径
    """
    model_evaluator.setup_experiment(
        train_size=Config.MODEL_CONFIG['train_size'],
        train_data=train,
        val_data = val,
        target_column = target_column,
        categorical_features = Config.FEATURE_CONFIG['categorical_columns']
    )

    # 训练模型并返回最佳模型字典
    return model_evaluator.train_top_models(n_models=Config.MODEL_CONFIG['n_top_models'])

def tune(models: dict):
    """模型调优和集成"""
    # 对top模型进行调优
    tuned_models = model_evaluator.tune_models(models)

    return tuned_models

def ensemble(models: dict):
    """模型集成"""
    # 对top模型进行集成
    blended_model = model_evaluator.ensemble_models(models)

    return blended_model    
    # 模型
    
def save_models(models: dict):

    model_evaluator.saved_models(models)

# %%
# 示例用法
df = pd.read_csv(Path(Config.PATH_CONFIG['features_dir'])  / 'training_data.csv')
data_loader = DataLoader()
model_evaluator = ModelEvaluator()

# 划分数据集
train_data, val_data, country_test_data = data_loader.split_data_by_countries(
    df,
    train_size=Config.DATA_CONFIG['country_train_size'],
    val_size=Config.DATA_CONFIG['country_val_size'],
    random_state=Config.DATA_CONFIG['random_state']
)

train_data, time_test_data = data_loader.split_data_by_time(train_data,
    test_size=Config.DATA_CONFIG['time_test_size'])

# 数据分析
print('\n训练集统计信息:')
data_loader.analyze_datasets(train_data)
print('\n验证集统计信息:')
data_loader.analyze_datasets(val_data)
print('\n外部国家测试集统计信息:')
data_loader.analyze_datasets(country_test_data)
print('\n外部时间测试集统计信息:')
data_loader.analyze_datasets(time_test_data)
#合并验证集和外部国家测试集作为测试集
test_data = pd.concat([val_data, country_test_data])
print('\n合并，作为测试集统计信息:')
data_loader.analyze_datasets(test_data)
# Out:
# 训练集统计信息:
# 总数据条数: 259
# 国家总数: 32
# 包含的国家: Austria, Belgium, Bulgaria, China, Croatia, Cyprus, Denmark, Estonia, France, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, Serbia, Slovak Republic, Spain, Sweden, Turkiye, United Kingdom, United States
#
# 特征数量: 48
# 特征列表: HIW, HIW_log, IW, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2000.0:1 | 2001.0:2 | 2002.0:1 | 2003.0:2 | 2004.0:28 | 2005.0:2 | 2006.0:26 | 2007.0:2 | 2008.0:27 | 2009.0:2 | 2010.0:30 | 2011.0:2 | 2012.0:31 | 2013.0:2 | 2014.0:31 | 2015.0:2 | 2016.0:30 | 2017.0:1 | 2018.0:30 | 2020.0:7
#
# 验证集统计信息:
# 总数据条数: 35
# 国家总数: 3
# 包含的国家: Finland, Japan, Slovenia
#
# 特征数量: 48
# 特征列表: HIW, HIW_log, IW, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2004.0:2 | 2006.0:2 | 2007.0:1 | 2008.0:3 | 2009.0:1 | 2010.0:3 | 2011.0:1 | 2012.0:3 | 2013.0:1 | 2014.0:3 | 2015.0:1 | 2016.0:3 | 2017.0:1 | 2018.0:3 | 2019.0:1 | 2020.0:3 | 2021.0:1 | 2022.0:2
#
# 外部国家测试集统计信息:
# 总数据条数: 26
# 国家总数: 3
# 包含的国家: Bosnia and Herzegovina, Czechia, Germany
#
# 特征数量: 48
# 特征列表: HIW, HIW_log, IW, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2004.0:2 | 2006.0:2 | 2008.0:2 | 2010.0:2 | 2012.0:3 | 2014.0:3 | 2016.0:3 | 2018.0:3 | 2020.0:3 | 2022.0:3
#
# 外部时间测试集统计信息:
# 总数据条数: 58
# 国家总数: 33
# 包含的国家: Albania, Austria, Belgium, Bulgaria, China, Croatia, Cyprus, Denmark, Estonia, France, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, Serbia, Slovak Republic, Spain, Sweden, Turkiye, United Kingdom, United States
#
# 特征数量: 48
# 特征列表: HIW, HIW_log, IW, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2017.0:1 | 2018.0:1 | 2019.0:1 | 2020.0:23 | 2021.0:1 | 2022.0:31
#
# 合并，作为测试集统计信息:
# 总数据条数: 61
# 国家总数: 6
# 包含的国家: Bosnia and Herzegovina, Czechia, Finland, Germany, Japan, Slovenia
#
# 特征数量: 48
# 特征列表: HIW, HIW_log, IW, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2004.0:4 | 2006.0:4 | 2007.0:1 | 2008.0:5 | 2009.0:1 | 2010.0:5 | 2011.0:1 | 2012.0:6 | 2013.0:1 | 2014.0:6 | 2015.0:1 | 2016.0:6 | 2017.0:1 | 2018.0:6 | 2019.0:1 | 2020.0:6 | 2021.0:1 | 2022.0:5

# %%
train_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'train.csv'), index=False)
test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'test.csv'), index=False)
time_test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'time_test_data.csv'), index=False)

# 排除不需要的列
feature_cols = [col for col in train_data.columns 
                if col not in [Config.DATA_CONFIG['target_column'], 'Country Name', 'Year','Region', 'Income Group']]

train = train_data[feature_cols]
test = test_data[feature_cols]
time_test_data = time_test_data[feature_cols] 

target_column = Config.DATA_CONFIG['target_column']
method = Config.FEATURE_CONFIG['target_transform_method']
transformed_column = f'{target_column}_{method}'

# %%
# 训练模型
models = train_models(train,test,transformed_column)
# Out:
# <style type="text/css">
# #T_94107_row8_col1, #T_94107_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_94107">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94107_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_94107_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94107_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94107_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_94107_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94107_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_94107_row1_col1" class="data row1 col1" >HIW_log</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94107_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_94107_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94107_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_94107_row3_col1" class="data row3 col1" >(320, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94107_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_94107_row4_col1" class="data row4 col1" >(320, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94107_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_94107_row5_col1" class="data row5 col1" >(259, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94107_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_94107_row6_col1" class="data row6 col1" >(61, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94107_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_94107_row7_col1" class="data row7 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94107_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_94107_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94107_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_94107_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_94107_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_94107_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_94107_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_94107_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_94107_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_94107_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_94107_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_94107_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_94107_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_94107_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_94107_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_94107_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_94107_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_94107_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_94107_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_94107_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_94107_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_94107_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_94107_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_94107_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_94107_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_94107_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_94107_row20_col1" class="data row20 col1" >0c2f</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_77f94 th {
#   text-align: left;
# }
# #T_77f94_row0_col0, #T_77f94_row0_col4, #T_77f94_row1_col0, #T_77f94_row1_col1, #T_77f94_row1_col2, #T_77f94_row1_col3, #T_77f94_row1_col5, #T_77f94_row1_col6, #T_77f94_row2_col0, #T_77f94_row2_col1, #T_77f94_row2_col2, #T_77f94_row2_col3, #T_77f94_row2_col4, #T_77f94_row2_col5, #T_77f94_row2_col6, #T_77f94_row3_col0, #T_77f94_row3_col1, #T_77f94_row3_col2, #T_77f94_row3_col3, #T_77f94_row3_col4, #T_77f94_row3_col5, #T_77f94_row3_col6, #T_77f94_row4_col0, #T_77f94_row4_col1, #T_77f94_row4_col2, #T_77f94_row4_col3, #T_77f94_row4_col4, #T_77f94_row4_col5, #T_77f94_row4_col6, #T_77f94_row5_col0, #T_77f94_row5_col1, #T_77f94_row5_col2, #T_77f94_row5_col3, #T_77f94_row5_col4, #T_77f94_row5_col5, #T_77f94_row5_col6, #T_77f94_row6_col0, #T_77f94_row6_col1, #T_77f94_row6_col2, #T_77f94_row6_col3, #T_77f94_row6_col4, #T_77f94_row6_col5, #T_77f94_row6_col6, #T_77f94_row7_col0, #T_77f94_row7_col1, #T_77f94_row7_col2, #T_77f94_row7_col3, #T_77f94_row7_col4, #T_77f94_row7_col5, #T_77f94_row7_col6, #T_77f94_row8_col0, #T_77f94_row8_col1, #T_77f94_row8_col2, #T_77f94_row8_col3, #T_77f94_row8_col4, #T_77f94_row8_col5, #T_77f94_row8_col6, #T_77f94_row9_col0, #T_77f94_row9_col1, #T_77f94_row9_col2, #T_77f94_row9_col3, #T_77f94_row9_col4, #T_77f94_row9_col5, #T_77f94_row9_col6, #T_77f94_row10_col0, #T_77f94_row10_col1, #T_77f94_row10_col2, #T_77f94_row10_col3, #T_77f94_row10_col4, #T_77f94_row10_col5, #T_77f94_row10_col6, #T_77f94_row11_col0, #T_77f94_row11_col1, #T_77f94_row11_col2, #T_77f94_row11_col3, #T_77f94_row11_col4, #T_77f94_row11_col5, #T_77f94_row11_col6, #T_77f94_row12_col0, #T_77f94_row12_col1, #T_77f94_row12_col2, #T_77f94_row12_col3, #T_77f94_row12_col4, #T_77f94_row12_col5, #T_77f94_row12_col6, #T_77f94_row13_col0, #T_77f94_row13_col1, #T_77f94_row13_col2, #T_77f94_row13_col3, #T_77f94_row13_col4, #T_77f94_row13_col5, #T_77f94_row13_col6, #T_77f94_row14_col0, #T_77f94_row14_col1, #T_77f94_row14_col2, #T_77f94_row14_col3, #T_77f94_row14_col4, #T_77f94_row14_col5, #T_77f94_row14_col6, #T_77f94_row15_col0, #T_77f94_row15_col1, #T_77f94_row15_col2, #T_77f94_row15_col3, #T_77f94_row15_col4, #T_77f94_row15_col5, #T_77f94_row15_col6, #T_77f94_row16_col0, #T_77f94_row16_col1, #T_77f94_row16_col2, #T_77f94_row16_col3, #T_77f94_row16_col4, #T_77f94_row16_col5, #T_77f94_row16_col6, #T_77f94_row17_col0, #T_77f94_row17_col1, #T_77f94_row17_col2, #T_77f94_row17_col3, #T_77f94_row17_col4, #T_77f94_row17_col5, #T_77f94_row17_col6, #T_77f94_row18_col0, #T_77f94_row18_col1, #T_77f94_row18_col2, #T_77f94_row18_col3, #T_77f94_row18_col4, #T_77f94_row18_col5, #T_77f94_row18_col6, #T_77f94_row19_col0, #T_77f94_row19_col1, #T_77f94_row19_col2, #T_77f94_row19_col3, #T_77f94_row19_col4, #T_77f94_row19_col5, #T_77f94_row19_col6 {
#   text-align: left;
# }
# #T_77f94_row0_col1, #T_77f94_row0_col2, #T_77f94_row0_col3, #T_77f94_row0_col5, #T_77f94_row0_col6, #T_77f94_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_77f94_row0_col7, #T_77f94_row1_col7, #T_77f94_row2_col7, #T_77f94_row3_col7, #T_77f94_row5_col7, #T_77f94_row6_col7, #T_77f94_row7_col7, #T_77f94_row8_col7, #T_77f94_row9_col7, #T_77f94_row10_col7, #T_77f94_row11_col7, #T_77f94_row12_col7, #T_77f94_row14_col7, #T_77f94_row17_col7, #T_77f94_row18_col7, #T_77f94_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_77f94_row4_col7, #T_77f94_row13_col7, #T_77f94_row15_col7, #T_77f94_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_77f94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77f94_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_77f94_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_77f94_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_77f94_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_77f94_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_77f94_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_77f94_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_77f94_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77f94_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_77f94_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_77f94_row0_col1" class="data row0 col1" >0.9173</td>
#       <td id="T_77f94_row0_col2" class="data row0 col2" >1.7315</td>
#       <td id="T_77f94_row0_col3" class="data row0 col3" >1.1928</td>
#       <td id="T_77f94_row0_col4" class="data row0 col4" >0.2549</td>
#       <td id="T_77f94_row0_col5" class="data row0 col5" >0.0824</td>
#       <td id="T_77f94_row0_col6" class="data row0 col6" >0.0652</td>
#       <td id="T_77f94_row0_col7" class="data row0 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_77f94_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_77f94_row1_col1" class="data row1 col1" >0.9981</td>
#       <td id="T_77f94_row1_col2" class="data row1 col2" >1.8083</td>
#       <td id="T_77f94_row1_col3" class="data row1 col3" >1.2580</td>
#       <td id="T_77f94_row1_col4" class="data row1 col4" >0.2573</td>
#       <td id="T_77f94_row1_col5" class="data row1 col5" >0.0868</td>
#       <td id="T_77f94_row1_col6" class="data row1 col6" >0.0713</td>
#       <td id="T_77f94_row1_col7" class="data row1 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_77f94_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_77f94_row2_col1" class="data row2 col1" >0.9773</td>
#       <td id="T_77f94_row2_col2" class="data row2 col2" >1.8835</td>
#       <td id="T_77f94_row2_col3" class="data row2 col3" >1.2633</td>
#       <td id="T_77f94_row2_col4" class="data row2 col4" >0.2027</td>
#       <td id="T_77f94_row2_col5" class="data row2 col5" >0.0871</td>
#       <td id="T_77f94_row2_col6" class="data row2 col6" >0.0696</td>
#       <td id="T_77f94_row2_col7" class="data row2 col7" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_77f94_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_77f94_row3_col1" class="data row3 col1" >1.0315</td>
#       <td id="T_77f94_row3_col2" class="data row3 col2" >1.8969</td>
#       <td id="T_77f94_row3_col3" class="data row3 col3" >1.3021</td>
#       <td id="T_77f94_row3_col4" class="data row3 col4" >0.2357</td>
#       <td id="T_77f94_row3_col5" class="data row3 col5" >0.0890</td>
#       <td id="T_77f94_row3_col6" class="data row3 col6" >0.0734</td>
#       <td id="T_77f94_row3_col7" class="data row3 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_77f94_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_77f94_row4_col1" class="data row4 col1" >1.0558</td>
#       <td id="T_77f94_row4_col2" class="data row4 col2" >2.0708</td>
#       <td id="T_77f94_row4_col3" class="data row4 col3" >1.3568</td>
#       <td id="T_77f94_row4_col4" class="data row4 col4" >0.1575</td>
#       <td id="T_77f94_row4_col5" class="data row4 col5" >0.0933</td>
#       <td id="T_77f94_row4_col6" class="data row4 col6" >0.0752</td>
#       <td id="T_77f94_row4_col7" class="data row4 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_77f94_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_77f94_row5_col1" class="data row5 col1" >1.0391</td>
#       <td id="T_77f94_row5_col2" class="data row5 col2" >2.0535</td>
#       <td id="T_77f94_row5_col3" class="data row5 col3" >1.365

# %%
# 定义需要包含的模型简称集合
include_models = {'rf','xgboost','et','lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}

# %%
print(f'当前调优模型: {", ".join(model_dict.keys())}')

# 调优
tune_models = tune(model_dict)
# Out:
# 当前调优模型: gbr, rf, xgboost, catboost, et, lightgbm
# 当前调优模型: gbr , 结果如下:
# <style type="text/css">
# #T_ea889_row5_col0, #T_ea889_row5_col1, #T_ea889_row5_col2, #T_ea889_row5_col3, #T_ea889_row5_col4, #T_ea889_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ea889">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea889_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ea889_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ea889_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ea889_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ea889_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ea889_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea889_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea889_row0_col0" class="data row0 col0" >0.7936</td>
#       <td id="T_ea889_row0_col1" class="data row0 col1" >1.0611</td>
#       <td id="T_ea889_row0_col2" class="data row0 col2" >1.0301</td>
#       <td id="T_ea889_row0_col3" class="data row0 col3" >0.5511</td>
#       <td id="T_ea889_row0_col4" class="data row0 col4" >0.0645</td>
#       <td id="T_ea889_row0_col5" class="data row0 col5" >0.0525</td>
#     </tr>
#     <tr>
#       <th id="T_ea889_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea889_row1_col0" class="data row1 col0" >1.7430</td>
#       <td id="T_ea889_row1_col1" class="data row1 col1" >4.4845</td>
#       <td id="T_ea889_row1_col2" class="data row1 col2" >2.1177</td>
#       <td id="T_ea889_row1_col3" class="data row1 col3" >-1.3946</td>
#       <td id="T_ea889_row1_col4" class="data row1 col4" >0.1378</td>
#       <td id="T_ea889_row1_col5" class="data row1 col5" >0.1187</td>
#     </tr>
#     <tr>
#       <th id="T_ea889_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea889_row2_col0" class="data row2 col0" >0.8100</td>
#       <td id="T_ea889_row2_col1" class="data row2 col1" >1.1740</td>
#       <td id="T_ea889_row2_col2" class="data row2 col2" >1.0835</td>
#       <td id="T_ea889_row2_col3" class="data row2 col3" >0.7612</td>
#       <td id="T_ea889_row2_col4" class="data row2 col4" >0.0865</td>
#       <td id="T_ea889_row2_col5" class="data row2 col5" >0.0646</td>
#     </tr>
#     <tr>
#       <th id="T_ea889_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea889_row3_col0" class="data row3 col0" >0.8420</td>
#       <td id="T_ea889_row3_col1" class="data row3 col1" >1.2242</td>
#       <td id="T_ea889_row3_col2" class="data row3 col2" >1.1064</td>
#       <td id="T_ea889_row3_col3" class="data row3 col3" >0.7196</td>
#       <td id="T_ea889_row3_col4" class="data row3 col4" >0.0809</td>
#       <td id="T_ea889_row3_col5" class="data row3 col5" >0.0646</td>
#     </tr>
#     <tr>
#       <th id="T_ea889_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea889_row4_col0" class="data row4 col0" >0.5719</td>
#       <td id="T_ea889_row4_col1" class="data row4 col1" >0.4651</td>
#       <td id="T_ea889_row4_col2" class="data row4 col2" >0.6820</td>
#       <td id="T_ea889_row4_col3" class="data row4 col3" >0.9258</td>
#       <td id="T_ea889_row4_col4" class="data row4 col4" >0.0456</td>
#       <td id="T_ea889_row4_col5" class="data row4 col5" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_ea889_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_ea889_row5_col0" class="data row5 col0" >0.9521</td>
#       <td id="T_ea889_row5_col1" class="data row5 col1" >1.6818</td>
#       <td id="T_ea889_row5_col2" class="data row5 col2" >1.2039</td>
#       <td id="T_ea889_row5_col3" class="data row5 col3" >0.3126</td>
#       <td id="T_ea889_row5_col4" class="data row5 col4" >0.0831</td>
#       <td id="T_ea889_row5_col5" class="data row5 col5" >0.0683</td>
#     </tr>
#     <tr>
#       <th id="T_ea889_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_ea889_row6_col0" class="data row6 col0" >0.4068</td>
#       <td id="T_ea889_row6_col1" class="data row6 col1" >1.4275</td>
#       <td id="T_ea889_row6_col2" class="data row6 col2" >0.4820</td>
#       <td id="T_ea889_row6_col3" class="data row6 col3" >0.8619</td>
#       <td id="T_ea889_row6_col4" class="data row6 col4" >0.0309</td>
#       <td id="T_ea889_row6_col5" class="data row6 col5" >0.0267</td>
#     </tr>
#   </tbody>
# </table>
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_6fe8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fe8a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6fe8a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6fe8a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6fe8a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6fe8a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6fe8a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6fe8a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fe8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fe8a_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6fe8a_row0_col1" class="data row0 col1" >0.8747</td>
#       <td id="T_6fe8a_row0_col2" class="data row0 col2" >1.2708</td>
#       <td id="T_6fe8a_row0_col3" class="data row0 col3" >1.1273</td>
#       <td id="T_6fe8a_row0_col4" class="data row0 col4" >0.6603</td>
#       <td id="T_6fe8a_row0_col5" class="data row0 col5" >0.0776</td>
#       <td id="T_6fe8a_row0_col6" class="data row0 col6" >0.0646</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: rf , 结果如下:
# <style type="text/css">
# #T_54da5_row5_col0, #T_54da5_row5_col1, #T_54da5_row5_col2, #T_54da5_row5_col3, #T_54da5_row5_col4, #T_54da5_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_54da5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54da5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_54da5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_54da5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_54da5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_54da5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_54da5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54da5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54da5_row0_col0" class="data row0 col0" >0.6884</td>
#       <td id="T_54da5_row0_col1" class="data row0 col1" >0.8080</td>
#       <td id="T_54da5_row0_col2" class="data row0 col2" >0.8989</td>
#       <td id="T_54da5_row0_col3" class="data row0 col3" >0.6581</td>
#       <td id="T_54da5_row0_col4" class="data row0 col4" >0.0560</td>
#       <td id="T_54da5_row0_col5" class="data row0 col5" >0.0457</td>
#     </tr>
#     <tr>
#       <th id="T_54da5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54da5_row1_col0" class="data row1 col0" >1.8132</td>
#       <td id="T_54da5_row1_col1" class="data row1 col1" >4.9279</td>
#       <td id="T_54da5_row1_col2" class="data row1 col2" >2.2199</td>
#       <td id="T_54da5_row1_col3" class="data row1 col3" >-1.6313</td>
#       <td id="T_54da5_row1_col4" class="data row1 col4" >0.1452</td>
#       <td id="T_54da5_row1_col5" class="data row1 col5" >0.1231</td>
#     </tr>
#     <tr>
#       <th id="T_54da5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54da5_row2_col0" class="data row2 col0" >0.7545</td>
#       <td id="T_54da5_row2_col1" class="data row2 col1" >1.0193</td>
#       <td id="T_54da5_row2_col2" class="data row2 col2" >1.0096</td>
#       <td id="T_54da5_row2_col3" class="data row2 col3" >0.7927</td>
#       <td id="T_54da5_row2_col4" class="data row2 col4" >0.0818</td>
#       <td id="T_54da5_row2_col5" class="data row2 col5" >0.0598</td>
#     </tr>
#     <tr>
#       <th id="T_54da5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54da5_row3_col0" class="data row3 col0" >0.7681</td>
#       <td id="T_54da5_row3_col1" class="data row3 col1" >1.0239</td>
#       <td id="T_54da5_row3_col2" class="data row3 col2" >1.0119</td>
#       <td id="T_54da5_row3_col3" class="data row3 col3" >0.7655</td>
#       <td id="T_54da5_row3_col4" class="data row3 col4" >0.0722</td>
#       <td id="T_54da5_row3_col5" class="data row3 col5" >0.0581</td>
#     </tr>
#     <tr>
#       <th id="T_54da5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54da5_row4_col0" class="data row4 col0" >0.7685</td>
#       <td id="T_54da5_row4_col1" class="data row4 col1" >0.8392</td>
#       <td id="T_54da5_row4_col2" class="data row4 col2" >0.9161</td>
#       <td id="T_54da5_row4_col3" class="data row4 col3" >0.8661</td>
#       <td id="T_54da5_row4_col4" class="data row4 col4" >0.0622</td>
#       <td id="T_54da5_row4_col5" class="data row4 col5" >0.0567</td>
#     </tr>
#     <tr>
#       <th id="T_54da5_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_54da5_row5_col0" class="data row5 col0" >0.9585</td>
#       <td id="T_54da5_row5_col1" class="data row5 col1" >1.7237</td>
#       <td id="T_54da5_row5_col2" class="data row5 col2" >1.2113</td>
#       <td id="T_54da5_row5_col3" class="data row5 col3" >0.2902</td>
#       <td id="T_54da5_row5_col4" class="data row5 col4" >0.0835</td>
#       <td id="T_54da5_row5_col5" class="data row5 col5" >0.0687</td>
#     </tr>
#     <tr>
#       <th id="T_54da5_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_54da5_row6_col0" class="data row6 col0" >0.4283</td>
#       <td id="T_54da5_row6_col1" class="data row6 col1" >1.6046</td>
#       <td id="T_54da5_row6_col2" class="data row6 col2" >0.5064</td>
#       <td id="T_54da5_row6_col3" class="data row6 col3" >0.9631</td>
#       <td id="T_54da5_row6_col4" class="data row6 col4" >0.0321</td>
#       <td id="T_54da5_row6_col5" class="data row6 col5" >0.0277</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ef45e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef45e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ef45e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ef45e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ef45e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ef45e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ef45e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ef45e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef45e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef45e_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_ef45e_row0_col1" class="data row0 col1" >1.1069</td>
#       <td id="T_ef45e_row0_col2" class="data row0 col2" >1.5560</td>
#       <td id="T_ef45e_row0_col3" class="data row0 col3" >1.2474</td>
#       <td id="T_ef45e_row0_col4" class="data row0 col4" >0.5840</td>
#       <td id="T_ef45e_row0_col5" class="data row0 col5" >0.0846</td>
#       <td id="T_ef45e_row0_col6" class="data row0 col6" >0.0802</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: xgboost , 结果如下:
# <style type="text/css">
# #T_d4865_row5_col0, #T_d4865_row5_col1, #T_d4865_row5_col2, #T_d4865_row5_col3, #T_d4865_row5_col4, #T_d4865_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d4865">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4865_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d4865_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d4865_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d4865_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d4865_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d4865_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4865_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4865_row0_col0" class="data row0 col0" >1.0361</td>
#       <td id="T_d4865_row0_col1" class="data row0 col1" >1.7507</td>
#       <td id="T_d4865_row0_col2" class="data row0 col2" >1.3231</td>
#       <td id="T_d4865_row0_col3" class="data row0 col3" >0.2593</td>
#       <td id="T_d4865_row0_col4" class="data row0 col4" >0.0853</td>
#       <td id="T_d4865_row0_col5" class="data row0 col5" >0.0697</td>
#     </tr>
#     <tr>
#       <th id="T_d4865_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4865_row1_col0" class="data row1 col0" >1.7122</td>
#       <td id="T_d4865_row1_col1" class="data row1 col1" >4.4052</td>
#       <td id="T_d4865_row1_col2" class="data row1 col2" >2.0989</td>
#       <td id="T_d4865_row1_col3" class="data row1 col3" >-1.3522</td>
#       <td id="T_d4865_row1_col4" class="data row1 col4" >0.1376</td>
#       <td id="T_d4865_row1_col5" class="data row1 col5" >0.1156</td>
#     </tr>
#     <tr>
#       <th id="T_d4865_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4865_row2_col0" class="data row2 col0" >0.7500</td>
#       <td id="T_d4865_row2_col1" class="data row2 col1" >1.0246</td>
#       <td id="T_d4865_row2_col2" class="data row2 col2" >1.0122</td>
#       <td id="T_d4865_row2_col3" class="data row2 col3" >0.7916</td>
#       <td id="T_d4865_row2_col4" class="data row2 col4" >0.0822</td>
#       <td id="T_d4865_row2_col5" class="data row2 col5" >0.0606</td>
#     </tr>
#     <tr>
#       <th id="T_d4865_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4865_row3_col0" class="data row3 col0" >0.7393</td>
#       <td id="T_d4865_row3_col1" class="data row3 col1" >1.0982</td>
#       <td id="T_d4865_row3_col2" class="data row3 col2" >1.0480</td>
#       <td id="T_d4865_row3_col3" class="data row3 col3" >0.7485</td>
#       <td id="T_d4865_row3_col4" class="data row3 col4" >0.0761</td>
#       <td id="T_d4865_row3_col5" class="data row3 col5" >0.0563</td>
#     </tr>
#     <tr>
#       <th id="T_d4865_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4865_row4_col0" class="data row4 col0" >0.6393</td>
#       <td id="T_d4865_row4_col1" class="data row4 col1" >0.5029</td>
#       <td id="T_d4865_row4_col2" class="data row4 col2" >0.7091</td>
#       <td id="T_d4865_row4_col3" class="data row4 col3" >0.9198</td>
#       <td id="T_d4865_row4_col4" class="data row4 col4" >0.0479</td>
#       <td id="T_d4865_row4_col5" class="data row4 col5" >0.0461</td>
#     </tr>
#     <tr>
#       <th id="T_d4865_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d4865_row5_col0" class="data row5 col0" >0.9754</td>
#       <td id="T_d4865_row5_col1" class="data row5 col1" >1.7563</td>
#       <td id="T_d4865_row5_col2" class="data row5 col2" >1.2383</td>
#       <td id="T_d4865_row5_col3" class="data row5 col3" >0.2734</td>
#       <td id="T_d4865_row5_col4" class="data row5 col4" >0.0858</td>
#       <td id="T_d4865_row5_col5" class="data row5 col5" >0.0697</td>
#     </tr>
#     <tr>
#       <th id="T_d4865_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d4865_row6_col0" class="data row6 col0" >0.3914</td>
#       <td id="T_d4865_row6_col1" class="data row6 col1" >1.3825</td>
#       <td id="T_d4865_row6_col2" class="data row6 col2" >0.4723</td>
#       <td id="T_d4865_row6_col3" class="data row6 col3" >0.8432</td>
#       <td id="T_d4865_row6_col4" class="data row6 col4" >0.0291</td>
#       <td id="T_d4865_row6_col5" class="data row6 col5" >0.0242</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7a211">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a211_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7a211_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7a211_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7a211_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7a211_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7a211_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7a211_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a211_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a211_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7a211_row0_col1" class="data row0 col1" >0.9144</td>
#       <td id="T_7a211_row0_col2" class="data row0 col2" >1.2498</td>
#       <td id="T_7a211_row0_col3" class="data row0 col3" >1.1179</td>
#       <td id="T_7a211_row0_col4" class="data row0 col4" >0.6659</td>
#       <td id="T_7a211_row0_col5" class="data row0 col5" >0.0757</td>
#       <td id="T_7a211_row0_col6" class="data row0 col6" >0.0661</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: catboost , 结果如下:
# <style type="text/css">
# #T_35222_row5_col0, #T_35222_row5_col1, #T_35222_row5_col2, #T_35222_row5_col3, #T_35222_row5_col4, #T_35222_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_35222">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35222_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_35222_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_35222_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_35222_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_35222_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_35222_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35222_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35222_row0_col0" class="data row0 col0" >0.7838</td>
#       <td id="T_35222_row0_col1" class="data row0 col1" >1.1734</td>
#       <td id="T_35222_row0_col2" class="data row0 col2" >1.0832</td>
#       <td id="T_35222_row0_col3" class="data row0 col3" >0.5035</td>
#       <td id="T_35222_row0_col4" class="data row0 col4" >0.0689</td>
#       <td id="T_35222_row0_col5" class="data row0 col5" >0.0525</td>
#     </tr>
#     <tr>
#       <th id="T_35222_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35222_row1_col0" class="data row1 col0" >1.7056</td>
#       <td id="T_35222_row1_col1" class="data row1 col1" >4.5374</td>
#       <td id="T_35222_row1_col2" class="data row1 col2" >2.1301</td>
#       <td id="T_35222_row1_col3" class="data row1 col3" >-1.4228</td>
#       <td id="T_35222_row1_col4" class="data row1 col4" >0.1401</td>
#       <td id="T_35222_row1_col5" class="data row1 col5" >0.1159</td>
#     </tr>
#     <tr>
#       <th id="T_35222_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35222_row2_col0" class="data row2 col0" >0.8142</td>
#       <td id="T_35222_row2_col1" class="data row2 col1" >1.1167</td>
#       <td id="T_35222_row2_col2" class="data row2 col2" >1.0567</td>
#       <td id="T_35222_row2_col3" class="data row2 col3" >0.7729</td>
#       <td id="T_35222_row2_col4" class="data row2 col4" >0.0848</td>
#       <td id="T_35222_row2_col5" class="data row2 col5" >0.0666</td>
#     </tr>
#     <tr>
#       <th id="T_35222_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35222_row3_col0" class="data row3 col0" >0.7985</td>
#       <td id="T_35222_row3_col1" class="data row3 col1" >1.1826</td>
#       <td id="T_35222_row3_col2" class="data row3 col2" >1.0875</td>
#       <td id="T_35222_row3_col3" class="data row3 col3" >0.7292</td>
#       <td id="T_35222_row3_col4" class="data row3 col4" >0.0833</td>
#       <td id="T_35222_row3_col5" class="data row3 col5" >0.0642</td>
#     </tr>
#     <tr>
#       <th id="T_35222_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35222_row4_col0" class="data row4 col0" >0.5742</td>
#       <td id="T_35222_row4_col1" class="data row4 col1" >0.4356</td>
#       <td id="T_35222_row4_col2" class="data row4 col2" >0.6600</td>
#       <td id="T_35222_row4_col3" class="data row4 col3" >0.9305</td>
#       <td id="T_35222_row4_col4" class="data row4 col4" >0.0437</td>
#       <td id="T_35222_row4_col5" class="data row4 col5" >0.0404</td>
#     </tr>
#     <tr>
#       <th id="T_35222_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_35222_row5_col0" class="data row5 col0" >0.9352</td>
#       <td id="T_35222_row5_col1" class="data row5 col1" >1.6891</td>
#       <td id="T_35222_row5_col2" class="data row5 col2" >1.2035</td>
#       <td id="T_35222_row5_col3" class="data row5 col3" >0.3026</td>
#       <td id="T_35222_row5_col4" class="data row5 col4" >0.0842</td>
#       <td id="T_35222_row5_col5" class="data row5 col5" >0.0679</td>
#     </tr>
#     <tr>
#       <th id="T_35222_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_35222_row6_col0" class="data row6 col0" >0.3950</td>
#       <td id="T_35222_row6_col1" class="data row6 col1" >1.4515</td>
#       <td id="T_35222_row6_col2" class="data row6 col2" >0.4906</td>
#       <td id="T_35222_row6_col3" class="data row6 col3" >0.8735</td>
#       <td id="T_35222_row6_col4" class="data row6 col4" >0.0316</td>
#       <td id="T_35222_row6_col5" class="data row6 col5" >0.0257</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1020b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1020b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1020b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1020b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1020b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1020b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1020b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1020b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1020b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1020b_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_1020b_row0_col1" class="data row0 col1" >0.8980</td>
#       <td id="T_1020b_row0_col2" class="data row0 col2" >1.5626</td>
#       <td id="T_1020b_row0_col3" class="data row0 col3" >1.2500</td>
#       <td id="T_1020b_row0_col4" class="data row0 col4" >0.5823</td>
#       <td id="T_1020b_row0_col5" class="data row0 col5" >0.0862</td>
#       <td id="T_1020b_row0_col6" class="data row0 col6" >0.0673</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: et , 结果如下:
# <style type="text/css">
# #T_9299f_row5_col0, #T_9299f_row5_col1, #T_9299f_row5_col2, #T_9299f_row5_col3, #T_9299f_row5_col4, #T_9299f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9299f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9299f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9299f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9299f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9299f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9299f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9299f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9299f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9299f_row0_col0" class="data row0 col0" >1.0774</td>
#       <td id="T_9299f_row0_col1" class="data row0 col1" >2.2390</td>
#       <td id="T_9299f_row0_col2" class="data row0 col2" >1.4963</td>
#       <td id="T_9299f_row0_col3" class="data row0 col3" >0.0527</td>
#       <td id="T_9299f_row0_col4" class="data row0 col4" >0.0958</td>
#       <td id="T_9299f_row0_col5" class="data row0 col5" >0.0704</td>
#     </tr>
#     <tr>
#       <th id="T_9299f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9299f_row1_col0" class="data row1 col0" >1.6239</td>
#       <td id="T_9299f_row1_col1" class="data row1 col1" >4.1640</td>
#       <td id="T_9299f_row1_col2" class="data row1 col2" >2.0406</td>
#       <td id="T_9299f_row1_col3" class="data row1 col3" >-1.2234</td>
#       <td id="T_9299f_row1_col4" class="data row1 col4" >0.1339</td>
#       <td id="T_9299f_row1_col5" class="data row1 col5" >0.1096</td>
#     </tr>
#     <tr>
#       <th id="T_9299f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9299f_row2_col0" class="data row2 col0" >0.6672</td>
#       <td id="T_9299f_row2_col1" class="data row2 col1" >0.7689</td>
#       <td id="T_9299f_row2_col2" class="data row2 col2" >0.8769</td>
#       <td id="T_9299f_row2_col3" class="data row2 col3" >0.8436</td>
#       <td id="T_9299f_row2_col4" class="data row2 col4" >0.0713</td>
#       <td id="T_9299f_row2_col5" class="data row2 col5" >0.0535</td>
#     </tr>
#     <tr>
#       <th id="T_9299f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9299f_row3_col0" class="data row3 col0" >0.9063</td>
#       <td id="T_9299f_row3_col1" class="data row3 col1" >1.8324</td>
#       <td id="T_9299f_row3_col2" class="data row3 col2" >1.3537</td>
#       <td id="T_9299f_row3_col3" class="data row3 col3" >0.5803</td>
#       <td id="T_9299f_row3_col4" class="data row3 col4" >0.1030</td>
#       <td id="T_9299f_row3_col5" class="data row3 col5" >0.0741</td>
#     </tr>
#     <tr>
#       <th id="T_9299f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9299f_row4_col0" class="data row4 col0" >0.7747</td>
#       <td id="T_9299f_row4_col1" class="data row4 col1" >0.7901</td>
#       <td id="T_9299f_row4_col2" class="data row4 col2" >0.8889</td>
#       <td id="T_9299f_row4_col3" class="data row4 col3" >0.8739</td>
#       <td id="T_9299f_row4_col4" class="data row4 col4" >0.0625</td>
#       <td id="T_9299f_row4_col5" class="data row4 col5" >0.0574</td>
#     </tr>
#     <tr>
#       <th id="T_9299f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_9299f_row5_col0" class="data row5 col0" >1.0099</td>
#       <td id="T_9299f_row5_col1" class="data row5 col1" >1.9589</td>
#       <td id="T_9299f_row5_col2" class="data row5 col2" >1.3313</td>
#       <td id="T_9299f_row5_col3" class="data row5 col3" >0.2254</td>
#       <td id="T_9299f_row5_col4" class="data row5 col4" >0.0933</td>
#       <td id="T_9299f_row5_col5" class="data row5 col5" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_9299f_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_9299f_row6_col0" class="data row6 col0" >0.3362</td>
#       <td id="T_9299f_row6_col1" class="data row6 col1" >1.2441</td>
#       <td id="T_9299f_row6_col2" class="data row6 col2" >0.4320</td>
#       <td id="T_9299f_row6_col3" class="data row6 col3" >0.7820</td>
#       <td id="T_9299f_row6_col4" class="data row6 col4" >0.0252</td>
#       <td id="T_9299f_row6_col5" class="data row6 col5" >0.0199</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2b72f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b72f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2b72f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2b72f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2b72f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2b72f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2b72f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2b72f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b72f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b72f_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_2b72f_row0_col1" class="data row0 col1" >1.0912</td>
#       <td id="T_2b72f_row0_col2" class="data row0 col2" >1.6652</td>
#       <td id="T_2b72f_row0_col3" class="data row0 col3" >1.2904</td>
#       <td id="T_2b72f_row0_col4" class="data row0 col4" >0.5548</td>
#       <td id="T_2b72f_row0_col5" class="data row0 col5" >0.0871</td>
#       <td id="T_2b72f_row0_col6" class="data row0 col6" >0.0794</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: lightgbm , 结果如下:
# <style type="text/css">
# #T_726a7_row5_col0, #T_726a7_row5_col1, #T_726a7_row5_col2, #T_726a7_row5_col3, #T_726a7_row5_col4, #T_726a7_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_726a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_726a7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_726a7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_726a7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_726a7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_726a7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_726a7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_726a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_726a7_row0_col0" class="data row0 col0" >1.0242</td>
#       <td id="T_726a7_row0_col1" class="data row0 col1" >1.5993</td>
#       <td id="T_726a7_row0_col2" class="data row0 col2" >1.2647</td>
#       <td id="T_726a7_row0_col3" class="data row0 col3" >0.3233</td>
#       <td id="T_726a7_row0_col4" class="data row0 col4" >0.0812</td>
#       <td id="T_726a7_row0_col5" class="data row0 col5" >0.0692</td>
#     </tr>
#     <tr>
#       <th id="T_726a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_726a7_row1_col0" class="data row1 col0" >1.8762</td>
#       <td id="T_726a7_row1_col1" class="data row1 col1" >5.2066</td>
#       <td id="T_726a7_row1_col2" class="data row1 col2" >2.2818</td>
#       <td id="T_726a7_row1_col3" class="data row1 col3" >-1.7801</td>
#       <td id="T_726a7_row1_col4" class="data row1 col4" >0.1509</td>
#       <td id="T_726a7_row1_col5" class="data row1 col5" >0.1275</td>
#     </tr>
#     <tr>
#       <th id="T_726a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_726a7_row2_col0" class="data row2 col0" >0.7860</td>
#       <td id="T_726a7_row2_col1" class="data row2 col1" >1.0349</td>
#       <td id="T_726a7_row2_col2" class="data row2 col2" >1.0173</td>
#       <td id="T_726a7_row2_col3" class="data row2 col3" >0.7895</td>
#       <td id="T_726a7_row2_col4" class="data row2 col4" >0.0816</td>
#       <td id="T_726a7_row2_col5" class="data row2 col5" >0.0641</td>
#     </tr>
#     <tr>
#       <th id="T_726a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_726a7_row3_col0" class="data row3 col0" >0.8970</td>
#       <td id="T_726a7_row3_col1" class="data row3 col1" >1.3577</td>
#       <td id="T_726a7_row3_col2" class="data row3 col2" >1.1652</td>
#       <td id="T_726a7_row3_col3" class="data row3 col3" >0.6891</td>
#       <td id="T_726a7_row3_col4" class="data row3 col4" >0.0845</td>
#       <td id="T_726a7_row3_col5" class="data row3 col5" >0.0684</td>
#     </tr>
#     <tr>
#       <th id="T_726a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_726a7_row4_col0" class="data row4 col0" >0.7052</td>
#       <td id="T_726a7_row4_col1" class="data row4 col1" >0.6865</td>
#       <td id="T_726a7_row4_col2" class="data row4 col2" >0.8285</td>
#       <td id="T_726a7_row4_col3" class="data row4 col3" >0.8905</td>
#       <td id="T_726a7_row4_col4" class="data row4 col4" >0.0579</td>
#       <td id="T_726a7_row4_col5" class="data row4 col5" >0.0522</td>
#     </tr>
#     <tr>
#       <th id="T_726a7_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_726a7_row5_col0" class="data row5 col0" >1.0577</td>
#       <td id="T_726a7_row5_col1" class="data row5 col1" >1.9770</td>
#       <td id="T_726a7_row5_col2" class="data row5 col2" >1.3115</td>
#       <td id="T_726a7_row5_col3" class="data row5 col3" >0.1824</td>
#       <td id="T_726a7_row5_col4" class="data row5 col4" >0.0912</td>
#       <td id="T_726a7_row5_col5" class="data row5 col5" >0.0763</td>
#     </tr>
#     <tr>
#       <th id="T_726a7_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_726a7_row6_col0" class="data row6 col0" >0.4231</td>
#       <td id="T_726a7_row6_col1" class="data row6 col1" >1.6438</td>
#       <td id="T_726a7_row6_col2" class="data row6 col2" >0.5069</td>
#       <td id="T_726a7_row6_col3" class="data row6 col3" >0.9998</td>
#       <td id="T_726a7_row6_col4" class="data row6 col4" >0.0313</td>
#       <td id="T_726a7_row6_col5" class="data row6 col5" >0.0263</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.7192530331025647, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7192530331025647
# [LightGBM] [Warning] bagging_fraction is set=0.45965799810912356, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45965799810912356
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# <style type="text/css">
# </style>
# <table id="T_6668a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6668a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6668a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6668a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6668a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6668a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6668a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6668a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6668a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6668a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6668a_row0_col1" class="data row0 col1" >0.8995</td>
#       <td id="T_6668a_row0_col2" class="data row0 col2" >1.1222</td>
#       <td id="T_6668a_row0_col3" class="data row0 col3" >1.0594</td>
#       <td id="T_6668a_row0_col4" class="data row0 col4" >0.7000</td>
#       <td id="T_6668a_row0_col5" class="data row0 col5" >0.0730</td>
#       <td id="T_6668a_row0_col6" class="data row0 col6" >0.0658</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.7192530331025647, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7192530331025647
# [LightGBM] [Warning] bagging_fraction is set=0.45965799810912356, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45965799810912356
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5

# %%
# 集成
models = ensemble(tune_models)
# Out:
# <style type="text/css">
# #T_00bdd_row5_col0, #T_00bdd_row5_col1, #T_00bdd_row5_col2, #T_00bdd_row5_col3, #T_00bdd_row5_col4, #T_00bdd_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_00bdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00bdd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_00bdd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_00bdd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_00bdd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_00bdd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_00bdd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00bdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00bdd_row0_col0" class="data row0 col0" >0.8637</td>
#       <td id="T_00bdd_row0_col1" class="data row0 col1" >1.3913</td>
#       <td id="T_00bdd_row0_col2" class="data row0 col2" >1.1795</td>
#       <td id="T_00bdd_row0_col3" class="data row0 col3" >0.4113</td>
#       <td id="T_00bdd_row0_col4" class="data row0 col4" >0.0746</td>
#       <td id="T_00bdd_row0_col5" class="data row0 col5" >0.0573</td>
#     </tr>
#     <tr>
#       <th id="T_00bdd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00bdd_row1_col0" class="data row1 col0" >1.7542</td>
#       <td id="T_00bdd_row1_col1" class="data row1 col1" >4.6690</td>
#       <td id="T_00bdd_row1_col2" class="data row1 col2" >2.1608</td>
#       <td id="T_00bdd_row1_col3" class="data row1 col3" >-1.4930</td>
#       <td id="T_00bdd_row1_col4" class="data row1 col4" >0.1420</td>
#       <td id="T_00bdd_row1_col5" class="data row1 col5" >0.1189</td>
#     </tr>
#     <tr>
#       <th id="T_00bdd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00bdd_row2_col0" class="data row2 col0" >0.7227</td>
#       <td id="T_00bdd_row2_col1" class="data row2 col1" >0.9370</td>
#       <td id="T_00bdd_row2_col2" class="data row2 col2" >0.9680</td>
#       <td id="T_00bdd_row2_col3" class="data row2 col3" >0.8094</td>
#       <td id="T_00bdd_row2_col4" class="data row2 col4" >0.0788</td>
#       <td id="T_00bdd_row2_col5" class="data row2 col5" >0.0584</td>
#     </tr>
#     <tr>
#       <th id="T_00bdd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00bdd_row3_col0" class="data row3 col0" >0.7491</td>
#       <td id="T_00bdd_row3_col1" class="data row3 col1" >1.0890</td>
#       <td id="T_00bdd_row3_col2" class="data row3 col2" >1.0436</td>
#       <td id="T_00bdd_row3_col3" class="data row3 col3" >0.7506</td>
#       <td id="T_00bdd_row3_col4" class="data row3 col4" >0.0782</td>
#       <td id="T_00bdd_row3_col5" class="data row3 col5" >0.0587</td>
#     </tr>
#     <tr>
#       <th id="T_00bdd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00bdd_row4_col0" class="data row4 col0" >0.6355</td>
#       <td id="T_00bdd_row4_col1" class="data row4 col1" >0.4785</td>
#       <td id="T_00bdd_row4_col2" class="data row4 col2" >0.6917</td>
#       <td id="T_00bdd_row4_col3" class="data row4 col3" >0.9237</td>
#       <td id="T_00bdd_row4_col4" class="data row4 col4" >0.0466</td>
#       <td id="T_00bdd_row4_col5" class="data row4 col5" >0.0455</td>
#     </tr>
#     <tr>
#       <th id="T_00bdd_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_00bdd_row5_col0" class="data row5 col0" >0.9451</td>
#       <td id="T_00bdd_row5_col1" class="data row5 col1" >1.7129</td>
#       <td id="T_00bdd_row5_col2" class="data row5 col2" >1.2087</td>
#       <td id="T_00bdd_row5_col3" class="data row5 col3" >0.2804</td>
#       <td id="T_00bdd_row5_col4" class="data row5 col4" >0.0840</td>
#       <td id="T_00bdd_row5_col5" class="data row5 col5" >0.0678</td>
#     </tr>
#     <tr>
#       <th id="T_00bdd_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_00bdd_row6_col0" class="data row6 col0" >0.4111</td>
#       <td id="T_00bdd_row6_col1" class="data row6 col1" >1.5071</td>
#       <td id="T_00bdd_row6_col2" class="data row6 col2" >0.5020</td>
#       <td id="T_00bdd_row6_col3" class="data row6 col3" >0.9030</td>
#       <td id="T_00bdd_row6_col4" class="data row6 col4" >0.0314</td>
#       <td id="T_00bdd_row6_col5" class="data row6 col5" >0.0260</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.7192530331025647, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7192530331025647
# [LightGBM] [Warning] bagging_fraction is set=0.45965799810912356, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45965799810912356
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# <style type="text/css">
# #T_ed6b5 th {
#   text-align: left;
# }
# #T_ed6b5_row0_col0, #T_ed6b5_row0_col1, #T_ed6b5_row0_col3, #T_ed6b5_row0_col5, #T_ed6b5_row0_col6, #T_ed6b5_row1_col0, #T_ed6b5_row1_col1, #T_ed6b5_row1_col2, #T_ed6b5_row1_col3, #T_ed6b5_row1_col4, #T_ed6b5_row1_col5, #T_ed6b5_row1_col6, #T_ed6b5_row2_col0, #T_ed6b5_row2_col1, #T_ed6b5_row2_col2, #T_ed6b5_row2_col3, #T_ed6b5_row2_col4, #T_ed6b5_row2_col5, #T_ed6b5_row2_col6, #T_ed6b5_row3_col0, #T_ed6b5_row3_col1, #T_ed6b5_row3_col2, #T_ed6b5_row3_col3, #T_ed6b5_row3_col4, #T_ed6b5_row3_col5, #T_ed6b5_row3_col6, #T_ed6b5_row4_col0, #T_ed6b5_row4_col2, #T_ed6b5_row4_col4, #T_ed6b5_row5_col0, #T_ed6b5_row5_col1, #T_ed6b5_row5_col2, #T_ed6b5_row5_col3, #T_ed6b5_row5_col4, #T_ed6b5_row5_col5, #T_ed6b5_row5_col6, #T_ed6b5_row6_col0, #T_ed6b5_row6_col1, #T_ed6b5_row6_col2, #T_ed6b5_row6_col3, #T_ed6b5_row6_col4, #T_ed6b5_row6_col5, #T_ed6b5_row6_col6 {
#   text-align: left;
# }
# #T_ed6b5_row0_col2, #T_ed6b5_row0_col4, #T_ed6b5_row4_col1, #T_ed6b5_row4_col3, #T_ed6b5_row4_col5, #T_ed6b5_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ed6b5_row0_col7, #T_ed6b5_row1_col7, #T_ed6b5_row2_col7, #T_ed6b5_row3_col7, #T_ed6b5_row4_col7, #T_ed6b5_row5_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ed6b5_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ed6b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed6b5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ed6b5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ed6b5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ed6b5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ed6b5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ed6b5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ed6b5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ed6b5_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed6b5_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_ed6b5_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_ed6b5_row0_col1" class="data row0 col1" >0.9352</td>
#       <td id="T_ed6b5_row0_col2" class="data row0 col2" >1.6891</td>
#       <td id="T_ed6b5_row0_col3" class="data row0 col3" >1.2035</td>
#       <td id="T_ed6b5_row0_col4" class="data row0 col4" >0.3026</td>
#       <td id="T_ed6b5_row0_col5" class="data row0 col5" >0.0842</td>
#       <td id="T_ed6b5_row0_col6" class="data row0 col6" >0.0679</td>
#       <td id="T_ed6b5_row0_col7" class="data row0 col7" >0.1020</td>
#     </tr>
#     <tr>
#       <th id="T_ed6b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed6b5_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_ed6b5_row1_col1" class="data row1 col1" >0.9585</td>
#       <td id="T_ed6b5_row1_col2" class="data row1 col2" >1.7237</td>
#       <td id="T_ed6b5_row1_col3" class="data row1 col3" >1.2113</td>
#       <td id="T_ed6b5_row1_col4" class="data row1 col4" >0.2902</td>
#       <td id="T_ed6b5_row1_col5" class="data row1 col5" >0.0835</td>
#       <td id="T_ed6b5_row1_col6" class="data row1 col6" >0.0687</td>
#       <td id="T_ed6b5_row1_col7" class="data row1 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_ed6b5_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_ed6b5_row2_col0" class="data row2 col0" >Voting Regressor</td>
#       <td id="T_ed6b5_row2_col1" class="data row2 col1" >0.9451</td>
#       <td id="T_ed6b5_row2_col2" class="data row2 col2" >1.7129</td>
#       <td id="T_ed6b5_row2_col3" class="data row2 col3" >1.2087</td>
#       <td id="T_ed6b5_row2_col4" class="data row2 col4" >0.2804</td>
#       <td id="T_ed6b5_row2_col5" class="data row2 col5" >0.0840</td>
#       <td id="T_ed6b5_row2_col6" class="data row2 col6" >0.0678</td>
#       <td id="T_ed6b5_row2_col7" class="data row2 col7" >0.1900</td>
#     </tr>
#     <tr>
#       <th id="T_ed6b5_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_ed6b5_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ed6b5_row3_col1" class="data row3 col1" >0.9754</td>
#       <td id="T_ed6b5_row3_col2" class="data row3 col2" >1.7563</td>
#       <td id="T_ed6b5_row3_col3" class="data row3 col3" >1.2383</td>
#       <td id="T_ed6b5_row3_col4" class="data row3 col4" >0.2734</td>
#       <td id="T_ed6b5_row3_col5" class="data row3 col5" >0.0858</td>
#       <td id="T_ed6b5_row3_col6" class="data row3 col6" >0.0697</td>
#       <td id="T_ed6b5_row3_col7" class="data row3 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_ed6b5_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_ed6b5_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ed6b5_row4_col1" class="data row4 col1" >0.9173</td>
#       <td id="T_ed6b5_row4_col2" class="data row4 col2" >1.7315</td>
#       <td id="T_ed6b5_row4_col3" class="data row4 col3" >1.1928</td>
#       <td id="T_ed6b5_row4_col4" class="data row4 col4" >0.2549</td>
#       <td id="T_ed6b5_row4_col5" class="data row4 col5" >0.0824</td>
#       <td id="T_ed6b5_row4_col6" class="data row4 col6" >0.0652</td>
#       <td id="T_ed6b5_row4_col7" class="data row4 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_ed6b5_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_ed6b5_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_ed6b5_row5_col1" class="data row5 col1" >1.0099</td>
#       <td id="T_ed6b5_row5_col2" class="data row5 col2" >1.9589</td>
#       <td id="T_ed6b5_row5_col3" class="data row5 col3" >1.3313</td>
#       <td id="T_ed6b5_row5_col4" class="data row5 col4" >0.2254</td>
#       <td id="T_ed6b5_row5_col5" class="data row5 col5" >0.0933</td>
#       <td id="T_ed6b5_row5_col6" class="data row5 col6" >0.0730</td>
#       <td id="T_ed6b5_row5_col7" class="data row5 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_ed6b5_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_ed6b5_row6_col0" class="data row6 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ed6b5_row6_col1" class="data row6 col1" >1.0577</td>
#       <td id="T_ed6b5_row6_col2" class="data row6 col2" >1.9770</td>
#       <td id="T_ed6b5_row6_col3" class="data row6 col3" >1.3115</td>
#       <td id="T_ed6b5_row6_col4" class="data row6 col4" >0.1824</td>
#       <td id="T_ed6b5_row6_col5" class="data row6 col5" >0.0912</td>
#       <td id="T_ed6b5_row6_col6" class="data row6 col6" >0.0763</td>
#       <td id="T_ed6b5_row6_col7" class="data row6 col7" >0.0240</td>
#     </tr>
#   </tbody>
# </table>

# %%
for model_name, model in models.items():
    print(f"\n{'-'*30}")
    print(f"正在分析模型: {model_name.upper()}")
    print(f"{'-'*30}")
    
    # SHAP值解释（需要安装shap包）
    try:
        interpret_model(model)
        plot_model(model, plot = 'feature')
    except:
        print(f"{model_name} 不支持SHAP分析")
# Out:
# ------------------------------
# 正在分析模型: GBR
# ------------------------------
# gbr 不支持SHAP分析
#
# ------------------------------
# 正在分析模型: RF
# ------------------------------
# ------------------------------
# 正在分析模型: XGBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: CATBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: ET
# ------------------------------
# ------------------------------
# 正在分析模型: LIGHTGBM
# ------------------------------
# ------------------------------
# 正在分析模型: BLEND
# ------------------------------
# blend 不支持SHAP分析

# %%
# 定义需要包含的模型简称集合
include_models = {'xgboost','lightgbm','gbr'}

# 生成过滤后的有序字典
seleced_model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}
# 集成
seleced_models = ensemble(seleced_model_dict)
# Out:
# <style type="text/css">
# #T_d5e9d_row5_col0, #T_d5e9d_row5_col1, #T_d5e9d_row5_col2, #T_d5e9d_row5_col3, #T_d5e9d_row5_col4, #T_d5e9d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d5e9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5e9d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d5e9d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d5e9d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d5e9d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d5e9d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d5e9d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5e9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5e9d_row0_col0" class="data row0 col0" >0.9327</td>
#       <td id="T_d5e9d_row0_col1" class="data row0 col1" >1.5464</td>
#       <td id="T_d5e9d_row0_col2" class="data row0 col2" >1.2436</td>
#       <td id="T_d5e9d_row0_col3" class="data row0 col3" >0.3457</td>
#       <td id="T_d5e9d_row0_col4" class="data row0 col4" >0.0794</td>
#       <td id="T_d5e9d_row0_col5" class="data row0 col5" >0.0624</td>
#     </tr>
#     <tr>
#       <th id="T_d5e9d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5e9d_row1_col0" class="data row1 col0" >1.7960</td>
#       <td id="T_d5e9d_row1_col1" class="data row1 col1" >4.8421</td>
#       <td id="T_d5e9d_row1_col2" class="data row1 col2" >2.2005</td>
#       <td id="T_d5e9d_row1_col3" class="data row1 col3" >-1.5855</td>
#       <td id="T_d5e9d_row1_col4" class="data row1 col4" >0.1449</td>
#       <td id="T_d5e9d_row1_col5" class="data row1 col5" >0.1218</td>
#     </tr>
#     <tr>
#       <th id="T_d5e9d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5e9d_row2_col0" class="data row2 col0" >0.7364</td>
#       <td id="T_d5e9d_row2_col1" class="data row2 col1" >0.9848</td>
#       <td id="T_d5e9d_row2_col2" class="data row2 col2" >0.9924</td>
#       <td id="T_d5e9d_row2_col3" class="data row2 col3" >0.7997</td>
#       <td id="T_d5e9d_row2_col4" class="data row2 col4" >0.0804</td>
#       <td id="T_d5e9d_row2_col5" class="data row2 col5" >0.0596</td>
#     </tr>
#     <tr>
#       <th id="T_d5e9d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5e9d_row3_col0" class="data row3 col0" >0.7424</td>
#       <td id="T_d5e9d_row3_col1" class="data row3 col1" >1.0200</td>
#       <td id="T_d5e9d_row3_col2" class="data row3 col2" >1.0100</td>
#       <td id="T_d5e9d_row3_col3" class="data row3 col3" >0.7664</td>
#       <td id="T_d5e9d_row3_col4" class="data row3 col4" >0.0743</td>
#       <td id="T_d5e9d_row3_col5" class="data row3 col5" >0.0571</td>
#     </tr>
#     <tr>
#       <th id="T_d5e9d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5e9d_row4_col0" class="data row4 col0" >0.5703</td>
#       <td id="T_d5e9d_row4_col1" class="data row4 col1" >0.3899</td>
#       <td id="T_d5e9d_row4_col2" class="data row4 col2" >0.6244</td>
#       <td id="T_d5e9d_row4_col3" class="data row4 col3" >0.9378</td>
#       <td id="T_d5e9d_row4_col4" class="data row4 col4" >0.0406</td>
#       <td id="T_d5e9d_row4_col5" class="data row4 col5" >0.0399</td>
#     </tr>
#     <tr>
#       <th id="T_d5e9d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d5e9d_row5_col0" class="data row5 col0" >0.9555</td>
#       <td id="T_d5e9d_row5_col1" class="data row5 col1" >1.7567</td>
#       <td id="T_d5e9d_row5_col2" class="data row5 col2" >1.2142</td>
#       <td id="T_d5e9d_row5_col3" class="data row5 col3" >0.2528</td>
#       <td id="T_d5e9d_row5_col4" class="data row5 col4" >0.0839</td>
#       <td id="T_d5e9d_row5_col5" class="data row5 col5" >0.0682</td>
#     </tr>
#     <tr>
#       <th id="T_d5e9d_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d5e9d_row6_col0" class="data row6 col0" >0.4356</td>
#       <td id="T_d5e9d_row6_col1" class="data row6 col1" >1.5856</td>
#       <td id="T_d5e9d_row6_col2" class="data row6 col2" >0.5315</td>
#       <td id="T_d5e9d_row6_col3" class="data row6 col3" >0.9402</td>
#       <td id="T_d5e9d_row6_col4" class="data row6 col4" >0.0338</td>
#       <td id="T_d5e9d_row6_col5" class="data row6 col5" >0.0279</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] feature_fraction is set=0.7192530331025647, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7192530331025647
# [LightGBM] [Warning] bagging_fraction is set=0.45965799810912356, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45965799810912356
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# <style type="text/css">
# #T_b789b th {
#   text-align: left;
# }
# #T_b789b_row0_col0, #T_b789b_row0_col1, #T_b789b_row0_col2, #T_b789b_row0_col3, #T_b789b_row0_col5, #T_b789b_row0_col6, #T_b789b_row1_col0, #T_b789b_row1_col4, #T_b789b_row2_col0, #T_b789b_row2_col1, #T_b789b_row2_col2, #T_b789b_row2_col3, #T_b789b_row2_col4, #T_b789b_row2_col5, #T_b789b_row2_col6, #T_b789b_row3_col0, #T_b789b_row3_col1, #T_b789b_row3_col2, #T_b789b_row3_col3, #T_b789b_row3_col4, #T_b789b_row3_col5, #T_b789b_row3_col6 {
#   text-align: left;
# }
# #T_b789b_row0_col4, #T_b789b_row1_col1, #T_b789b_row1_col2, #T_b789b_row1_col3, #T_b789b_row1_col5, #T_b789b_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b789b_row0_col7, #T_b789b_row1_col7, #T_b789b_row2_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b789b_row3_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b789b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b789b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b789b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b789b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b789b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b789b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b789b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b789b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b789b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b789b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b789b_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_b789b_row0_col1" class="data row0 col1" >0.9754</td>
#       <td id="T_b789b_row0_col2" class="data row0 col2" >1.7563</td>
#       <td id="T_b789b_row0_col3" class="data row0 col3" >1.2383</td>
#       <td id="T_b789b_row0_col4" class="data row0 col4" >0.2734</td>
#       <td id="T_b789b_row0_col5" class="data row0 col5" >0.0858</td>
#       <td id="T_b789b_row0_col6" class="data row0 col6" >0.0697</td>
#       <td id="T_b789b_row0_col7" class="data row0 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_b789b_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_b789b_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_b789b_row1_col1" class="data row1 col1" >0.9173</td>
#       <td id="T_b789b_row1_col2" class="data row1 col2" >1.7315</td>
#       <td id="T_b789b_row1_col3" class="data row1 col3" >1.1928</td>
#       <td id="T_b789b_row1_col4" class="data row1 col4" >0.2549</td>
#       <td id="T_b789b_row1_col5" class="data row1 col5" >0.0824</td>
#       <td id="T_b789b_row1_col6" class="data row1 col6" >0.0652</td>
#       <td id="T_b789b_row1_col7" class="data row1 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_b789b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b789b_row2_col0" class="data row2 col0" >Voting Regressor</td>
#       <td id="T_b789b_row2_col1" class="data row2 col1" >0.9555</td>
#       <td id="T_b789b_row2_col2" class="data row2 col2" >1.7567</td>
#       <td id="T_b789b_row2_col3" class="data row2 col3" >1.2142</td>
#       <td id="T_b789b_row2_col4" class="data row2 col4" >0.2528</td>
#       <td id="T_b789b_row2_col5" class="data row2 col5" >0.0839</td>
#       <td id="T_b789b_row2_col6" class="data row2 col6" >0.0682</td>
#       <td id="T_b789b_row2_col7" class="data row2 col7" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_b789b_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_b789b_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b789b_row3_col1" class="data row3 col1" >1.0577</td>
#       <td id="T_b789b_row3_col2" class="data row3 col2" >1.9770</td>
#       <td id="T_b789b_row3_col3" class="data row3 col3" >1.3115</td>
#       <td id="T_b789b_row3_col4" class="data row3 col4" >0.1824</td>
#       <td id="T_b789b_row3_col5" class="data row3 col5" >0.0912</td>
#       <td id="T_b789b_row3_col6" class="data row3 col6" >0.0763</td>
#       <td id="T_b789b_row3_col7" class="data row3 col7" >0.0240</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_model = save_models(seleced_models)
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
